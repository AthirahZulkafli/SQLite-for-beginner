# %% [markdown]
# # SQL Essentials

# %% [markdown]
# In this course, we will work with the well-known 'Northwind' database through SQLite. The norhwind database has 12 different tables we can query and is a good database for us to practice our SQL skills. The following diagram shows us how these tables are related to one another in our database.
#
# <img src ='northwind_erd.png'>

# %% [markdown]
# ### SQL General Data Types
#
# |Data Type | Description |
# |:- | :-: |
# | CHAR(*n*)  | 	Character string. Fixed-length *n*.|
# | VARCHAR(*n*) | Character string. Variable length. Maximum length *n*. |
# | INT  | Integer numerical (no decimal). Precision 10.|
# | SMALLINT  | Integer numerical (no decimal). Precision 5. |
# | BIGINT   |  Integer numerical (no decimal). Precision 19. |
# | DECIMAL(*p,s*)* | Exact numerical, precision *p*, scale *s*. |
# | FLOAT | Approximate numerical. Precision 16.|
# |REAL |	Approximate numerical. Precision 7.|
# |TEXT	| Holds a string with a maximum length of 65,535 characters.|
# | DATETIME	| A date and time combination. Format: YYYY-MM-DD HH:MI:SS|
# | IMAGE	| Variable width binary string that holds 2GB data.|
# | BIT	| Integer that can be 0, 1, or NULL.|
# | MONEY**	| Monetary data from -922,337,203,685,477.5808 to 922,337,203,685,477.5807.|
#
# *Example: decimal(5,2) is a number that has 3 digits before the decimal and 2 digits after the decimal.
#
# ** NOT supported in some of sql databases such as Oracle, MySQL.

# %% [markdown]
# #### Run the three following cells to get started working with SQLite on Jupyter. Remember that you need to use the magic functions (%sql or %%sql) when trying to run SQL commands; the former is used for single line commands whilst the latter is for multiple lines.

# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in c:\programdata\anaconda3\lib\site-packages (0.4.0)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\programdata\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: sqlparse in c:\programdata\anaconda3\lib\site-packages (from ipython-sql) (0.4.1)
# Requirement already satisfied: sqlalchemy>=0.6.7 in c:\programdata\anaconda3\lib\site-packages (from ipython-sql) (1.4.7)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: prettytable<1 in c:\programdata\anaconda3\lib\site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: ipython>=1.0 in c:\programdata\anaconda3\lib\site-packages (from ipython-sql) (7.22.0)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: pygments in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (2.8.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (3.0.17)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (5.0.6)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.4.4)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (52.0.0.post20210125)
# Requirement already satisfied: traitlets>=4.2 in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (5.0.5)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.17.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy>=0.6.7->ipython-sql) (1.0.0)

# %% [markdown]
# ### To add SQL extension

# %%
# %load_ext sql

# %% [markdown]
# ### Connect to database

# %%
# %sql sqlite:///northwind.db

# %% [markdown]
# ### Data Manipulation Language (DML)
#
# DML is the data manipulation commands in SQL and can be used to retrieve, store, modify, and delete data from database. Examples of DML are SELECT, INSERT, UPDATE, and DELETE.

# %% [markdown]
# ### SQL keywords are NOT case sensitive: select is the same as SELECT

# %%
#in python is case-sensitive
'Python'=='python'

#but not in sql
# Out:
# False

# %%
# %sql SELECT sql from sqlite_master WHERE type='table';
# Out:
#  * sqlite:///northwind.db
# Done.
# [('CREATE TABLE [Regions](\n\t[RegionID] integer primary key NOT NULL,\n\t[RegionDescription] nvarchar(50) NOT NULL COLLATE NOCASE\n)',),
#  ('CREATE TABLE [PreviousEmployees](\n\t[EmployeeID] integer primary key NOT NULL,\n\t[LastName] nvarchar(20) NOT NULL COLLATE NOCASE,\n\t[FirstName] nv ... (561 characters truncated) ... text NULL,\n\t[PhotoPath] nvarchar(255) NULL COLLATE NOCASE,\n    CONSTRAINT [CK_PreviousEmployeesBirthdate] CHECK ([BirthDate]<CURRENT_TIMESTAMP)\n)',),
#  ('CREATE TABLE [Employees](\n\t[EmployeeID] integer primary key autoincrement NOT NULL,\n\t[LastName] nvarchar(20) NOT NULL COLLATE NOCASE,\n\t[FirstNa ... (553 characters truncated) ... ,\n\t[Notes] ntext NULL,\n\t[PhotoPath] nvarchar(255) NULL COLLATE NOCASE,\n    CONSTRAINT [CK_Birthdate] CHECK  ([BirthDate] < CURRENT_TIMESTAMP)\n)',),
#  ('CREATE TABLE sqlite_sequence(name,seq)',),
#  ('CREATE TABLE [Customers](\n\t[CustomerID] nchar(5) primary key NOT NULL COLLATE NOCASE,\n\t[CompanyName] nvarchar(40) NOT NULL COLLATE NOCASE,\n\t[Co ... (271 characters truncated) ... LATE NOCASE,\n\t[Country] nvarchar(15) NULL COLLATE NOCASE,\n\t[Phone] nvarchar(24) NULL COLLATE NOCASE,\n\t[Fax] nvarchar(24) NULL COLLATE NOCASE\n)',),
#  ('CREATE TABLE [Suppliers](\n\t[SupplierID] integer primary key autoincrement NOT NULL,\n\t[CompanyName] nvarchar(40) NOT NULL COLLATE NOCASE,\n\t[Cont ... (310 characters truncated) ... LL COLLATE NOCASE,\n\t[Phone] nvarchar(24) NULL COLLATE NOCASE,\n\t[Fax] nvarchar(24) NULL COLLATE NOCASE,\n\t[HomePage] ntext NULL COLLATE NOCASE\n)',),
#  ('CREATE TABLE [InternationalOrders](\n\t[OrderID] integer primary key NOT NULL,\n\t[CustomsDescription] nvarchar(100) NOT NULL COLLATE NOCASE,\n\t[ExciseTax] money NOT NULL,\n    CONSTRAINT [FK_InternationalOrders_Orders] FOREIGN KEY([OrderID])\n    REFERENCES [Orders] ([OrderID])\n)',),
#  ('CREATE TABLE [OrderDetails](\n\t[OrderID] integer NOT NULL,\n\t[ProductID] integer NOT NULL,\n\t[UnitPrice] money NOT NULL CONSTRAINT [DF_Order_Detai ... (549 characters truncated) ...     REFERENCES [Orders] ([OrderID]),\n    CONSTRAINT [FK_Order_Details_Products] FOREIGN KEY([ProductID])\n    REFERENCES [Products] ([ProductID])\n)',),
#  ('CREATE TABLE [Territories](\n\t[TerritoryID] integer primary key NOT NULL,\n\t[TerritoryDescription] nvarchar(50) NOT NULL COLLATE NOCASE,\n\t[RegionID] integer NOT NULL,\n    CONSTRAINT [FK_Territories_Region] FOREIGN KEY([RegionID])\n    REFERENCES [Regions] ([RegionID])\n)',),
#  ('CREATE TABLE [EmployeesTerritories](\n\t[EmployeeID] integer NOT NULL,\n\t[TerritoryID] integer NOT NULL,\n    CONSTRAINT [PK_EmployeeTerritories] PR ... (168 characters truncated) ... ees] ([EmployeeID]),\n    CONSTRAINT [FK_EmployeeTerritories_Territories] FOREIGN KEY([TerritoryID])\n    REFERENCES [Territories] ([TerritoryID])\n)',),
#  ('CREATE TABLE [Products](\n\t[ProductID] integer primary key autoincrement NOT NULL,\n\t[ProductName] nvarchar(40) NOT NULL COLLATE NOCASE,\n\t[Suppli ... (885 characters truncated) ... FERENCES [Categories] ([CategoryID]),\n    CONSTRAINT [FK_Products_Suppliers] FOREIGN KEY([SupplierID])\n    REFERENCES [Suppliers] ([SupplierID])\n)',),
#  ('CREATE TABLE [Orders](\n\t[OrderID] integer primary key autoincrement NOT NULL,\n\t[CustomerID] nchar(5) NULL COLLATE NOCASE,\n\t[EmployeeID] integer ... (433 characters truncated) ... ntry] nvarchar(15) NULL COLLATE NOCASE,\n    CONSTRAINT [FK_Orders_Customers] FOREIGN KEY([CustomerID])\n    REFERENCES [Customers] ([CustomerID])\n)',),
#  ('CREATE TABLE [Categories] (\r\n    [CategoryID] integer PRIMARY KEY AUTOINCREMENT NOT NULL,\r\n    [CategoryName] nvarchar(15) NOT NULL COLLATE NOCASE,\r\n    [Description] nvarchar COLLATE NOCASE,\r\n    [Picture] varbinary\r\n)',),
#  ('CREATE TABLE [PagingTest] (\r    [Id] integer PRIMARY KEY AUTOINCREMENT NOT NULL,\r    [Row] integer NOT NULL COLLATE NOCASE\r)',),
#  ('CREATE TABLE Shippers (\nShipperID integer,\nShipperName text,\nPhone text\n)',)]

# %% [markdown]
# ### The SELECT statement is used to select data from a database.
# #### The data returned is stored in a result table, called the result-set.

# %%
# %sql SELECT * FROM Customers;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Inigo Montoya', 'Owner', 'Mataderos  2312', 'México D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', None, '68306', 'Germany', '0621-08460', '0621-08924'),
#  ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', 'Marketing Manager', '24, place Kléber', 'Strasbourg', None, '67000', 'France', '88.60.15.31', '88.60.15.32'),
#  ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', 'Owner', 'C/ Araquil, 67', 'Madrid', None, '28023', 'Spain', '(91) 555 22 82', '(91) 555 91 99'),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 'Owner', '12, rue des Bouchers', 'Marseille', None, '13008', 'France', '91.24.45.40', '91.24.45.41'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Accounting Manager', '23 Tsawassen Blvd.', 'Tsawassen', 'BC', 'T2F 8M4', 'Canada', '(604) 555-4729', '(604) 555-3745'),
#  ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None),
#  ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Sales Agent', 'Cerrito 333', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5555', '(1) 135-4892'),
#  ('CENTC', 'Centro comercial Moctezuma', 'Antonio Banderas', 'Marketing Manager', 'Sierras de Granada 9993', 'México D.F.', None, '05022', 'Mexico', '(5) 555-3392', '(5) 555-7293'),
#  ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Owner', 'Hauptstr. 29', 'Bern', None, '3012', 'Switzerland', '0452-076545', None),
#  ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', 'Sales Associate', 'Av. dos Lusíadas, 23', 'Sao Paulo', 'SP', '05432-043', 'Brazil', '(11) 555-7647', None),
#  ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199'),
#  ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Order Administrator', 'Walserweg 21', 'Aachen', None, '52066', 'Germany', '0241-039123', '0241-059428'),
#  ('DUMON', 'Du monde entier', 'Janine Labrune', 'Owner', '67, rue des Cinquante Otages', 'Nantes', None, '44000', 'France', '40.67.88.88', '40.67.89.89'),
#  ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'),
#  ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Sales Manager', 'Kirchgasse 6', 'Graz', None, '8010', 'Austria', '7675-3425', '7675-3426'),
#  ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Marketing Assistant', 'Rua Orós, 92', 'Sao Paulo', 'SP', '05442-030', 'Brazil', '(11) 555-9857', None),
#  ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'Accounting Manager', 'C/ Moralzarzal, 86', 'Madrid', None, '28034', 'Spain', '(91) 555 94 44', '(91) 555 55 93'),
#  ('FOLIG', 'Folies gourmandes', 'Martine Rancé', 'Assistant Sales Agent', '184, chaussée de Tournai', 'Lille', None, '59000', 'France', '20.16.10.16', '20.16.10.17'),
#  ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Owner', 'Åkergatan 24', 'Bräcke', None, 'S-844 67', 'Sweden', '0695-34 67 21', None),
#  ('FRANK', 'Frankenversand', 'Peter Franken', 'Marketing Manager', 'Berliner Platz 43', 'München', None, '80805', 'Germany', '089-0877310', '089-0877451'),
#  ('FRANR', 'France restauration', 'Carine Schmitt', 'Marketing Manager', '54, rue Royale', 'Nantes', None, '44000', 'France', '40.32.21.21', '40.32.21.20'),
#  ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Sales Representative', 'Via Monte Bianco 34', 'Torino', None, '10100', 'Italy', '011-4988260', '011-4988261'),
#  ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Sales Manager', 'Jardim das rosas n. 32', 'Lisboa', None, '1675', 'Portugal', '(1) 354-2534', '(1) 354-2535'),
#  ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Marketing Manager', 'Rambla de Cataluña, 23', 'Barcelona', None, '08022', 'Spain', '(93) 203 4560', '(93) 203 4561'),
#  ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'Sales Manager', 'C/ Romero, 33', 'Sevilla', None, '41101', 'Spain', '(95) 555 82 82', None),
#  ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Sales Associate', 'Av. Brasil, 442', 'Campinas', 'SP', '04876-786', 'Brazil', '(11) 555-9482', None),
#  ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 'Marketing Manager', '2732 Baker Blvd.', 'Eugene', 'OR', '97403', 'USA', '(503) 555-7555', None),
#  ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', 'Owner', '5ª Ave. Los Palos Grandes', 'Caracas', 'DF', '1081', 'Venezuela', '(2) 283-2951', '(2) 283-3397'),
#  ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Accounting Manager', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil', '(21) 555-0091', '(21) 555-8765'),
#  ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Sales Representative', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', 'Táchira', '5022', 'Venezuela', '(5) 555-1340', '(5) 555-1948'),
#  ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'Sales Representative', 'City Center Plaza 516 Main St.', 'Elgin', 'OR', '97827', 'USA', '(503) 555-6874', '(503) 555-2376'),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', 'Sales Associate', '8 Johnstown Road', 'Cork', 'Co. Cork', None, 'Ireland', '2967 542', '2967 3333'),
#  ('ISLAT', 'Island Trading', 'Helen Bennett', 'Marketing Manager', 'Garden House Crowther Way', 'Cowes', 'Isle of Wight', 'PO31 7PJ', 'UK', '(198) 555-8888', None),
#  ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Sales Associate', 'Maubelstr. 90', 'Brandenburg', None, '14776', 'Germany', '0555-09876', None),
#  ('LACOR', "La corne d'abondance", 'Daniel Tonini', 'Sales Representative', "67, avenue de l'Europe", 'Versailles', None, '78000', 'France', '30.59.84.10', '30.59.85.11'),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', 'Marketing Assistant', '1900 Oak St.', 'Vancouver', 'BC', 'V3F 2K1', 'Canada', '(604) 555-3392', '(604) 555-7293'),
#  ('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Marketing Manager', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'USA', '(509) 555-7969', '(509) 555-6221'),
#  ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Sales Representative', 'Magazinweg 7', 'Frankfurt a.M.', None, '60528', 'Germany', '069-0245984', '069-0245874'),
#  ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Owner', '87 Polk St. Suite 5', 'San Francisco', 'CA', '94117', 'USA', '(415) 555-5938', None),
#  ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Accounting Manager', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', 'Lara', '3508', 'Venezuela', '(9) 331-6954', '(9) 331-7256'),
#  ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Owner', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', 'Nueva Esparta', '4980', 'Venezuela', '(8) 34-56-12', '(8) 34-93-93'),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 'Sales Manager', '89 Chiaroscuro Rd.', 'Portland', 'OR', '97219', 'USA', '(503) 555-9573', '(503) 555-9646'),
#  ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Marketing Manager', 'Via Ludovico il Moro 22', 'Bergamo', None, '24100', 'Italy', '035-640230', '035-640231'),
#  ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Sales Agent', 'Rue Joseph-Bens 532', 'Bruxelles', None, 'B-1180', 'Belgium', '(02) 201 24 67', '(02) 201 24 68'),
#  ('MEREP', 'Mère Paillarde', 'Jean Fresnière', 'Marketing Assistant', '43 rue St. Laurent', 'Montréal', 'Québec', 'H1J 1C3', 'Canada', '(514) 555-8054', '(514) 555-8055'),
#  ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Marketing Assistant', 'Heerstr. 22', 'Leipzig', None, '04179', 'Germany', '0342-023176', None),
#  ('NORTS', 'North/South', 'Simon Crowther', 'Sales Associate', 'South House 300 Queensbridge', 'London', None, 'SW7 1RZ', 'UK', '(171) 555-7733', '(171) 555-2530'),
#  ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Sales Agent', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5333', '(1) 135-5535'),
#  ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', 'Sales Representative', '2743 Bering St.', 'Anchorage', 'AK', '99508', 'USA', '(907) 555-7584', '(907) 555-2880'),
#  ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Owner', 'Mehrheimerstr. 369', 'Köln', None, '50739', 'Germany', '0221-0644327', '0221-0765721'),
#  ('PARIS', 'Paris spécialités', 'Marie Bertrand', 'Owner', '265, boulevard Charonne', 'Paris', None, '75012', 'France', '(1) 42.34.22.66', '(1) 42.34.22.77'),
#  ('PERIC', 'Pericles Comidas clásicas', 'Salma Hayek', 'Sales Representative', 'Calle Dr. Jorge Cash 321', 'México D.F.', None, '05033', 'Mexico', '(5) 552-3745', '(5) 545-3745'),
#  ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Sales Manager', 'Geislweg 14', 'Salzburg', None, '5020', 'Austria', '6562-9722', '6562-9723'),
#  ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Sales Representative', 'Estrada da saúde n. 58', 'Lisboa', None, '1756', 'Portugal', '(1) 356-5634', None),
#  ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Accounting Manager', 'Rua da Panificadora, 12', 'Rio de Janeiro', 'RJ', '02389-673', 'Brazil', '(21) 555-4252', '(21) 555-4545'),
#  ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Marketing Assistant', 'Alameda dos Canàrios, 891', 'Sao Paulo', 'SP', '05487-020', 'Brazil', '(11) 555-1189', None),
#  ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Accounting Manager', 'Taucherstraße 10', 'Cunewalde', None, '01307', 'Germany', '0372-035188', None),
#  ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Sales Representative', 'Av. del Libertador 900', 'Buenos Aires', None, '1010', 'Argentina', '(1) 123-5555', '(1) 123-5556'),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', 'Assistant Sales Representative', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA', '(505) 555-5939', '(505) 555-3620'),
#  ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Sales Associate', 'Strada Provinciale 124', 'Reggio Emilia', None, '42100', 'Italy', '0522-556721', '0522-556722'),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Assistant Sales Agent', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brazil', '(21) 555-3412', None),
#  ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Sales Manager', 'Grenzacherweg 237', 'Genève', None, '1203', 'Switzerland', '0897-034214', None),
#  ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Accounting Manager', 'Gran Vía, 1', 'Madrid', None, '28001', 'Spain', '(91) 745 6200', '(91) 745 6210'),
#  ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Owner', 'Erling Skakkes gate 78', 'Stavern', None, '4110', 'Norway', '07-98 92 35', '07-98 92 47'),
#  ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Sales Representative', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', None),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Owner', 'Vinbæltet 34', 'Kobenhavn', None, '1734', 'Denmark', '31 12 34 56', '31 13 35 57'),
#  ('SPECD', 'Spécialités du monde', 'Dominique Perrier', 'Marketing Manager', '25, rue Lauriston', 'Paris', None, '75016', 'France', '(1) 47.55.60.10', '(1) 47.55.60.20'),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525'),
#  ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Accounting Manager', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium', '(071) 23 67 22 20', '(071) 23 67 22 21'),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Marketing Manager', '89 Jefferson Way Suite 2', 'Portland', 'OR', '97201', 'USA', '(503) 555-3612', None),
#  ('THECR', 'The Cracker Box', 'Liu Wong', 'Marketing Assistant', '55 Grizzly Peak Rd.', 'Butte', 'MT', '59801', 'USA', '(406) 555-5834', '(406) 555-8083'),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany', '0251-031259', '0251-035695'),
#  ('TORTU', 'Tortuga Restaurante', 'Hugo Sanchis', 'Owner', 'Avda. Azteca 123', 'México D.F.', None, '05033', 'Mexico', '(5) 555-2933', None),
#  ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Sales Representative', 'Av. Inês de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brazil', '(11) 555-2167', '(11) 555-2168'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Sales Associate', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'USA', '(206) 555-8257', '(206) 555-2174'),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Sales Manager', 'Smagsloget 45', 'Århus', None, '8200', 'Denmark', '86 21 32 43', '86 22 33 44'),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'Sales Agent', '2, rue du Commerce', 'Lyon', None, '69004', 'France', '78.32.54.86', '78.32.54.87'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11'),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Sales Representative', 'Adenauerallee 900', 'Stuttgart', None, '70563', 'Germany', '0711-020361', '0711-035428'),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Accounting Manager', 'Torikatu 38', 'Oulu', None, '90110', 'Finland', '981-443655', '981-443655'),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Sales Manager', 'Rua do Mercado, 12', 'Resende', 'SP', '08737-363', 'Brazil', '(14) 555-8122', None),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115'),
#  ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Owner/Marketing Assistant', 'Keskuskatu 45', 'Helsinki', None, '21240', 'Finland', '90-224 8858', '90-224 8858'),
#  ('WOLZA', 'Wolski Zajazd', 'Zbyszek Piestrzeniewicz', 'Owner', 'ul. Filtrowa 68', 'Warszawa', None, '01-012', 'Poland', '(26) 642-7012', '(26) 642-7012'),
#  ('CARTO', 'Cardinal', 'Tom B. Erichsen', 'Owner', 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('BARCAS', 'Barcelona CF', 'Lionel Messi', None, 'Camp Nou', 'Barcelona', None, '8028', 'Spain', None, None),
#  ('CART1', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4040', 'Norway', None, None),
#  ('CART2', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, 'Norway', None, None)]

# %% [markdown]
# #### The following statement returns the columns information stored in table Orders

# %%
# %sql PRAGMA table_info(Orders);
# Out:
#  * sqlite:///northwind.db
# Done.
# [(0, 'OrderID', 'integer', 1, None, 1),
#  (1, 'CustomerID', 'nchar(5)', 0, None, 0),
#  (2, 'EmployeeID', 'integer', 0, None, 0),
#  (3, 'OrderDate', 'datetime', 0, None, 0),
#  (4, 'RequiredDate', 'datetime', 0, None, 0),
#  (5, 'ShippedDate', 'datetime', 0, None, 0),
#  (6, 'Freight', 'money', 0, '0', 0),
#  (7, 'ShipName', 'nvarchar(40)', 0, None, 0),
#  (8, 'ShipAddress', 'nvarchar(60)', 0, None, 0),
#  (9, 'ShipCity', 'nvarchar(15)', 0, None, 0),
#  (10, 'ShipRegion', 'nvarchar(15)', 0, None, 0),
#  (11, 'ShipPostalCode', 'nvarchar(10)', 0, None, 0),
#  (12, 'ShipCountry', 'nvarchar(15)', 0, None, 0)]

# %%
# %sql PRAGMA table_info(Employees);
# Out:
#  * sqlite:///northwind.db
# Done.
# [(0, 'EmployeeID', 'integer', 1, None, 1),
#  (1, 'LastName', 'nvarchar(20)', 1, None, 0),
#  (2, 'FirstName', 'nvarchar(10)', 1, None, 0),
#  (3, 'Title', 'nvarchar(30)', 0, None, 0),
#  (4, 'TitleOfCourtesy', 'nvarchar(25)', 0, None, 0),
#  (5, 'BirthDate', 'datetime', 0, None, 0),
#  (6, 'HireDate', 'datetime', 0, None, 0),
#  (7, 'Address', 'nvarchar(60)', 0, None, 0),
#  (8, 'City', 'nvarchar(15)', 0, None, 0),
#  (9, 'Region', 'nvarchar(15)', 0, None, 0),
#  (10, 'PostalCode', 'nvarchar(10)', 0, None, 0),
#  (11, 'Country', 'nvarchar(15)', 0, None, 0),
#  (12, 'HomePhone', 'nvarchar(24)', 0, None, 0),
#  (13, 'Extension', 'nvarchar(4)', 0, None, 0),
#  (14, 'Photo', 'image', 0, None, 0),
#  (15, 'Notes', 'ntext', 0, None, 0),
#  (16, 'PhotoPath', 'nvarchar(255)', 0, None, 0)]

# %%
# %sql PRAGMA table_info(Customers);
#untuk tengook column/attribute
# Out:
#  * sqlite:///northwind.db
# Done.
# [(0, 'CustomerID', 'nchar(5)', 1, None, 1),
#  (1, 'CompanyName', 'nvarchar(40)', 1, None, 0),
#  (2, 'ContactName', 'nvarchar(30)', 0, None, 0),
#  (3, 'ContactTitle', 'nvarchar(30)', 0, None, 0),
#  (4, 'Address', 'nvarchar(60)', 0, None, 0),
#  (5, 'City', 'nvarchar(15)', 0, None, 0),
#  (6, 'Region', 'nvarchar(15)', 0, None, 0),
#  (7, 'PostalCode', 'nvarchar(10)', 0, None, 0),
#  (8, 'Country', 'nvarchar(15)', 0, None, 0),
#  (9, 'Phone', 'nvarchar(24)', 0, None, 0),
#  (10, 'Fax', 'nvarchar(24)', 0, None, 0)]

# %%
# %sql PRAGMA foreign_key_list(Orders);
# Out:
#  * sqlite:///northwind.db
# Done.
# [(0, 0, 'Customers', 'CustomerID', 'CustomerID', 'NO ACTION', 'NO ACTION', 'NONE')]

# %% [markdown]
# ### Some database systems require a semicolon at the end of each SQL statement. Semicolon is the standard way to separate each SQL statement in database systems that allow more than one SQL statement to be executed in the same call to the server.

# %% [markdown]
# ## SELECT Column Example

# %% [markdown]
# #### The following SQL statement selects the "CustomerName" and "City" columns from the "Customers" table:

# %%
# %%sql SELECT OrderID, Freight
# FROM Orders
# Out:
#  * sqlite:///northwind.db
# Done.
# [(10248, 32.38),
#  (10249, 11.61),
#  (10250, 65.83),
#  (10251, 41.34),
#  (10252, 51.3),
#  (10253, 58.17),
#  (10254, 22.98),
#  (10255, 148.33),
#  (10256, 13.97),
#  (10257, 81.91),
#  (10258, 140.51),
#  (10259, 3.25),
#  (10260, 55.09),
#  (10261, 3.05),
#  (10262, 48.29),
#  (10263, 146.06),
#  (10264, 3.67),
#  (10265, 55.28),
#  (10266, 25.73),
#  (10267, 208.58),
#  (10268, 66.29),
#  (10269, 4.56),
#  (10270, 136.54),
#  (10271, 4.54),
#  (10272, 98.03),
#  (10273, 76.07),
#  (10274, 6.01),
#  (10275, 26.93),
#  (10276, 13.84),
#  (10277, 125.77),
#  (10278, 92.69),
#  (10279, 25.83),
#  (10280, 8.98),
#  (10281, 2.94),
#  (10282, 12.69),
#  (10283, 84.81),
#  (10284, 76.56),
#  (10285, 76.83),
#  (10286, 229.24),
#  (10287, 12.76),
#  (10288, 7.45),
#  (10289, 22.77),
#  (10290, 79.7),
#  (10291, 6.4),
#  (10292, 1.35),
#  (10293, 21.18),
#  (10294, 147.26),
#  (10295, 1.15),
#  (10296, 0.12),
#  (10297, 5.74),
#  (10298, 168.22),
#  (10299, 29.76),
#  (10300, 17.68),
#  (10301, 45.08),
#  (10302, 6.27),
#  (10303, 107.83),
#  (10304, 63.79),
#  (10305, 257.62),
#  (10306, 7.56),
#  (10307, 0.56),
#  (10308, 1.61),
#  (10309, 47.3),
#  (10310, 17.52),
#  (10311, 24.69),
#  (10312, 40.26),
#  (10313, 1.96),
#  (10314, 74.16),
#  (10315, 41.76),
#  (10316, 150.15),
#  (10317, 12.69),
#  (10318, 4.73),
#  (10319, 64.5),
#  (10320, 34.57),
#  (10321, 3.43),
#  (10963, 2.7),
#  (10964, 87.38),
#  (10965, 144.38),
#  (10966, 27.19),
#  (10967, 62.22),
#  (10968, 74.6),
#  (10969, 0.21),
#  (10970, 16.16),
#  (10971, 121.82),
#  (10972, 0.02),
#  (10973, 15.17),
#  (10974, 12.96),
#  (10975, 32.27),
#  (10976, 37.97),
#  (10977, 208.5),
#  (10978, 32.82),
#  (10979, 353.07),
#  (10980, 1.26),
#  (10981, 193.37),
#  (10982, 14.01),
#  (10983, 657.54),
#  (10984, 211.22),
#  (10985, 91.51),
#  (10986, 217.86),
#  (10987, 185.48),
#  (10988, 61.14),
#  (10989, 34.76),
#  (10990, 117.61),
#  (10991, 38.51),
#  (10992, 4.27),
#  (10993, 8.81),
#  (10994, 65.53),
#  (10995, 46),
#  (10996, 1.12),
#  (10997, 73.91),
#  (10998, 20.31),
#  (10999, 96.35),
#  (11000, 55.12),
#  (11001, 197.3),
#  (11002, 141.16),
#  (11003, 14.91),
#  (11004, 44.84),
#  (11005, 0.75),
#  (11006, 25.19),
#  (11007, 202.24),
#  (11008, 79.46),
#  (11009, 59.11),
#  (11010, 28.71),
#  (11011, 1.21),
#  (11012, 242.95),
#  (11013, 32.99),
#  (11014, 23.6),
#  (11015, 4.62),
#  (11016, 33.8),
#  (11017, 754.26),
#  (11018, 11.65),
#  (11019, 3.17),
#  (11020, 43.3),
#  (11021, 297.18),
#  (11022, 6.27),
#  (11023, 123.83),
#  (11024, 74.36),
#  (11025, 29.17),
#  (11026, 47.09),
#  (11027, 52.52),
#  (11028, 29.59),
#  (11029, 47.84),
#  (11030, 830.75),
#  (11031, 227.22),
#  (11032, 606.19),
#  (11033, 84.74),
#  (11034, 40.32),
#  (11035, 0.17),
#  (11036, 149.47),
#  (11037, 3.2),
#  (11038, 29.59),
#  (11039, 65),
#  (11040, 18.84),
#  (11041, 48.22),
#  (11042, 29.99),
#  (11043, 8.8),
#  (11044, 8.72),
#  (11045, 70.58),
#  (11046, 71.64),
#  (11047, 46.62),
#  (11048, 24.12),
#  (11049, 8.34),
#  (11050, 59.41),
#  (11051, 2.79),
#  (11052, 67.26),
#  (11053, 53.05),
#  (11054, 0.33),
#  (11055, 120.92),
#  (11056, 278.96),
#  (11057, 4.13),
#  (11058, 31.14),
#  (11059, 85.8),
#  (11060, 10.98),
#  (11061, 14.01),
#  (11062, 29.93),
#  (11063, 81.73),
#  (11064, 30.09),
#  (11065, 12.91),
#  (11066, 44.72),
#  (11067, 7.98),
#  (11068, 81.75),
#  (11069, 15.67),
#  (11070, 136),
#  (11071, 0.93),
#  (11072, 258.64),
#  (11073, 24.95),
#  (11074, 18.44),
#  (11075, 6.19),
#  (11076, 38.28),
#  (11077, 8.53)]

# %%
# %%sql SELECT OrderID, Freight
# FROM Orders
# WHERE Freight >  (SELECT Freight)
# Out:
#  * sqlite:///northwind.db
# Done.
# []

# %%
# %%sql SELECT CompanyName, City
# FROM Customers;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('Alfreds Futterkiste', 'Berlin'),
#  ('Ana Trujillo Emparedados y helados', 'México D.F.'),
#  ('Antonio Moreno Taquería', 'México D.F.'),
#  ('Around the Horn', 'London'),
#  ('Berglunds snabbköp', 'Luleå'),
#  ('Blauer See Delikatessen', 'Mannheim'),
#  ('Blondesddsl père et fils', 'Strasbourg'),
#  ('Bólido Comidas preparadas', 'Madrid'),
#  ("Bon app'", 'Marseille'),
#  ('Bottom-Dollar Markets', 'Tsawassen'),
#  ("B's Beverages", 'London'),
#  ('Cactus Comidas para llevar', 'Buenos Aires'),
#  ('Centro comercial Moctezuma', 'México D.F.'),
#  ('Chop-suey Chinese', 'Bern'),
#  ('Comércio Mineiro', 'Sao Paulo'),
#  ('Consolidated Holdings', 'London'),
#  ('Drachenblut Delikatessen', 'Aachen'),
#  ('Du monde entier', 'Nantes'),
#  ('Eastern Connection', 'London'),
#  ('Ernst Handel', 'Graz'),
#  ('Familia Arquibaldo', 'Sao Paulo'),
#  ('FISSA Fabrica Inter. Salchichas S.A.', 'Madrid'),
#  ('Folies gourmandes', 'Lille'),
#  ('Folk och fä HB', 'Bräcke'),
#  ('Frankenversand', 'München'),
#  ('France restauration', 'Nantes'),
#  ('Franchi S.p.A.', 'Torino'),
#  ('Furia Bacalhau e Frutos do Mar', 'Lisboa'),
#  ('Galería del gastrónomo', 'Barcelona'),
#  ('Godos Cocina Típica', 'Sevilla'),
#  ('Gourmet Lanchonetes', 'Campinas'),
#  ('Great Lakes Food Market', 'Eugene'),
#  ('GROSELLA-Restaurante', 'Caracas'),
#  ('Hanari Carnes', 'Rio de Janeiro'),
#  ('HILARION-Abastos', 'San Cristóbal'),
#  ('Hungry Coyote Import Store', 'Elgin'),
#  ('Hungry Owl All-Night Grocers', 'Cork'),
#  ('Island Trading', 'Cowes'),
#  ('Königlich Essen', 'Brandenburg'),
#  ("La corne d'abondance", 'Versailles'),
#  ('Laughing Bacchus Wine Cellars', 'Vancouver'),
#  ('Lazy K Kountry Store', 'Walla Walla'),
#  ('Lehmanns Marktstand', 'Frankfurt a.M.'),
#  ("Let's Stop N Shop", 'San Francisco'),
#  ('LILA-Supermercado', 'Barquisimeto'),
#  ('LINO-Delicateses', 'I. de Margarita'),
#  ('Lonesome Pine Restaurant', 'Portland'),
#  ('Magazzini Alimentari Riuniti', 'Bergamo'),
#  ('Maison Dewey', 'Bruxelles'),
#  ('Mère Paillarde', 'Montréal'),
#  ('Morgenstern Gesundkost', 'Leipzig'),
#  ('North/South', 'London'),
#  ('Océano Atlántico Ltda.', 'Buenos Aires'),
#  ('Old World Delicatessen', 'Anchorage'),
#  ('Ottilies Käseladen', 'Köln'),
#  ('Paris spécialités', 'Paris'),
#  ('Pericles Comidas clásicas', 'México D.F.'),
#  ('Piccolo und mehr', 'Salzburg'),
#  ('Princesa Isabel Vinhos', 'Lisboa'),
#  ('Que Delícia', 'Rio de Janeiro'),
#  ('Queen Cozinha', 'Sao Paulo'),
#  ('QUICK-Stop', 'Cunewalde'),
#  ('Rancho grande', 'Buenos Aires'),
#  ('Rattlesnake Canyon Grocery', 'Albuquerque'),
#  ('Reggiani Caseifici', 'Reggio Emilia'),
#  ('Ricardo Adocicados', 'Rio de Janeiro'),
#  ('Richter Supermarkt', 'Genève'),
#  ('Romero y tomillo', 'Madrid'),
#  ('Santé Gourmet', 'Stavern'),
#  ('Save-a-lot Markets', 'Boise'),
#  ('Seven Seas Imports', 'London'),
#  ('Simons bistro', 'Kobenhavn'),
#  ('Spécialités du monde', 'Paris'),
#  ('Split Rail Beer & Ale', 'Lander'),
#  ('Suprêmes délices', 'Charleroi'),
#  ('The Big Cheese', 'Portland'),
#  ('The Cracker Box', 'Butte'),
#  ('Toms Spezialitäten', 'Münster'),
#  ('Tortuga Restaurante', 'México D.F.'),
#  ('Tradição Hipermercados', 'Sao Paulo'),
#  ("Trail's Head Gourmet Provisioners", 'Kirkland'),
#  ('Vaffeljernet', 'Århus'),
#  ('Victuailles en stock', 'Lyon'),
#  ('Vins et alcools Chevalier', 'Reims'),
#  ('Die Wandernde Kuh', 'Stuttgart'),
#  ('Wartian Herkku', 'Oulu'),
#  ('Wellington Importadora', 'Resende'),
#  ('White Clover Markets', 'Seattle'),
#  ('Wilman Kala', 'Helsinki'),
#  ('Wolski Zajazd', 'Warszawa'),
#  ('Cardinal', 'Stavanger'),
#  ('Barcelona CF', 'Barcelona'),
#  ('Cardinal', 'Stavanger'),
#  ('Cardinal', '4006')]

# %% [markdown]
# ## SELECT * Example

# %%
# %%sql SELECT
#     table_name
# FROM
#     dba_tables;
# Out:
#  * sqlite:///northwind.db
# (sqlite3.OperationalError) no such table: dba_tables
# [SQL: SELECT table_name FROM dba_tables;]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ### The following SQL statement selects all the columns from the Customers table:

# %%
# %sql SELECT * FROM Customers;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Inigo Montoya', 'Owner', 'Mataderos  2312', 'México D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', None, '68306', 'Germany', '0621-08460', '0621-08924'),
#  ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', 'Marketing Manager', '24, place Kléber', 'Strasbourg', None, '67000', 'France', '88.60.15.31', '88.60.15.32'),
#  ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', 'Owner', 'C/ Araquil, 67', 'Madrid', None, '28023', 'Spain', '(91) 555 22 82', '(91) 555 91 99'),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 'Owner', '12, rue des Bouchers', 'Marseille', None, '13008', 'France', '91.24.45.40', '91.24.45.41'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Accounting Manager', '23 Tsawassen Blvd.', 'Tsawassen', 'BC', 'T2F 8M4', 'Canada', '(604) 555-4729', '(604) 555-3745'),
#  ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None),
#  ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Sales Agent', 'Cerrito 333', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5555', '(1) 135-4892'),
#  ('CENTC', 'Centro comercial Moctezuma', 'Antonio Banderas', 'Marketing Manager', 'Sierras de Granada 9993', 'México D.F.', None, '05022', 'Mexico', '(5) 555-3392', '(5) 555-7293'),
#  ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Owner', 'Hauptstr. 29', 'Bern', None, '3012', 'Switzerland', '0452-076545', None),
#  ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', 'Sales Associate', 'Av. dos Lusíadas, 23', 'Sao Paulo', 'SP', '05432-043', 'Brazil', '(11) 555-7647', None),
#  ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199'),
#  ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Order Administrator', 'Walserweg 21', 'Aachen', None, '52066', 'Germany', '0241-039123', '0241-059428'),
#  ('DUMON', 'Du monde entier', 'Janine Labrune', 'Owner', '67, rue des Cinquante Otages', 'Nantes', None, '44000', 'France', '40.67.88.88', '40.67.89.89'),
#  ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'),
#  ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Sales Manager', 'Kirchgasse 6', 'Graz', None, '8010', 'Austria', '7675-3425', '7675-3426'),
#  ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Marketing Assistant', 'Rua Orós, 92', 'Sao Paulo', 'SP', '05442-030', 'Brazil', '(11) 555-9857', None),
#  ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'Accounting Manager', 'C/ Moralzarzal, 86', 'Madrid', None, '28034', 'Spain', '(91) 555 94 44', '(91) 555 55 93'),
#  ('FOLIG', 'Folies gourmandes', 'Martine Rancé', 'Assistant Sales Agent', '184, chaussée de Tournai', 'Lille', None, '59000', 'France', '20.16.10.16', '20.16.10.17'),
#  ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Owner', 'Åkergatan 24', 'Bräcke', None, 'S-844 67', 'Sweden', '0695-34 67 21', None),
#  ('FRANK', 'Frankenversand', 'Peter Franken', 'Marketing Manager', 'Berliner Platz 43', 'München', None, '80805', 'Germany', '089-0877310', '089-0877451'),
#  ('FRANR', 'France restauration', 'Carine Schmitt', 'Marketing Manager', '54, rue Royale', 'Nantes', None, '44000', 'France', '40.32.21.21', '40.32.21.20'),
#  ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Sales Representative', 'Via Monte Bianco 34', 'Torino', None, '10100', 'Italy', '011-4988260', '011-4988261'),
#  ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Sales Manager', 'Jardim das rosas n. 32', 'Lisboa', None, '1675', 'Portugal', '(1) 354-2534', '(1) 354-2535'),
#  ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Marketing Manager', 'Rambla de Cataluña, 23', 'Barcelona', None, '08022', 'Spain', '(93) 203 4560', '(93) 203 4561'),
#  ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'Sales Manager', 'C/ Romero, 33', 'Sevilla', None, '41101', 'Spain', '(95) 555 82 82', None),
#  ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Sales Associate', 'Av. Brasil, 442', 'Campinas', 'SP', '04876-786', 'Brazil', '(11) 555-9482', None),
#  ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 'Marketing Manager', '2732 Baker Blvd.', 'Eugene', 'OR', '97403', 'USA', '(503) 555-7555', None),
#  ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', 'Owner', '5ª Ave. Los Palos Grandes', 'Caracas', 'DF', '1081', 'Venezuela', '(2) 283-2951', '(2) 283-3397'),
#  ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Accounting Manager', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil', '(21) 555-0091', '(21) 555-8765'),
#  ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Sales Representative', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', 'Táchira', '5022', 'Venezuela', '(5) 555-1340', '(5) 555-1948'),
#  ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'Sales Representative', 'City Center Plaza 516 Main St.', 'Elgin', 'OR', '97827', 'USA', '(503) 555-6874', '(503) 555-2376'),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', 'Sales Associate', '8 Johnstown Road', 'Cork', 'Co. Cork', None, 'Ireland', '2967 542', '2967 3333'),
#  ('ISLAT', 'Island Trading', 'Helen Bennett', 'Marketing Manager', 'Garden House Crowther Way', 'Cowes', 'Isle of Wight', 'PO31 7PJ', 'UK', '(198) 555-8888', None),
#  ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Sales Associate', 'Maubelstr. 90', 'Brandenburg', None, '14776', 'Germany', '0555-09876', None),
#  ('LACOR', "La corne d'abondance", 'Daniel Tonini', 'Sales Representative', "67, avenue de l'Europe", 'Versailles', None, '78000', 'France', '30.59.84.10', '30.59.85.11'),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', 'Marketing Assistant', '1900 Oak St.', 'Vancouver', 'BC', 'V3F 2K1', 'Canada', '(604) 555-3392', '(604) 555-7293'),
#  ('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Marketing Manager', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'USA', '(509) 555-7969', '(509) 555-6221'),
#  ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Sales Representative', 'Magazinweg 7', 'Frankfurt a.M.', None, '60528', 'Germany', '069-0245984', '069-0245874'),
#  ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Owner', '87 Polk St. Suite 5', 'San Francisco', 'CA', '94117', 'USA', '(415) 555-5938', None),
#  ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Accounting Manager', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', 'Lara', '3508', 'Venezuela', '(9) 331-6954', '(9) 331-7256'),
#  ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Owner', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', 'Nueva Esparta', '4980', 'Venezuela', '(8) 34-56-12', '(8) 34-93-93'),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 'Sales Manager', '89 Chiaroscuro Rd.', 'Portland', 'OR', '97219', 'USA', '(503) 555-9573', '(503) 555-9646'),
#  ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Marketing Manager', 'Via Ludovico il Moro 22', 'Bergamo', None, '24100', 'Italy', '035-640230', '035-640231'),
#  ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Sales Agent', 'Rue Joseph-Bens 532', 'Bruxelles', None, 'B-1180', 'Belgium', '(02) 201 24 67', '(02) 201 24 68'),
#  ('MEREP', 'Mère Paillarde', 'Jean Fresnière', 'Marketing Assistant', '43 rue St. Laurent', 'Montréal', 'Québec', 'H1J 1C3', 'Canada', '(514) 555-8054', '(514) 555-8055'),
#  ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Marketing Assistant', 'Heerstr. 22', 'Leipzig', None, '04179', 'Germany', '0342-023176', None),
#  ('NORTS', 'North/South', 'Simon Crowther', 'Sales Associate', 'South House 300 Queensbridge', 'London', None, 'SW7 1RZ', 'UK', '(171) 555-7733', '(171) 555-2530'),
#  ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Sales Agent', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5333', '(1) 135-5535'),
#  ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', 'Sales Representative', '2743 Bering St.', 'Anchorage', 'AK', '99508', 'USA', '(907) 555-7584', '(907) 555-2880'),
#  ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Owner', 'Mehrheimerstr. 369', 'Köln', None, '50739', 'Germany', '0221-0644327', '0221-0765721'),
#  ('PARIS', 'Paris spécialités', 'Marie Bertrand', 'Owner', '265, boulevard Charonne', 'Paris', None, '75012', 'France', '(1) 42.34.22.66', '(1) 42.34.22.77'),
#  ('PERIC', 'Pericles Comidas clásicas', 'Salma Hayek', 'Sales Representative', 'Calle Dr. Jorge Cash 321', 'México D.F.', None, '05033', 'Mexico', '(5) 552-3745', '(5) 545-3745'),
#  ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Sales Manager', 'Geislweg 14', 'Salzburg', None, '5020', 'Austria', '6562-9722', '6562-9723'),
#  ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Sales Representative', 'Estrada da saúde n. 58', 'Lisboa', None, '1756', 'Portugal', '(1) 356-5634', None),
#  ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Accounting Manager', 'Rua da Panificadora, 12', 'Rio de Janeiro', 'RJ', '02389-673', 'Brazil', '(21) 555-4252', '(21) 555-4545'),
#  ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Marketing Assistant', 'Alameda dos Canàrios, 891', 'Sao Paulo', 'SP', '05487-020', 'Brazil', '(11) 555-1189', None),
#  ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Accounting Manager', 'Taucherstraße 10', 'Cunewalde', None, '01307', 'Germany', '0372-035188', None),
#  ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Sales Representative', 'Av. del Libertador 900', 'Buenos Aires', None, '1010', 'Argentina', '(1) 123-5555', '(1) 123-5556'),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', 'Assistant Sales Representative', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA', '(505) 555-5939', '(505) 555-3620'),
#  ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Sales Associate', 'Strada Provinciale 124', 'Reggio Emilia', None, '42100', 'Italy', '0522-556721', '0522-556722'),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Assistant Sales Agent', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brazil', '(21) 555-3412', None),
#  ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Sales Manager', 'Grenzacherweg 237', 'Genève', None, '1203', 'Switzerland', '0897-034214', None),
#  ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Accounting Manager', 'Gran Vía, 1', 'Madrid', None, '28001', 'Spain', '(91) 745 6200', '(91) 745 6210'),
#  ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Owner', 'Erling Skakkes gate 78', 'Stavern', None, '4110', 'Norway', '07-98 92 35', '07-98 92 47'),
#  ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Sales Representative', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', None),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Owner', 'Vinbæltet 34', 'Kobenhavn', None, '1734', 'Denmark', '31 12 34 56', '31 13 35 57'),
#  ('SPECD', 'Spécialités du monde', 'Dominique Perrier', 'Marketing Manager', '25, rue Lauriston', 'Paris', None, '75016', 'France', '(1) 47.55.60.10', '(1) 47.55.60.20'),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525'),
#  ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Accounting Manager', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium', '(071) 23 67 22 20', '(071) 23 67 22 21'),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Marketing Manager', '89 Jefferson Way Suite 2', 'Portland', 'OR', '97201', 'USA', '(503) 555-3612', None),
#  ('THECR', 'The Cracker Box', 'Liu Wong', 'Marketing Assistant', '55 Grizzly Peak Rd.', 'Butte', 'MT', '59801', 'USA', '(406) 555-5834', '(406) 555-8083'),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany', '0251-031259', '0251-035695'),
#  ('TORTU', 'Tortuga Restaurante', 'Hugo Sanchis', 'Owner', 'Avda. Azteca 123', 'México D.F.', None, '05033', 'Mexico', '(5) 555-2933', None),
#  ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Sales Representative', 'Av. Inês de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brazil', '(11) 555-2167', '(11) 555-2168'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Sales Associate', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'USA', '(206) 555-8257', '(206) 555-2174'),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Sales Manager', 'Smagsloget 45', 'Århus', None, '8200', 'Denmark', '86 21 32 43', '86 22 33 44'),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'Sales Agent', '2, rue du Commerce', 'Lyon', None, '69004', 'France', '78.32.54.86', '78.32.54.87'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11'),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Sales Representative', 'Adenauerallee 900', 'Stuttgart', None, '70563', 'Germany', '0711-020361', '0711-035428'),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Accounting Manager', 'Torikatu 38', 'Oulu', None, '90110', 'Finland', '981-443655', '981-443655'),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Sales Manager', 'Rua do Mercado, 12', 'Resende', 'SP', '08737-363', 'Brazil', '(14) 555-8122', None),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115'),
#  ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Owner/Marketing Assistant', 'Keskuskatu 45', 'Helsinki', None, '21240', 'Finland', '90-224 8858', '90-224 8858'),
#  ('WOLZA', 'Wolski Zajazd', 'Zbyszek Piestrzeniewicz', 'Owner', 'ul. Filtrowa 68', 'Warszawa', None, '01-012', 'Poland', '(26) 642-7012', '(26) 642-7012'),
#  ('CARTO', 'Cardinal', 'Tom B. Erichsen', 'Owner', 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('BARCAS', 'Barcelona CF', 'Lionel Messi', None, 'Camp Nou', 'Barcelona', None, '8028', 'Spain', None, None),
#  ('CART1', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4040', 'Norway', None, None),
#  ('CART2', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, 'Norway', None, None)]

# %%
# %sql SELECT salary  FROM Orders;
# Out:
#  * sqlite:///northwind.db
# (sqlite3.OperationalError) no such column: salary
# [SQL: SELECT salary FROM Orders;]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ## SQL SELECT DISTINCT Statement

# %% [markdown]
# ### The SELECT DISTINCT statement is used to return only distinct (different) values.
# ### Inside a table, a column often contains many duplicate values; and sometimes you only want to list the different (distinct) values.
# ### The SELECT DISTINCT statement is used to return only distinct (different) values.

# %%
# %sql SELECT DISTINCT Country,  FROM Customers

# %% [markdown]
# ### The following SQL statement lists the number of different (distinct) customer countries:

# %%
# %sql SELECT COUNT(DISTINCT Country) FROM Customers;
#nak kira ada berapa country
# Out:
#  * sqlite:///northwind.db
# Done.
# [(21,)]

# %%
# %sql SELECT COUNT(Country) FROM Customers ;
#ada berapa record yg kita adacountry duplicate
# Out:
#  * sqlite:///northwind.db
# Done.
# [(94,)]

# %% [markdown]
# ## SQL Where Clause

# %% [markdown]
# ### The WHERE clause is used to filter records. The WHERE clause is used to extract only those records that fulfill a specified condition.

# %% [markdown]
# #### The following SQL statement selects all the customer from the country "Mexico, in the "Customer" table:

# %%
# %%sql
# SELECT * FROM Customers
# WHERE Country='Mexico';
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Inigo Montoya', 'Owner', 'Mataderos  2312', 'México D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('CENTC', 'Centro comercial Moctezuma', 'Antonio Banderas', 'Marketing Manager', 'Sierras de Granada 9993', 'México D.F.', None, '05022', 'Mexico', '(5) 555-3392', '(5) 555-7293'),
#  ('PERIC', 'Pericles Comidas clásicas', 'Salma Hayek', 'Sales Representative', 'Calle Dr. Jorge Cash 321', 'México D.F.', None, '05033', 'Mexico', '(5) 552-3745', '(5) 545-3745'),
#  ('TORTU', 'Tortuga Restaurante', 'Hugo Sanchis', 'Owner', 'Avda. Azteca 123', 'México D.F.', None, '05033', 'Mexico', '(5) 555-2933', None)]

# %%
# %%sql
# SELECT count(*) FROM Customers;
# Out:
#  * sqlite:///northwind.db
# Done.
# [(94,)]

# %%
# %%sql
# SELECT count(*) FROM Customers
# WHERE Country='Mexico';
# Out:
#  * sqlite:///northwind.db
# Done.
# [(5,)]

# %% [markdown]
# ## Text Fields vs. Numeric Fields

# %% [markdown]
# ### SQL requires single quotes around text values (most database systems will also allow double quotes). However, numeric fields should not be enclosed in quotes:

# %%
# %%sql
# SELECT * FROM Employees
# WHERE EmployeeID = 1;
# Out:
#  * sqlite:///northwind.db
# Done.
# [(1, 'Davolio', 'Nancy', 'Sales Representative', 'Ms.', '1948-12-08 00:00:00', '1992-05-01 00:00:00', '507 - 20th Ave. E.\r\nApt. 2A', 'Seattle', 'WA', '98122', 'USA', '(206) 555-9857', '5467', b'\x15\x1c/\x00\x02\x00\x00\x00\r\x00\x0e\x00\x14\x00!\x00\xff\xff\xff\xffBitmap Image\x00Paint.Picture\x00\x01\x05\x00\x00\x02\x00\x00\x00\x07\x00\x0 ... (80909 characters truncated) ... 0\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x05\x00\x00\x00\x00\x00\x00\xb4\xad\x05\xfe', 'Education includes a BA in psychology from Colorado State University in 1970.  She also completed "The Art of the Cold Call."  Nancy is a member of Toastmasters International.', 'http://accweb/emmployees/davolio.bmp')]

# %% [markdown]
# ## Operators in the WHERE clause

# %% [markdown]
# ### The following operators can be used in the WHERE clause:

# %% [markdown]
# |Operator | Description |
# | :- | :-: |
# | =  | Equal|
# | <> | Not equal |
# | >  | Greater than|
# | <  | Less than |
# | >= | Greater than or Equal|
# | <= |	Less than or Equal |
# |BETWEEN |	Between an inclusive range|
# |LIKE	| Search for a pattern|
# | IN	| To specify multiple possible values for a column|

# %% [markdown]
# ## SQL AND, OR and NOT Operators

# %% [markdown]
# ### The WHERE clause can be combined with logical (AND, OR, and NOT) operators

# %% [markdown]
# |AND Operator |
# |:-|
# | A | B | A and B |
# | False  | False | FALSE |
# | False | True |FALSE|
# | True  | False|FALSE|
# | True  | True |TRUE|

# %% [markdown]
# |OR Operator |
# |:-|
# | A | B | A or B |
# | False  | False | FALSE |
# | False | True |TRUE|
# | True  | False|TRUE|
# | True  | True |TRUE|

# %% [markdown]
# ## AND Example
# #### The following SQL statement selects all fields from "Customers" where country is "USA" AND Region is "WA":

# %%
# %%sql
# SELECT * FROM Customers
# WHERE Country = 'USA' AND Region = 'WA';
# Out:
#  * sqlite:///northwind.db
# Done.
# [('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Marketing Manager', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'USA', '(509) 555-7969', '(509) 555-6221'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Sales Associate', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'USA', '(206) 555-8257', '(206) 555-2174'),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115')]

# %% [markdown]
# ## OR Example
# ### The following SQL statement selects all fields from "Customers" where country is "France" OR "Germany":

# %%
# %%sql
# SELECT CustomerID,CompanyName,ContactName,Country FROM Customers
# WHERE Country='France' OR Country='Germany';
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Germany'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Germany'),
#  ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', 'France'),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 'France'),
#  ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Germany'),
#  ('DUMON', 'Du monde entier', 'Janine Labrune', 'France'),
#  ('FOLIG', 'Folies gourmandes', 'Martine Rancé', 'France'),
#  ('FRANK', 'Frankenversand', 'Peter Franken', 'Germany'),
#  ('FRANR', 'France restauration', 'Carine Schmitt', 'France'),
#  ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Germany'),
#  ('LACOR', "La corne d'abondance", 'Daniel Tonini', 'France'),
#  ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Germany'),
#  ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Germany'),
#  ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Germany'),
#  ('PARIS', 'Paris spécialités', 'Marie Bertrand', 'France'),
#  ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Germany'),
#  ('SPECD', 'Spécialités du monde', 'Dominique Perrier', 'France'),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Germany'),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'France'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'France'),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Germany')]

# %% [markdown]
# ## NOT Example
# #### The following SQL statement selects all fields from "Customers"where country is NOT "USA":

# %%
# %%sql
# SELECT * FROM Customers
# WHERE NOT Country='USA';
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Inigo Montoya', 'Owner', 'Mataderos  2312', 'México D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', None, '68306', 'Germany', '0621-08460', '0621-08924'),
#  ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', 'Marketing Manager', '24, place Kléber', 'Strasbourg', None, '67000', 'France', '88.60.15.31', '88.60.15.32'),
#  ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', 'Owner', 'C/ Araquil, 67', 'Madrid', None, '28023', 'Spain', '(91) 555 22 82', '(91) 555 91 99'),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 'Owner', '12, rue des Bouchers', 'Marseille', None, '13008', 'France', '91.24.45.40', '91.24.45.41'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Accounting Manager', '23 Tsawassen Blvd.', 'Tsawassen', 'BC', 'T2F 8M4', 'Canada', '(604) 555-4729', '(604) 555-3745'),
#  ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None),
#  ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Sales Agent', 'Cerrito 333', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5555', '(1) 135-4892'),
#  ('CENTC', 'Centro comercial Moctezuma', 'Antonio Banderas', 'Marketing Manager', 'Sierras de Granada 9993', 'México D.F.', None, '05022', 'Mexico', '(5) 555-3392', '(5) 555-7293'),
#  ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Owner', 'Hauptstr. 29', 'Bern', None, '3012', 'Switzerland', '0452-076545', None),
#  ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', 'Sales Associate', 'Av. dos Lusíadas, 23', 'Sao Paulo', 'SP', '05432-043', 'Brazil', '(11) 555-7647', None),
#  ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199'),
#  ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Order Administrator', 'Walserweg 21', 'Aachen', None, '52066', 'Germany', '0241-039123', '0241-059428'),
#  ('DUMON', 'Du monde entier', 'Janine Labrune', 'Owner', '67, rue des Cinquante Otages', 'Nantes', None, '44000', 'France', '40.67.88.88', '40.67.89.89'),
#  ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'),
#  ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Sales Manager', 'Kirchgasse 6', 'Graz', None, '8010', 'Austria', '7675-3425', '7675-3426'),
#  ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Marketing Assistant', 'Rua Orós, 92', 'Sao Paulo', 'SP', '05442-030', 'Brazil', '(11) 555-9857', None),
#  ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'Accounting Manager', 'C/ Moralzarzal, 86', 'Madrid', None, '28034', 'Spain', '(91) 555 94 44', '(91) 555 55 93'),
#  ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Marketing Assistant', 'Alameda dos Canàrios, 891', 'Sao Paulo', 'SP', '05487-020', 'Brazil', '(11) 555-1189', None),
#  ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Accounting Manager', 'Taucherstraße 10', 'Cunewalde', None, '01307', 'Germany', '0372-035188', None),
#  ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Sales Representative', 'Av. del Libertador 900', 'Buenos Aires', None, '1010', 'Argentina', '(1) 123-5555', '(1) 123-5556'),
#  ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Sales Associate', 'Strada Provinciale 124', 'Reggio Emilia', None, '42100', 'Italy', '0522-556721', '0522-556722'),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Assistant Sales Agent', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brazil', '(21) 555-3412', None),
#  ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Sales Manager', 'Grenzacherweg 237', 'Genève', None, '1203', 'Switzerland', '0897-034214', None),
#  ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Accounting Manager', 'Gran Vía, 1', 'Madrid', None, '28001', 'Spain', '(91) 745 6200', '(91) 745 6210'),
#  ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Owner', 'Erling Skakkes gate 78', 'Stavern', None, '4110', 'Norway', '07-98 92 35', '07-98 92 47'),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Owner', 'Vinbæltet 34', 'Kobenhavn', None, '1734', 'Denmark', '31 12 34 56', '31 13 35 57'),
#  ('SPECD', 'Spécialités du monde', 'Dominique Perrier', 'Marketing Manager', '25, rue Lauriston', 'Paris', None, '75016', 'France', '(1) 47.55.60.10', '(1) 47.55.60.20'),
#  ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Accounting Manager', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium', '(071) 23 67 22 20', '(071) 23 67 22 21'),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany', '0251-031259', '0251-035695'),
#  ('TORTU', 'Tortuga Restaurante', 'Hugo Sanchis', 'Owner', 'Avda. Azteca 123', 'México D.F.', None, '05033', 'Mexico', '(5) 555-2933', None),
#  ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Sales Representative', 'Av. Inês de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brazil', '(11) 555-2167', '(11) 555-2168'),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Sales Manager', 'Smagsloget 45', 'Århus', None, '8200', 'Denmark', '86 21 32 43', '86 22 33 44'),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'Sales Agent', '2, rue du Commerce', 'Lyon', None, '69004', 'France', '78.32.54.86', '78.32.54.87'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11'),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Sales Representative', 'Adenauerallee 900', 'Stuttgart', None, '70563', 'Germany', '0711-020361', '0711-035428'),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Accounting Manager', 'Torikatu 38', 'Oulu', None, '90110', 'Finland', '981-443655', '981-443655'),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Sales Manager', 'Rua do Mercado, 12', 'Resende', 'SP', '08737-363', 'Brazil', '(14) 555-8122', None),
#  ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Owner/Marketing Assistant', 'Keskuskatu 45', 'Helsinki', None, '21240', 'Finland', '90-224 8858', '90-224 8858'),
#  ('WOLZA', 'Wolski Zajazd', 'Zbyszek Piestrzeniewicz', 'Owner', 'ul. Filtrowa 68', 'Warszawa', None, '01-012', 'Poland', '(26) 642-7012', '(26) 642-7012'),
#  ('CARTO', 'Cardinal', 'Tom B. Erichsen', 'Owner', 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('BARCAS', 'Barcelona CF', 'Lionel Messi', None, 'Camp Nou', 'Barcelona', None, '8028', 'Spain', None, None),
#  ('CART1', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4040', 'Norway', None, None),
#  ('CART2', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, 'Norway', None, None)]

# %% [markdown]
# ## Combining AND, OR and NOT
# #### The following SQL statement selects all fields from "Customers" where country is "USA" AND city must be "Portland" OR "Seattle" (use parenthesis to form complex expressions):

# %%
# %%sql
# SELECT * FROM Customers
# WHERE Country='USA' AND (City='Portland' OR City='Seattle');
# Out:
#  * sqlite:///northwind.db
# Done.
# [('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 'Sales Manager', '89 Chiaroscuro Rd.', 'Portland', 'OR', '97219', 'USA', '(503) 555-9573', '(503) 555-9646'),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Marketing Manager', '89 Jefferson Way Suite 2', 'Portland', 'OR', '97201', 'USA', '(503) 555-3612', None),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115')]

# %% [markdown]
# ### Exercise 1
# #### Write a SQL query that selects all fields from "Customers" where the country is NOT "Germany" and NOT "France":

# %%
# %%sql
# SELECT * FROM Customers
# WHERE NOT Country='USA' AND NOT Country='France'
# # WHERE NOT (Country = 'Germany') AND NOT (Country = 'France')
# # where   Country <>'Germany' and Country <> 'France';
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Inigo Montoya', 'Owner', 'Mataderos  2312', 'México D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', None, '68306', 'Germany', '0621-08460', '0621-08924'),
#  ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', 'Owner', 'C/ Araquil, 67', 'Madrid', None, '28023', 'Spain', '(91) 555 22 82', '(91) 555 91 99'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Accounting Manager', '23 Tsawassen Blvd.', 'Tsawassen', 'BC', 'T2F 8M4', 'Canada', '(604) 555-4729', '(604) 555-3745'),
#  ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None),
#  ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Sales Agent', 'Cerrito 333', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5555', '(1) 135-4892'),
#  ('CENTC', 'Centro comercial Moctezuma', 'Antonio Banderas', 'Marketing Manager', 'Sierras de Granada 9993', 'México D.F.', None, '05022', 'Mexico', '(5) 555-3392', '(5) 555-7293'),
#  ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Owner', 'Hauptstr. 29', 'Bern', None, '3012', 'Switzerland', '0452-076545', None),
#  ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', 'Sales Associate', 'Av. dos Lusíadas, 23', 'Sao Paulo', 'SP', '05432-043', 'Brazil', '(11) 555-7647', None),
#  ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199'),
#  ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Order Administrator', 'Walserweg 21', 'Aachen', None, '52066', 'Germany', '0241-039123', '0241-059428'),
#  ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'),
#  ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Sales Manager', 'Kirchgasse 6', 'Graz', None, '8010', 'Aust
#  ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Sales Representative', 'Av. del Libertador 900', 'Buenos Aires', None, '1010', 'Argentina', '(1) 123-5555', '(1) 123-5556'),
#  ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Sales Associate', 'Strada Provinciale 124', 'Reggio Emilia', None, '42100', 'Italy', '0522-556721', '0522-556722'),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Assistant Sales Agent', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brazil', '(21) 555-3412', None),
#  ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Sales Manager', 'Grenzacherweg 237', 'Genève', None, '1203', 'Switzerland', '0897-034214', None),
#  ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Accounting Manager', 'Gran Vía, 1', 'Madrid', None, '28001', 'Spain', '(91) 745 6200', '(91) 745 6210'),
#  ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Owner', 'Erling Skakkes gate 78', 'Stavern', None, '4110', 'Norway', '07-98 92 35', '07-98 92 47'),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Owner', 'Vinbæltet 34', 'Kobenhavn', None, '1734', 'Denmark', '31 12 34 56', '31 13 35 57'),
#  ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Accounting Manager', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium', '(071) 23 67 22 20', '(071) 23 67 22 21'),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany', '0251-031259', '0251-035695'),
#  ('TORTU', 'Tortuga Restaurante', 'Hugo Sanchis', 'Owner', 'Avda. Azteca 123', 'México D.F.', None, '05033', 'Mexico', '(5) 555-2933', None),
#  ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Sales Representative', 'Av. Inês de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brazil', '(11) 555-2167', '(11) 555-2168'),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Sales Manager', 'Smagsloget 45', 'Århus', None, '8200', 'Denmark', '86 21 32 43', '86 22 33 44'),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Sales Representative', 'Adenauerallee 900', 'Stuttgart', None, '70563', 'Germany', '0711-020361', '0711-035428'),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Accounting Manager', 'Torikatu 38', 'Oulu', None, '90110', 'Finland', '981-443655', '981-443655'),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Sales Manager', 'Rua do Mercado, 12', 'Resende', 'SP', '08737-363', 'Brazil', '(14) 555-8122', None),
#  ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Owner/Marketing Assistant', 'Keskuskatu 45', 'Helsinki', None, '21240', 'Finland', '90-224 8858', '90-224 8858'),
#  ('WOLZA', 'Wolski Zajazd', 'Zbyszek Piestrzeniewicz', 'Owner', 'ul. Filtrowa 68', 'Warszawa', None, '01-012', 'Poland', '(26) 642-7012', '(26) 642-7012'),
#  ('CARTO', 'Cardinal', 'Tom B. Erichsen', 'Owner', 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('BARCAS', 'Barcelona CF', 'Lionel Messi', None, 'Camp Nou', 'Barcelona', None, '8028', 'Spain', None, None),
#  ('CART1', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4040', 'Norway', None, None),
#  ('CART2', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, 'Norway', None, None)]

# %% [markdown]
# ## ORDER BY

# %% [markdown]
# The <b>ORDER BY</b> keyword is used to sort the result-set in <i>ascending</i> or <i>descending</i> order.
# The ORDER BY keyword sorts the records in ascending order by default.
# To sort the records in descending order, use the <b>DESC</b> keyword.

# %% [markdown]
# <code>SELECT column1, column2, ...
# FROM table_name
# ORDER BY column1, column2, ... ASC|DESC;</code>

# %% [markdown]
# #### The following SQL statement selects all customers from the "Customers" table, sorted by the "Country" column:

# %%
# %%sql
# SELECT CompanyName, Country FROM Customers
# ORDER BY Country;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('Cactus Comidas para llevar', 'Argentina'),
#  ('Océano Atlántico Ltda.', 'Argentina'),
#  ('Rancho grande', 'Argentina'),
#  ('Ernst Handel', 'Austria'),
#  ('Piccolo und mehr', 'Austria'),
#  ('Maison Dewey', 'Belgium'),
#  ('Suprêmes délices', 'Belgium'),
#  ('Comércio Mineiro', 'Brazil'),
#  ('Familia Arquibaldo', 'Brazil'),
#  ('Gourmet Lanchonetes', 'Brazil'),
#  ('Hanari Carnes', 'Brazil'),
#  ('Que Delícia', 'Brazil'),
#  ('Queen Cozinha', 'Brazil'),
#  ('Ricardo Adocicados', 'Brazil'),
#  ('Tradição Hipermercados', 'Brazil'),
#  ('Wellington Importadora', 'Brazil'),
#  ('Bottom-Dollar Markets', 'Canada'),
#  ('Laughing Bacchus Wine Cellars', 'Canada'),
#  ('Mère Paillarde', 'Canada'),
#  ('Simons bistro', 'Denmark'),
#  ('Vaffeljernet', 'Denmark'),
#  ('Wartian Herkku', 'Finland'),
#  ('Wilman Kala', 'Finland'),
#  ('Blondesddsl père et fils', 'France'),
#  ("Bon app'", 'France'),
#  ('Du monde entier', 'France'),
#  ('Folies gourmandes', 'France'),
#  ('France restauration', 'France'),
#  ("La corne d'abondance", 'France'),
#  ('Paris spécialités', 'France'),
#  ('Spécialités du monde', 'France'),
#  ('Victuailles en stock', 'France'),
#  ('Vins et alcools Chevalier', 'France'),
#  ('Alfreds Futterkiste', 'Germany'),
#  ('Blauer See Delikatessen', 'Germany'),
#  ('Drachenblut Delikatessen', 'Germany'),
#  ('Frankenversand', 'Germany'),
#  ('Königlich Essen', 'Germany'),
#  ('Lehmanns Marktstand', 'Germany'),
#  ('Morgenstern Gesundkost', 'Germany'),
#  ('Ottilies Käseladen', 'Germany'),
#  ('QUICK-Stop', 'Germany'),
#  ('Toms Spezialitäten', 'Germany'),
#  ('Die Wandernde Kuh', 'Germany'),
#  ('Hungry Owl All-Night Grocers', 'Ireland'),
#  ('Franchi S.p.A.', 'Italy'),
#  ('Magazzini Alimentari Riuniti', 'Italy'),
#  ('Reggiani Caseifici', 'Italy'),
#  ('Ana Trujillo Emparedados y helados', 'Mexico'),
#  ('Antonio Moreno Taquería', 'Mexico'),
#  ('Centro comercial Moctezuma', 'Mexico'),
#  ('Pericles Comidas clásicas', 'Mexico'),
#  ('Tortuga Restaurante', 'Mexico'),
#  ('Santé Gourmet', 'Norway'),
#  ('Cardinal', 'Norway'),
#  ('Cardinal', 'Norway'),
#  ('Cardinal', 'Norway'),
#  ('Wolski Zajazd', 'Poland'),
#  ('Furia Bacalhau e Frutos do Mar', 'Portugal'),
#  ('Princesa Isabel Vinhos', 'Portugal'),
#  ('Bólido Comidas preparadas', 'Spain'),
#  ('FISSA Fabrica Inter. Salchichas S.A.', 'Spain'),
#  ('Galería del gastrónomo', 'Spain'),
#  ('Godos Cocina Típica', 'Spain'),
#  ('Romero y tomillo', 'Spain'),
#  ('Barcelona CF', 'Spain'),
#  ('Berglunds snabbköp', 'Sweden'),
#  ('Folk och fä HB', 'Sweden'),
#  ('Chop-suey Chinese', 'Switzerland'),
#  ('Richter Supermarkt', 'Switzerland'),
#  ('Around the Horn', 'UK'),
#  ("B's Beverages", 'UK'),
#  ('Consolidated Holdings', 'UK'),
#  ('Eastern Connection', 'UK'),
#  ('Island Trading', 'UK'),
#  ('North/South', 'UK'),
#  ('Seven Seas Imports', 'UK'),
#  ('Great Lakes Food Market', 'USA'),
#  ('Hungry Coyote Import Store', 'USA'),
#  ('Lazy K Kountry Store', 'USA'),
#  ("Let's Stop N Shop", 'USA'),
#  ('Lonesome Pine Restaurant', 'USA'),
#  ('Old World Delicatessen', 'USA'),
#  ('Rattlesnake Canyon Grocery', 'USA'),
#  ('Save-a-lot Markets', 'USA'),
#  ('Split Rail Beer & Ale', 'USA'),
#  ('The Big Cheese', 'USA'),
#  ('The Cracker Box', 'USA'),
#  ("Trail's Head Gourmet Provisioners", 'USA'),
#  ('White Clover Markets', 'USA'),
#  ('GROSELLA-Restaurante', 'Venezuela'),
#  ('HILARION-Abastos', 'Venezuela'),
#  ('LILA-Supermercado', 'Venezuela'),
#  ('LINO-Delicateses', 'Venezuela')]

# %% [markdown]
# ### Exercise 2
# #### Write a SQL statement selects all customers from the "Customers" table, sorted DESCENDING by the "Country" column:

# %%
# %%sql
# SELECT * FROM Customers
# ORDER BY Country DESC;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', 'Owner', '5ª Ave. Los Palos Grandes', 'Caracas', 'DF', '1081', 'Venezuela', '(2) 283-2951', '(2) 283-3397'),
#  ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Sales Representative', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', 'Táchira', '5022', 'Venezuela', '(5) 555-1340', '(5) 555-1948'),
#  ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Accounting Manager', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', 'Lara', '3508', 'Venezuela', '(9) 331-6954', '(9) 331-7256'),
#  ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Owner', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', 'Nueva Esparta', '4980', 'Venezuela', '(8) 34-56-12', '(8) 34-93-93'),
#  ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 'Marketing Manager', '2732 Baker Blvd.', 'Eugene', 'OR', '97403', 'USA', '(503) 555-7555', None),
#  ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'Sales Representative', 'City Center Plaza 516 Main St.', 'Elgin', 'OR', '97827', 'USA', '(503) 555-6874', '(503) 555-2376'),
#  ('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Marketing Manager', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'USA', '(509) 555-7969', '(509) 555-6221'),
#  ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Owner', '87 Polk St. Suite 5', 'San Francisco', 'CA', '94117', 'USA', '(415) 555-5938', None),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 'Sales Manager', '89 Chiaroscuro Rd.', 'Portland', 'OR', '97219', 'USA', '(503) 555-9573', '(503) 555-9646'),
#  ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', 'Sales Representative', '2743 Bering St.', 'Anchorage', 'AK', '99508', 'USA', '(907) 555-7584', '(907) 555-2880'),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', 'Assistant Sales Representative', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA', '(505) 555-5939', '(505) 555-3620'),
#  ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Sales Representative', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', None),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525'),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Marketing Manager', '89 Jefferson Way Suite 2', 'Portland', 'OR', '97201', 'USA', '(503) 555-3612', None),
#  ('THECR', 'The Cracker Box', 'Liu Wong', 'Marketing Assistant', '55 Grizzly Peak Rd.', 'Butte', 'MT', '59801', 'USA', '(406) 555-5834', '(406) 555-8083'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Sales Associate', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'USA', '(206) 555-8257', '(206) 555-2174'),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115'),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None),
#  ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199'),
#  ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'),
#  ('ISLAT', 'Island Trading', 'Helen Bennett', 'Marketing Manager', 'Garden House Crowther Way', 'Cowes', 'Isle of Wight', 'PO31 7PJ', 'UK', '(198) 555-8888', None),
#  ('NORTS', 'North/South', 'Simon Crowther', 'Sales Associate', 'South House 300 Queensbridge', 'London', None, 'SW7 1RZ', 'UK', '(171) 555-7733', '(171) 555-2530'),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'),
#  ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Owner', 'Hauptstr. 29', 'Bern', None, '3012', 'Switzerland', '0452-076545', None),
#  ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Sales Manager', 'Grenzacherweg 237', 'Genève', None, '1203', 'Switzerland', '0897-034214', None),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67'),
#  ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Owner', 'Åkergatan 24', 'Bräcke', None, 'S-844 67', 'Sweden', '0695-34 67 21', None),
#  ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', 'Owner', 'C/ Araquil, 67', 'Madrid', None, '28023', 'Spain', '(91) 555 22 82', '(91) 555 91 99'),
#  ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'Accounting Manager', 'C/ Moralzarzal, 86', 'Madrid', None, '28034', 'Spain', '(91) 555 94 44', '(91) 555 55 93'),
#  ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Marketing Manager', 'Rambla de Cataluña, 23', 'Barcelona', None, '08022', 'Spain', '(93) 203 4560', '(93) 203 4561'),
#  ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'Sales Manager', 'C/ Romero, 33', 'Sevilla', None, '41101', 'Spain', '(95) 555 82 82', None),
#  ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Accounting Manager', 'Gran Vía, 1', 'Madrid', None, '28001', 'Spain', '(91) 745 6200', '(91) 745 6210'),
#  ('BARCAS', 'Barcelona CF', 'Lionel Messi', None, 'Camp Nou', 'Barcelona', None, '8028', 'Spain', None, None),
#  ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Sales Manager', 'Jardim das rosas n. 32', 'Lisboa', None, '1675', 'Portugal', '(1) 354-2534', '(1) 354-2535'),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'Sales Agent', '2, rue du Commerce', 'Lyon', None, '69004', 'France', '78.32.54.86', '78.32.54.87'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11'),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Accounting Manager', 'Torikatu 38', 'Oulu', None, '90110', 'Finland', '981-443655', '981-443655'),
#  ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Owner/Marketing Assistant', 'Keskuskatu 45', 'Helsinki', None, '21240', 'Finland', '90-224 8858', '90-224 8858'),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Owner', 'Vinbæltet 34', 'Kobenhavn', None, '1734', 'Denmark', '31 12 34 56', '31 13 35 57'),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Sales Manager', 'Smagsloget 45', 'Århus', None, '8200', 'Denmark', '86 21 32 43', '86 22 33 44'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Accounting Manager', '23 Tsawassen Blvd.', 'Tsawassen', 'BC', 'T2F 8M4', 'Canada', '(604) 555-4729', '(604) 555-3745'),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', 'Marketing Assistant', '1900 Oak St.', 'Vancouver', 'BC', 'V3F 2K1', 'Canada', '(604) 555-3392', '(604) 555-7293'),
#  ('MEREP', 'Mère Paillarde', 'Jean Fresnière', 'Marketing Assistant', '43 rue St. Laurent', 'Montréal', 'Québec', 'H1J 1C3', 'Canada', '(514) 555-8054', '(514) 555-8055'),
#  ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', 'Sales Associate', 'Av. dos Lusíadas, 23', 'Sao Paulo', 'SP', '05432-043', 'Brazil', '(11) 555-7647', None),
#  ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Marketing Assistant', 'Rua Orós, 92', 'Sao Paulo', 'SP', '05442-030', 'Brazil', '(11) 555-9857', None),
#  ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Sales Associate', 'Av. Brasil, 442', 'Campinas', 'SP', '04876-786', 'Brazil', '(11) 555-9482', None),
#  ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Accounting Manager', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil', '(21) 555-0091', '(21) 555-8765'),
#  ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Accounting Manager', 'Rua da Panificadora, 12', 'Rio de Janeiro', 'RJ', '02389-673', 'Brazil', '(21) 555-4252', '(21) 555-4545'),
#  ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Marketing Assistant', 'Alameda dos Canàrios, 891', 'Sao Paulo', 'SP', '05487-020', 'Brazil', '(11) 555-1189', None),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Assistant Sales Agent', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brazil', '(21) 555-3412', None),
#  ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Sales Representative', 'Av. Inês de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brazil', '(11) 555-2167', '(11) 555-2168'),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Sales Manager', 'Rua do Mercado, 12', 'Resende', 'SP', '08737-363', 'Brazil', '(14) 555-8122', None),
#  ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Sales Agent', 'Rue Joseph-Bens 532', 'Bruxelles', None, 'B-1180', 'Belgium', '(02) 201 24 67', '(02) 201 24 68'),
#  ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Accounting Manager', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium', '(071) 23 67 22 20', '(071) 23 67 22 21'),
#  ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Sales Manager', 'Kirchgasse 6', 'Graz', None, '8010', 'Austria', '7675-3425', '7675-3426'),
#  ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Sales Manager', 'Geislweg 14', 'Salzburg', None, '5020', 'Austria', '6562-9722', '6562-9723'),
#  ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Sales Agent', 'Cerrito 333', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5555', '(1) 135-4892'),
#  ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Sales Agent', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5333', '(1) 135-5535'),
#  ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Sales Representative', 'Av. del Libertador 900', 'Buenos Aires', None, '1010', 'Argentina', '(1) 123-5555', '(1) 123-5556')]

# %% [markdown]
# ## ORDER BY Several Columns Example
# #### The following SQL statement selects all customers from the "Customers" table, sorted by the "Country" and the "CompanyName" column:

# %%
# %%sql
# SELECT CompanyName,ContactName,Country FROM Customers
# ORDER BY Country, CompanyName;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('Cactus Comidas para llevar', 'Patricio Simpson', 'Argentina'),
#  ('Océano Atlántico Ltda.', 'Yvonne Moncada', 'Argentina'),
#  ('Rancho grande', 'Sergio Gutiérrez', 'Argentina'),
#  ('Ernst Handel', 'Roland Mendel', 'Austria'),
#  ('Piccolo und mehr', 'Georg Pipps', 'Austria'),
#  ('Maison Dewey', 'Catherine Dewey', 'Belgium'),
#  ('Suprêmes délices', 'Pascale Cartrain', 'Belgium'),
#  ('Comércio Mineiro', 'Pedro Afonso', 'Brazil'),
#  ('Familia Arquibaldo', 'Aria Cruz', 'Brazil'),
#  ('Gourmet Lanchonetes', 'André Fonseca', 'Brazil'),
#  ('Hanari Carnes', 'Mario Pontes', 'Brazil'),
#  ('Que Delícia', 'Bernardo Batista', 'Brazil'),
#  ('Queen Cozinha', 'Lúcia Carvalho', 'Brazil'),
#  ('Ricardo Adocicados', 'Janete Limeira', 'Brazil'),
#  ('Tradição Hipermercados', 'Anabela Domingues', 'Brazil'),
#  ('Wellington Importadora', 'Paula Parente', 'Brazil'),
#  ('Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Canada'),
#  ('Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', 'Canada'),
#  ('Mère Paillarde', 'Jean Fresnière', 'Canada'),
#  ('Simons bistro', 'Jytte Petersen', 'Denmark'),
#  ('Vaffeljernet', 'Palle Ibsen', 'Denmark'),
#  ('Wartian Herkku', 'Pirkko Koskitalo', 'Finland'),
#  ('Wilman Kala', 'Matti Karttunen', 'Finland'),
#  ('Blondesddsl père et fils', 'Frédérique Citeaux', 'France'),
#  ("Bon app'", 'Laurence Lebihan', 'France'),
#  ('Du monde entier', 'Janine Labrune', 'France'),
#  ('Folies gourmandes', 'Martine Rancé', 'France'),
#  ('France restauration', 'Carine Schmitt', 'France'),
#  ("La corne d'abondance", 'Daniel Tonini', 'France'),
#  ('Paris spécialités', 'Marie Bertrand', 'France'),
#  ('Spécialités du monde', 'Dominique Perrier', 'France'),
#  ('Victuailles en stock', 'Mary Saveley', 'France'),
#  ('Vins et alcools Chevalier', 'Paul Henriot', 'France'),
#  ('Alfreds Futterkiste', 'Maria Anders', 'Germany'),
#  ('Blauer See Delikatessen', 'Hanna Moos', 'Germany'),
#  ('Die Wandernde Kuh', 'Rita Müller', 'Germany'),
#  ('Drachenblut Delikatessen', 'Sven Ottlieb', 'Germany'),
#  ('Frankenversand', 'Peter Franken', 'Germany'),
#  ('Königlich Essen', 'Philip Cramer', 'Germany'),
#  ('Lehmanns Marktstand', 'Renate Messner', 'Germany'),
#  ('Morgenstern Gesundkost', 'Alexander Feuer', 'Germany'),
#  ('Ottilies Käseladen', 'Henriette Pfalzheim', 'Germany'),
#  ('QUICK-Stop', 'Horst Kloss', 'Germany'),
#  ('Toms Spezialitäten', 'Karin Josephs', 'Germany'),
#  ('Hungry Owl All-Night Grocers', 'Patricia McKenna', 'Ireland'),
#  ('Franchi S.p.A.', 'Paolo Accorti', 'Italy'),
#  ('Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Italy'),
#  ('Reggiani Caseifici', 'Maurizio Moroni', 'Italy'),
#  ('Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Mexico'),
#  ('Antonio Moreno Taquería', 'Inigo Montoya', 'Mexico'),
#  ('Centro comercial Moctezuma', 'Antonio Banderas', 'Mexico'),
#  ('Pericles Comidas clásicas', 'Salma Hayek', 'Mexico'),
#  ('Tortuga Restaurante', 'Hugo Sanchis', 'Mexico'),
#  ('Cardinal', 'Tom B. Erichsen', 'Norway'),
#  ('Cardinal', 'Tom B. Erichsen', 'Norway'),
#  ('Cardinal', 'Tom B. Erichsen', 'Norway'),
#  ('Santé Gourmet', 'Jonas Bergulfsen', 'Norway'),
#  ('Wolski Zajazd', 'Zbyszek Piestrzeniewicz', 'Poland'),
#  ('Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Portugal'),
#  ('Princesa Isabel Vinhos', 'Isabel de Castro', 'Portugal'),
#  ('Barcelona CF', 'Lionel Messi', 'Spain'),
#  ('Bólido Comidas preparadas', 'Martín Sommer', 'Spain'),
#  ('FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'Spain'),
#  ('Galería del gastrónomo', 'Eduardo Saavedra', 'Spain'),
#  ('Godos Cocina Típica', 'José Pedro Freyre', 'Spain'),
#  ('Romero y tomillo', 'Alejandra Camino', 'Spain'),
#  ('Berglunds snabbköp', 'Christina Berglund', 'Sweden'),
#  ('Folk och fä HB', 'Maria Larsson', 'Sweden'),
#  ('Chop-suey Chinese', 'Yang Wang', 'Switzerland'),
#  ('Richter Supermarkt', 'Michael Holz', 'Switzerland'),
#  ('Around the Horn', 'Thomas Hardy', 'UK'),
#  ("B's Beverages", 'Victoria Ashworth', 'UK'),
#  ('Consolidated Holdings', 'Elizabeth Brown', 'UK'),
#  ('Eastern Connection', 'Ann Devon', 'UK'),
#  ('Island Trading', 'Helen Bennett', 'UK'),
#  ('North/South', 'Simon Crowther', 'UK'),
#  ('Seven Seas Imports', 'Hari Kumar', 'UK'),
#  ('Great Lakes Food Market', 'Howard Snyder', 'USA'),
#  ('Hungry Coyote Import Store', 'Yoshi Latimer', 'USA'),
#  ('Lazy K Kountry Store', 'John Steel', 'USA'),
#  ("Let's Stop N Shop", 'Jaime Yorres', 'USA'),
#  ('Lonesome Pine Restaurant', 'Fran Wilson', 'USA'),
#  ('Old World Delicatessen', 'Rene Phillips', 'USA'),
#  ('Rattlesnake Canyon Grocery', 'Paula Wilson', 'USA'),
#  ('Save-a-lot Markets', 'Jose Pavarotti', 'USA'),
#  ('Split Rail Beer & Ale', 'Art Braunschweiger', 'USA'),
#  ('The Big Cheese', 'Liz Nixon', 'USA'),
#  ('The Cracker Box', 'Liu Wong', 'USA'),
#  ("Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'USA'),
#  ('White Clover Markets', 'Karl Jablonski', 'USA'),
#  ('GROSELLA-Restaurante', 'Manuel Pereira', 'Venezuela'),
#  ('HILARION-Abastos', 'Carlos Hernández', 'Venezuela'),
#  ('LILA-Supermercado', 'Carlos González', 'Venezuela'),
#  ('LINO-Delicateses', 'Felipe Izquierdo', 'Venezuela')]

# %% [markdown]
# ### Exercise 3
# #### Write a SQL statement to select all customers from the "Customers" table, sorted ascending by the "Country" and descending by the "CompanyName" column:

# %%
# %%sql
# SELECT * FROM Customers
# ORDER BY Country, CompanyName desc;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Sales Representative', 'Av. del Libertador 900', 'Buenos Aires', None, '1010', 'Argentina', '(1) 123-5555', '(1) 123-5556'),
#  ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Sales Agent', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5333', '(1) 135-5535'),
#  ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Sales Agent', 'Cerrito 333', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5555', '(1) 135-4892'),
#  ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Sales Manager', 'Geislweg 14', 'Salzburg', None, '5020', 'Austria', '6562-9722', '6562-9723'),
#  ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Sales Manager', 'Kirchgasse 6', 'Graz', None, '8010', 'Austria', '7675-3425', '7675-3426'),
#  ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Accounting Manager', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium', '(071) 23 67 22 20', '(071) 23 67 22 21'),
#  ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Sales Agent', 'Rue Joseph-Bens 532', 'Bruxelles', None, 'B-1180', 'Belgium', '(02) 201 24 67', '(02) 201 24 68'),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Sales Manager', 'Rua do Mercado, 12', 'Resende', 'SP', '08737-363', 'Brazil', '(14) 555-8122', None),
#  ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Sales Representative', 'Av. Inês de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brazil', '(11) 555-2167', '(11) 555-2168'),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Assistant Sales Agent', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brazil', '(21) 555-3412', None),
#  ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Marketing Assistant', 'Alameda dos Canàrios, 891', 'Sao Paulo', 'SP', '05487-020', 'Brazil', '(11) 555-1189', None),
#  ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Accounting Manager', 'Rua da Panificadora, 12', 'Rio de Janeiro', 'RJ', '02389-673', 'Brazil', '(21) 555-4252', '(21) 555-4545'),
#  ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Accounting Manager', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil', '(21) 555-0091', '(21) 555-8765'),
#  ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Sales Associate', 'Av. Brasil, 442', 'Campinas', 'SP', '04876-786', 'Brazil', '(11) 555-9482', None),
#  ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Marketing Assistant', 'Rua Orós, 92', 'Sao Paulo', 'SP', '05442-030', 'Brazil', '(11) 555-9857', None),
#  ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', 'Sales Associate', 'Av. dos Lusíadas, 23', 'Sao Paulo', 'SP', '05432-043', 'Brazil', '(11) 555-7647', None),
#  ('MEREP', 'Mère Paillarde', 'Jean Fresnière', 'Marketing Assistant', '43 rue St. Laurent', 'Montréal', 'Québec', 'H1J 1C3', 'Canada', '(514) 555-8054', '(514) 555-8055'),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', 'Marketing Assistant', '1900 Oak St.', 'Vancouver', 'BC', 'V3F 2K1', 'Canada', '(604) 555-3392', '(604) 555-7293'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Accounting Manager', '23 Tsawassen Blvd.', 'Tsawassen', 'BC', 'T2F 8M4', 'Canada', '(604) 555-4729', '(604) 555-3745'),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Sales Manager', 'Smagsloget 45', 'Århus', None, '8200', 'Denmark', '86 21 32 43', '86 22 33 44'),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Owner', 'Vinbæltet 34', 'Kobenhavn', None, '1734', 'Denmark', '31 12 34 56', '31 13 35 57'),
#  ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Owner/Marketing Assistant', 'Keskuskatu 45', 'Helsinki', None, '21240', 'Finland', '90-224 8858', '90-224 8858'),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Accounting Manager', 'Torikatu 38', 'Oulu', None, '90110', 'Finland', '981-443655', '981-443655'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11'),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'Sales Agent', '2, rue du Commerce', 'Lyon', None, '69004', 'France', '78.32.54.86', '78.32.54.87'),
#  ('SPECD', 'Spécialités du monde', 'Dominique Perrier', 'Marketing Manager', '25, rue Lauriston', 'Paris', None, '75016', 'France', '(1) 47.55.60.10', '(1) 47.55.60.20'),
#  ('PARIS', 'Paris spécialités', 'Marie Bertrand', 'Owner', '265, boulevard Charonne', 'Paris', None, '75012', 'France', '(1) 42.34.22.66', '(1) 42.34.22.77'),
#  ('LACOR', "La corne d'abondance", 'Daniel Tonini', 'Sales Representative', "67, avenue de l'Europe", 'Versailles', None, '78000', 'France', '30.59.84.10', '30.59.85.11'),
#  ('FRANR', 'France restauration', 'Carine Schmitt', 'Marketing Manager', '54, rue Royale', 'Nantes', None, '44000', 'France', '40.32.21.21', '40.32.21.20'),
#  ('FOLIG', 'Folies gourmandes', 'Martine Rancé', 'Assistant Sales Agent', '184, chaussée de Tournai', 'Lille', None, '59000', 'France', '20.16.10.16', '20.16.10.17'),
#  ('DUMON', 'Du monde entier', 'Janine Labrune', 'Owner', '67, rue des Cinquante Otages', 'Nantes', None, '44000', 'France', '40.67.88.88', '40.67.89.89'),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 'Owner', '12, rue des Bouchers', 'Marseille', None, '13008', 'France', '91.24.45.40', '91.24.45.41'),
#  ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', 'Marketing Manager', '24, place Kléber', 'Strasbourg', None, '67000', 'France', '88.60.15.31', '88.60.15.32'),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany', '0251-031259', '0251-035695'),
#  ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Accounting Manager', 'Taucherstraße 10', 'Cunewalde', None, '01307', 'Germany', '0372-035188', None),
#  ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Owner', 'Mehrheimerstr. 369', 'Köln', None, '50739', 'Germany', '0221-0644327', '0221-0765721'),
#  ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Owner', 'Hauptstr. 29', 'Bern', None, '3012', 'Switzerland', '0452-076545', None),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'),
#  ('NORTS', 'North/South', 'Simon Crowther', 'Sales Associate', 'South House 300 Queensbridge', 'London', None, 'SW7 1RZ', 'UK', '(171) 555-7733', '(171) 555-2530'),
#  ('ISLAT', 'Island Trading', 'Helen Bennett', 'Marketing Manager', 'Garden House Crowther Way', 'Cowes', 'Isle of Wight', 'PO31 7PJ', 'UK', '(198) 555-8888', None),
#  ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'),
#  ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199'),
#  ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Sales Associate', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'USA', '(206) 555-8257', '(206) 555-2174'),
#  ('THECR', 'The Cracker Box', 'Liu Wong', 'Marketing Assistant', '55 Grizzly Peak Rd.', 'Butte', 'MT', '59801', 'USA', '(406) 555-5834', '(406) 555-8083'),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Marketing Manager', '89 Jefferson Way Suite 2', 'Portland', 'OR', '97201', 'USA', '(503) 555-3612', None),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525'),
#  ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Sales Representative', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', None),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', 'Assistant Sales Representative', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA', '(505) 555-5939', '(505) 555-3620'),
#  ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', 'Sales Representative', '2743 Bering St.', 'Anchorage', 'AK', '99508', 'USA', '(907) 555-7584', '(907) 555-2880'),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 'Sales Manager', '89 Chiaroscuro Rd.', 'Portland', 'OR', '97219', 'USA', '(503) 555-9573', '(503) 555-9646'),
#  ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Owner', '87 Polk St. Suite 5', 'San Francisco', 'CA', '94117', 'USA', '(415) 555-5938', None),
#  ('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Marketing Manager', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'USA', '(509) 555-7969', '(509) 555-6221'),
#  ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'Sales Representative', 'City Center Plaza 516 Main St.', 'Elgin', 'OR', '97827', 'USA', '(503) 555-6874', '(503) 555-2376'),
#  ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 'Marketing Manager', '2732 Baker Blvd.', 'Eugene', 'OR', '97403', 'USA', '(503) 555-7555', None),
#  ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Owner', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', 'Nueva Esparta', '4980', 'Venezuela', '(8) 34-56-12', '(8) 34-93-93'),
#  ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Accounting Manager', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', 'Lara', '3508', 'Venezuela', '(9) 331-6954', '(9) 331-7256'),
#  ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Sales Representative', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', 'Táchira', '5022', 'Venezuela', '(5) 555-1340', '(5) 555-1948'),
#  ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', 'Owner', '5ª Ave. Los Palos Grandes', 'Caracas', 'DF', '1081', 'Venezuela', '(2) 283-2951', '(2) 283-3397')]

# %% [markdown]
# ## INSERT INTO
# #### The INSERT INTO statement is used to insert new rows in a table.
# ##### There are two ways to insert records into a table, the first way is specifying the column names and the values to be inserted.
# ##### The second way is inserting all of the fields into a table without specifying the column names in the SQL query. however, make sure the order of the values is in the same order as the columns in the table.

# %% [markdown]
# <code>INSERT INTO table_name (column1, column2, column3, ...)
# VALUES (value1, value2, value3, ...);</code>
# <br><b>OR</b><br>
# <code>INSERT INTO table_name
# VALUES (value1, value2, value3, ...);</code>

# %% [markdown]
# ## INSERT INTO Example

# %% [markdown]
# #### The following SQL statement inserts a new record in the Customers table:

# %%
# %sql SELECT * FROM Customers
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Inigo Montoya', 'Owner', 'Mataderos  2312', 'México D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', None, '68306', 'Germany', '0621-08460', '0621-08924'),
#  ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', 'Marketing Manager', '24, place Kléber', 'Strasbourg', None, '67000', 'France', '88.60.15.31', '88.60.15.32'),
#  ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', 'Owner', 'C/ Araquil, 67', 'Madrid', None, '28023', 'Spain', '(91) 555 22 82', '(91) 555 91 99'),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 'Owner', '12, rue des Bouchers', 'Marseille', None, '13008', 'France', '91.24.45.40', '91.24.45.41'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Accounting Manager', '23 Tsawassen Blvd.', 'Tsawassen', 'BC', 'T2F 8M4', 'Canada', '(604) 555-4729', '(604) 555-3745'),
#  ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None),
#  ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Sales Agent', 'Cerrito 333', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5555', '(1) 135-4892'),
#  ('CENTC', 'Centro comercial Moctezuma', 'Antonio Banderas', 'Marketing Manager', 'Sierras de Granada 9993', 'México D.F.', None, '05022', 'Mexico', '(5) 555-3392', '(5) 555-7293'),
#  ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Owner', 'Hauptstr. 29', 'Bern', None, '3012', 'Switzerland', '0452-076545', None),
#  ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', 'Sales Associate', 'Av. dos Lusíadas, 23', 'Sao Paulo', 'SP', '05432-043', 'Brazil', '(11) 555-7647', None),
#  ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199'),
#  ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Order Administrator', 'Walserweg 21', 'Aachen', None, '52066', 'Germany', '0241-039123', '0241-059428'),
#  ('DUMON', 'Du monde entier', 'Janine Labrune', 'Owner', '67, rue des Cinquante Otages', 'Nantes', None, '44000', 'France', '40.67.88.88', '40.67.89.89'),
#  ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'),
#  ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Sales Manager', 'Kirchgasse 6', 'Graz', None, '8010', 'Austria', '7675-3425', '7675-3426'),
#  ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Marketing Assistant', 'Rua Orós, 92', 'Sao Paulo', 'SP', '05442-030', 'Brazil', '(11) 555-9857', None),
#  ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'Accounting Manager', 'C/ Moralzarzal, 86', 'Madrid', None, '28034', 'Spain', '(91) 555 94 44', '(91) 555 55 93'),
#  ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Sales Associate', 'Maubelstr. 90', 'Brandenburg', None, '14776', 'Germany', '0555-09876', None),
#  ('LACOR', "La corne d'abondance", 'Daniel Tonini', 'Sales Representative', "67, avenue de l'Europe", 'Versailles', None, '78000', 'France', '30.59.84.10', '30.59.85.11'),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', 'Marketing Assistant', '1900 Oak St.', 'Vancouver', 'BC', 'V3F 2K1', 'Canada', '(604) 555-3392', '(604) 555-7293'),
#  ('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Marketing Manager', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'USA', '(509) 555-7969', '(509) 555-6221'),
#  ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Sales Representative', 'Magazinweg 7', 'Frankfurt a.M.', None, '60528', 'Germany', '069-0245984', '069-0245874'),
#  ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Owner', '87 Polk St. Suite 5', 'San Francisco', 'CA', '94117', 'USA', '(415) 555-5938', None),
#  ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Accounting Manager', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', 'Lara', '3508', 'Venezuela', '(9) 331-6954', '(9) 331-7256'),
#  ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Owner', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', 'Nueva Esparta', '4980', 'Venezuela', '(8) 34-56-12', '(8) 34-93-93'),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 'Sales Manager', '89 Chiaroscuro Rd.', 'Portland', 'OR', '97219', 'USA', '(503) 555-9573', '(503) 555-9646'),
#  ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Marketing Manager', 'Via Ludovico il Moro 22', 'Bergamo', None, '24100', 'Italy', '035-640230', '035-640231'),
#  ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Sales Agent', 'Rue Joseph-Bens 532', 'Bruxelles', None, 'B-1180', 'Belgium', '(02) 201 24 67', '(02) 201 24 68'),
#  ('MEREP', 'Mère Paillarde', 'Jean Fresnière', 'Marketing Assistant', '43 rue St. Laurent', 'Montréal', 'Québec', 'H1J 1C3', 'Canada', '(514) 555-8054', '(514) 555-8055'),
#  ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Marketing Assistant', 'Heerstr. 22', 'Leipzig', None, '04179', 'Germany', '0342-023176', None),
#  ('NORTS', 'North/South', 'Simon Crowther', 'Sales Associate', 'South House 300 Queensbridge', 'London', None, 'SW7 1RZ', 'UK', '(171) 555-7733', '(171) 555-2530'),
#  ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Sales Agent', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires
'187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', None),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Owner', 'Vinbæltet 34', 'Kobenhavn', None, '1734', 'Denmark', '31 12 34 56', '31 13 35 57'),
#  ('SPECD', 'Spécialités du monde', 'Dominique Perrier', 'Marketing Manager', '25, rue Lauriston', 'Paris', None, '75016', 'France', '(1) 47.55.60.10', '(1) 47.55.60.20'),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525'),
#  ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Accounting Manager', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium', '(071) 23 67 22 20', '(071) 23 67 22 21'),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Marketing Manager', '89 Jefferson Way Suite 2', 'Portland', 'OR', '97201', 'USA', '(503) 555-3612', None),
#  ('THECR', 'The Cracker Box', 'Liu Wong', 'Marketing Assistant', '55 Grizzly Peak Rd.', 'Butte', 'MT', '59801', 'USA', '(406) 555-5834', '(406) 555-8083'),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany', '0251-031259', '0251-035695'),
#  ('TORTU', 'Tortuga Restaurante', 'Hugo Sanchis', 'Owner', 'Avda. Azteca 123', 'México D.F.', None, '05033', 'Mexico', '(5) 555-2933', None),
#  ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Sales Representative', 'Av. Inês de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brazil', '(11) 555-2167', '(11) 555-2168'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Sales Associate', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'USA', '(206) 555-8257', '(206) 555-2174'),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Sales Manager', 'Smagsloget 45', 'Århus', None, '8200', 'Denmark', '86 21 32 43', '86 22 33 44'),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'Sales Agent', '2, rue du Commerce', 'Lyon', None, '69004', 'France', '78.32.54.86', '78.32.54.87'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11'),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Sales Representative', 'Adenauerallee 900', 'Stuttgart', None, '70563', 'Germany', '0711-020361', '0711-035428'),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Accounting Manager', 'Torikatu 38', 'Oulu', None, '90110', 'Finland', '981-443655', '981-443655'),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Sales Manager', 'Rua do Mercado, 12', 'Resende', 'SP', '08737-363', 'Brazil', '(14) 555-8122', None),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115'),
#  ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Owner/Marketing Assistant', 'Keskuskatu 45', 'Helsinki', None, '21240', 'Finland', '90-224 8858', '90-224 8858'),
#  ('WOLZA', 'Wolski Zajazd', 'Zbyszek Piestrzeniewicz', 'Owner', 'ul. Filtrowa 68', 'Warszawa', None, '01-012', 'Poland', '(26) 642-7012', '(26) 642-7012'),
#  ('CARTO', 'Cardinal', 'Tom B. Erichsen', 'Owner', 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('BARCAS', 'Barcelona CF', 'Lionel Messi', None, 'Camp Nou', 'Barcelona', None, '8028', 'Spain', None, None),
#  ('CART1', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4040', 'Norway', None, None),
#  ('CART2', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, 'Norway', None, None)]

# %%
# %%sql
# INSERT INTO Customers (CustomerID, CompanyName, ContactName, address, City, PostalCode, Country)
# VALUES ('CART001','Cardinal', 'Tom B. Erichsen', 'Skagen 21','Stavanger', '4006', 'Norway');
# Out:
#  * sqlite:///northwind.db
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-33-b87288ca6664> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "INSERT INTO Customers (CustomerID, CompanyName, ContactName, address, City, PostalCode, Country)\nVALUES ('CART001','Cardinal', 'Tom B. Erichsen', 'Skagen 21','Stavanger', '4006', 'Norway');\n")
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# INSERT INTO Customers
# VALUES ('CART002','Cardinal', 'Tom B. Erichsen', 'Skagen 21','Stavanger', '4006', 'Norway',NULL,NULL,NULL,NULL);
# Out:
#  * sqlite:///northwind.db
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-35-a3e675be3ae2> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "INSERT INTO Customers\nVALUES ('CART002','Cardinal', 'Tom B. Erichsen', 'Skagen 21','Stavanger', '4006', 'Norway',NULL,NULL,NULL,NULL);\n")
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
#
# SELECT * FROM Customers
# WHERE CustomerID='CART001'
# Out:
#  * sqlite:///northwind.db
# Done.
# [('CART001', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None)]

# %% [markdown]
# ### Exercise 4
# #### Check whether the previous record is inserted or not?

# %%
# %%sql
#
# SELECT * FROM Customers
# WHERE CustomerID='CART001' or CustomerID='CART002'
# Out:
#  * sqlite:///northwind.db
# Done.
# [('CART001', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('CART002', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, None, None, None)]

# %% [markdown]
# ## SQL NULL Values

# %% [markdown]
# ### What is a NULL Value?
# #### A field with no value is a NULL value field. NULL value is different from a zero value or a field that contain spaces.

# %% [markdown]
# ### IS NULL and IS NOT NULL
# #### To test a NULL values, we can't use comparision operators, such as =,<, or <>. So we have to use the <b>IS NULL</b> or <b>IS NOT NULL</b> operators instead.

# %% [markdown]
# ### The following SQL statement uses the IS NULL operator to list all customers that have no address:

# %%
# %%sql
# SELECT * FROM Customers
# WHERE Address IS  NOT NULL
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Inigo Montoya', 'Owner', 'Mataderos  2312', 'México D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', None, '68306', 'Germany', '0621-08460', '0621-08924'),
#  ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', 'Marketing Manager', '24, place Kléber', 'Strasbourg', None, '67000', 'France', '88.60.15.31', '88.60.15.32'),
#  ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', 'Owner', 'C/ Araquil, 67', 'Madrid', None, '28023', 'Spain', '(91) 555 22 82', '(91) 555 91 99'),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 'Owner', '12, rue des Bouchers', 'Marseille', None, '13008', 'France', '91.24.45.40', '91.24.45.41'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Accounting Manager', '23 Tsawassen Blvd.', 'Tsawassen', 'BC', 'T2F 8M4', 'Canada', '(604) 555-4729', '(604) 555-3745'),
#  ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None),
#  ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Sales Agent', 'Cerrito 333', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5555', '(1) 135-4892'),
#  ('CENTC', 'Centro comercial Moctezuma', 'Antonio Banderas', 'Marketing Manager', 'Sierras de Granada 9993', 'México D.F.', None, '05022', 'Mexico', '(5) 555-3392', '(5) 555-7293'),
#  ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Owner', 'Hauptstr. 29', 'Bern', None, '3012', 'Switzerland', '0452-076545', None),
#  ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 'Marketing Manager', '2732 Baker Blvd.', 'Eugene', 'OR', '97403', 'USA', '(503) 555-7555', None),
#  ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', 'Owner', '5ª Ave. Los Palos Grandes', 'Caracas', 'DF', '1081', 'Venezuela', '(2) 283-2951', '(2) 283-3397'),
#  ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Accounting Manager', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil', '(21) 555-0091', '(21) 555-8765'),
#  ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Sales Representative', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', 'Táchira', '5022', 'Venezuela', '(5) 555-1340', '(5) 555-1948'),
#  ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'Sales Representative', 'City Center Plaza 516 Main St.', 'Elgin', 'OR', '97827', 'USA', '(503) 555-6874', '(503) 555-2376'),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', 'Sales Associate', '8 Johnstown Road', 'Cork', 'Co. Cork', None, 'Ireland', '2967 542', '2967 3333'),
#  ('ISLAT', 'Island Trading', 'Helen Bennett', 'Marketing Manager', 'Garden House Crowther Way', 'Cowes', 'Isle of Wight', 'PO31 7PJ', 'UK', '(198) 555-8888', None),
#  ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Sales Associate', 'Maubelstr. 90', 'Brandenburg', None, '14776', 'Germany', '0555-09876', None),
#  ('LACOR', "La corne d'abondance", 'Daniel Tonini', 'Sales Representative', "67, avenue de l'Europe", 'Versailles', None, '78000', 'France', '30.59.84.10', '30.59.85.11'),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', 'Marketing Assistant', '1900 Oak St.', 'Vancouver', 'BC', 'V3F 2K1', 'Canada', '(604) 555-3392', '(604) 555-7293'),
#  ('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Marketing Manager', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'USA', '(509) 555-7969', '(509) 555-6221'),
#  ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Sales Representative', 'Magazinweg 7', 'Frankfurt a.M.', None, '60528', 'Germany', '069-0245984', '069-0245874'),
#  ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Owner', '87 Polk St. Suite 5', 'San Francisco', 'CA', '94117', 'USA', '(415) 555-5938', None),
#  ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Accounting Manager', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', 'Lara', '3508', 'Venezuela', '(9) 331-6954', '(9) 331-7256'),
#  ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Owner', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita
'2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA', '(505) 555-5939', '(505) 555-3620'),
#  ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Sales Associate', 'Strada Provinciale 124', 'Reggio Emilia', None, '42100', 'Italy', '0522-556721', '0522-556722'),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Assistant Sales Agent', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brazil', '(21) 555-3412', None),
#  ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Sales Manager', 'Grenzacherweg 237', 'Genève', None, '1203', 'Switzerland', '0897-034214', None),
#  ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Accounting Manager', 'Gran Vía, 1', 'Madrid', None, '28001', 'Spain', '(91) 745 6200', '(91) 745 6210'),
#  ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Owner', 'Erling Skakkes gate 78', 'Stavern', None, '4110', 'Norway', '07-98 92 35', '07-98 92 47'),
#  ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Sales Representative', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', None),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Owner', 'Vinbæltet 34', 'Kobenhavn', None, '1734', 'Denmark', '31 12 34 56', '31 13 35 57'),
#  ('SPECD', 'Spécialités du monde', 'Dominique Perrier', 'Marketing Manager', '25, rue Lauriston', 'Paris', None, '75016', 'France', '(1) 47.55.60.10', '(1) 47.55.60.20'),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525'),
#  ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Accounting Manager', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium', '(071) 23 67 22 20', '(071) 23 67 22 21'),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Marketing Manager', '89 Jefferson Way Suite 2', 'Portland', 'OR', '97201', 'USA', '(503) 555-3612', None),
#  ('THECR', 'The Cracker Box', 'Liu Wong', 'Marketing Assistant', '55 Grizzly Peak Rd.', 'Butte', 'MT', '59801', 'USA', '(406) 555-5834', '(406) 555-8083'),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany', '0251-031259', '0251-035695'),
#  ('TORTU', 'Tortuga Restaurante', 'Hugo Sanchis', 'Owner', 'Avda. Azteca 123', 'México D.F.', None, '05033', 'Mexico', '(5) 555-2933', None),
#  ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Sales Representative', 'Av. Inês de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brazil', '(11) 555-2167', '(11) 555-2168'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Sales Associate', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'USA', '(206) 555-8257', '(206) 555-2174'),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Sales Manager', 'Smagsloget 45', 'Århus', None, '8200', 'Denmark', '86 21 32 43', '86 22 33 44'),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'Sales Agent', '2, rue du Commerce', 'Lyon', None, '69004', 'France', '78.32.54.86', '78.32.54.87'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11'),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Sales Representative', 'Adenauerallee 900', 'Stuttgart', None, '70563', 'Germany', '0711-020361', '0711-035428'),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Accounting Manager', 'Torikatu 38', 'Oulu', None, '90110', 'Finland', '981-443655', '981-443655'),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Sales Manager', 'Rua do Mercado, 12', 'Resende', 'SP', '08737-363', 'Brazil', '(14) 555-8122', None),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115'),
#  ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Owner/Marketing Assistant', 'Keskuskatu 45', 'Helsinki', None, '21240', 'Finland', '90-224 8858', '90-224 8858'),
#  ('WOLZA', 'Wolski Zajazd', 'Zbyszek Piestrzeniewicz', 'Owner', 'ul. Filtrowa 68', 'Warszawa', None, '01-012', 'Poland', '(26) 642-7012', '(26) 642-7012'),
#  ('CARTO', 'Cardinal', 'Tom B. Erichsen', 'Owner', 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('BARCAS', 'Barcelona CF', 'Lionel Messi', None, 'Camp Nou', 'Barcelona', None, '8028', 'Spain', None, None),
#  ('CART1', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4040', 'Norway', None, None),
#  ('CART2', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, 'Norway', None, None),
#  ('CART001', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('CART002', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, None, None, None)]

# %%
# %%sql
# SELECT * FROM Customers
# WHERE Address IS NULL
# #to check ada ke adress yg null
# Out:
#  * sqlite:///northwind.db
# Done.
# []

# %%
# %%sql
# SELECT * FROM Customers
# WHERE Phone IS NULL
# Out:
#  * sqlite:///northwind.db
# Done.
# [('CARTO', 'Cardinal', 'Tom B. Erichsen', 'Owner', 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('BARCAS', 'Barcelona CF', 'Lionel Messi', None, 'Camp Nou', 'Barcelona', None, '8028', 'Spain', None, None),
#  ('CART1', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4040', 'Norway', None, None),
#  ('CART2', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, 'Norway', None, None),
#  ('CART001', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('CART002', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, None, None, None)]

# %% [markdown]
# ## SQL Update Statement

# %% [markdown]
# #### The UPDATE statement is used to modify the existing records in a table.

# %% [markdown]
# ### UPDATE Syntax
# <br><code>UPDATE table_name
# SET column1 = value1, column2 = value2, ...
# WHERE condition;</code>

# %%
# %%sql
# UPDATE Customers
# SET ContactName = 'Tom B. Erichsen'
# WHERE CompanyName='Blauer See Delikatessen' OR CompanyName='Victoria Ashworth';
# Out:
#  * sqlite:///northwind.db
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-124-0d0b2f6c32ce> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "UPDATE Customers\nSET ContactName = 'Tom B. Erichsen'\nWHERE CompanyName='Blauer See Delikatessen' OR CompanyName='Victoria Ashworth';\n")
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# UPDATE Customers
# SET PostalCode = '4040'
# WHERE CustomerID = 'CART1'
# Out:
#  * sqlite:///northwind.db
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-47-f60de6c94ecc> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "UPDATE Customers\nSET PostalCode = '4040'\nWHERE CustomerID = 'CART1'\n")
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
#
# SELECT * FROM Customers
# WHERE CustomerID = 'CART1'
# Out:
#  * sqlite:///northwind.db
# Done.
# [('CART1', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4040', 'Norway', None, None)]

# %%
# %%sql
# UPDATE Customers
# SET CompanyName = 'TheCADS', ContactName ="Mehdi"
# WHERE CustomerID = 'CART1'
# Out:
#  * sqlite:///northwind.db
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-50-a8b269ca0060> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', 'UPDATE Customers\nSET CompanyName = \'TheCADS\', ContactName ="Mehdi"\nWHERE CustomerID = \'CART1\'\n')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
#
# SELECT * FROM Customers
# WHERE CustomerID = 'CART1'
# Out:
#  * sqlite:///northwind.db
# Done.
# [('CART1', 'TheCADS', 'Mehdi', None, 'Skagen 21', 'Stavanger', None, '4040', 'Norway', None, None)]

# %% [markdown]
# ### Exercise 5
# #### Write a SQL statement to update country name of 'Tom B. Erichsen' from 'Cardinal' Company to "Netherlands".

# %%
# %%sql
# UPDATE Customers
# SET Country = 'Netherlands',
# WHERE ContactName = 'Tom B. Erichsen' AND CompanyName = 'Cardinal';
# Out:
#  * sqlite:///northwind.db
# (sqlite3.OperationalError) near "WHERE": syntax error
# [SQL: UPDATE Customers SET Country = 'Netherlands',
# WHERE ContactName = 'Tom B. Erichsen' AND CompanyName = 'Cardinal';]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
# %%sql
#
# SELECT * FROM Customers
# WHERE ContactName = 'Tom B. Erichsen'
# Out:
#  * sqlite:///northwind.db
# Done.
# [('CARTO', 'Cardinal', 'Tom B. Erichsen', 'Owner', 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('CART2', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, 'Norway', None, None),
#  ('CART001', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('CART002', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, None, None, None)]

# %% [markdown]
# ### Update Multiple Records

# %% [markdown]
# #### There WHERE clause determines how many records that will be updated
# ### Exercise 6
# ##### Write a SQL statement to update the ContactName to "Julio Iglesias" for all records where country is "Mexico":

# %%
# %%sql
# UPDATE Customers
# SET ContactName = 'Julio Iglesias'
# WHERE Country='Mexico';
# Out:
#  * sqlite:///northwind.db
# 5 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-61-b748a4fc8f94> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "UPDATE Customers\nSET ContactName = 'Julio Iglesias'\nWHERE Country='Mexico';\n")
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
#
# SELECT * FROM Customers
# WHERE Country='Mexico';
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ANATR', 'Ana Trujillo Emparedados y helados', 'Julio Iglesias', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Julio Iglesias', 'Owner', 'Mataderos  2312', 'México D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('CENTC', 'Centro comercial Moctezuma', 'Julio Iglesias', 'Marketing Manager', 'Sierras de Granada 9993', 'México D.F.', None, '05022', 'Mexico', '(5) 555-3392', '(5) 555-7293'),
#  ('PERIC', 'Pericles Comidas clásicas', 'Julio Iglesias', 'Sales Representative', 'Calle Dr. Jorge Cash 321', 'México D.F.', None, '05033', 'Mexico', '(5) 552-3745', '(5) 545-3745'),
#  ('TORTU', 'Tortuga Restaurante', 'Julio Iglesias', 'Owner', 'Avda. Azteca 123', 'México D.F.', None, '05033', 'Mexico', '(5) 555-2933', None)]

# %% [markdown]
# ### Be careful when updating records. If you omit the WHERE clause, ALL records get updated!

# %% [markdown]
# ## SQL DELETE Statement

# %% [markdown]
# ### The DELETE statament is used to delete existing records in a table.

# %% [markdown]
# <code>DELETE FROM table_name
# WHERE condition;
# </code>

# %% [markdown]
# #### Caution! If you omit the WHERE clause, all records in the table will be deleted.

# %% [markdown]
# ### Exercise 7
# #### Write a query to delete Lionel Messi record. (his CustomerID is 'BARCAS')

# %%
# delete
DELETE FROM Customers
WHERE CustomerID = 'BARCAS';
# Out:
#   File "<ipython-input-69-28099f7e39da>", line 2
#     DELETE FROM Customers
#            ^
# SyntaxError: invalid syntax

# %%
# check record

# %% [markdown]
# ### Restore the database with these commands

# %%
# %%sql
#
# UPDATE Customers
# SET Country = 'Norway'
# WHERE CompanyName = 'Cardinal' AND ContactName = 'Tom B. Erichsen';
#
# UPDATE Customers
# SET ContactName = 'Ana Trujillo'
# WHERE CustomerID = 'ANATR';
#
# UPDATE Customers
# SET ContactName = 'Inigo Montoya'
# WHERE CustomerID = 'ANTON';
#
# UPDATE Customers
# SET ContactName = 'Antonio Banderas'
# WHERE CustomerID = 'CENTC';
#
# UPDATE Customers
# SET ContactName = 'Salma Hayek'
# WHERE CustomerID = 'PERIC';
#
# UPDATE Customers
# SET ContactName = 'Hugo Sanchis'
# WHERE CustomerID = 'TORTU';
#
#
# INSERT INTO Customers (CustomerID, CompanyName, ContactName, Address, City, PostalCode, Country)
# VALUES ('BARCAS','Barcelona CF', 'Lionel Messi', 'Camp Nou','Barcelona', '8028', 'Spain');
#
#
# DELETE Customers
# WHERE CustomerID = CART1;
#
# DELETE Customers
# WHERE CustomerID = CART2;
# Out:
#  * sqlite:///northwind.db
# 4 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#
# IntegrityError: UNIQUE constraint failed: Customers.CustomerID
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-70-2d293f85cc37> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "\nUPDATE Customers\nSET Country = 'Norway'\nWHERE CompanyName = 'Cardinal' AND ContactName = 'Tom B. Erichsen';\n\nUPDATE Customers\nSET ContactName = 'Ana Trujillo'\nWHERE CustomerID = 'ANATR';\n\nUPDATE Customers\nSET ContactName = 'Inigo Montoya'\nWHERE CustomerID = 'ANTON';\n\nUPDATE Customers\nSET ContactName = 'Antonio Banderas'\nWHERE CustomerID = 'CENTC';\n\nUPDATE Customers\nSET ContactName = 'Salma Hayek'\nWHERE CustomerID = 'PERIC';\n\nUPDATE Customers\nSET ContactName = 'Hugo Sanchis'\nWHERE CustomerID = 'TORTU';\n\n\nINSERT INTO Customers (CustomerID, CompanyName, ContactName, Address, City, PostalCode, Country)\nVALUES ('BARCAS','Barcelona CF', 'Lionel Messi', 'Camp Nou','Barcelona', '8028', 'Spain');\n\n\nDELETE Customers\nWHERE CustomerID = CART1;\n\nDELETE Customers\nWHERE CustomerID = CART2;\n")
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     365             else:
#     366                 txt = sqlalchemy.sql.text(statement)
# --> 367                 result = conn.session.execute(txt, user_namespace)
#     368             _commit(conn=conn, config=config)
#     369             if result and config.feedback:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1198             )
#    1199         else:
# -> 1200             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1201
#    1202     def _execute_function(self, func, multiparams, params, execution_options):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     311     ):
#     312         if _force or self.supports_execution:
# --> 313             return connection._execute_clauseelement(
#     314                 self, multiparams, params, execution_options
#     315             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1387             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1388         )
# -> 1389         ret = self._execute_context(
#    1390             dialect,
#    1391             dialect.execution_ctx_cls._init_compiled,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1746
#    1747         except BaseException as e:
# -> 1748             self._handle_dbapi_exception(
#    1749                 e, statement, parameters, cursor, context
#    1750             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1927                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1928             elif should_wrap:
# -> 1929                 util.raise_(
#    1930                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1931                 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1703                             break
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#    1707                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     690
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#     694     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (sqlite3.IntegrityError) UNIQUE constraint failed: Customers.CustomerID
# [SQL: INSERT INTO Customers (CustomerID, CompanyName, ContactName, Address, City, PostalCode, Country)
# VALUES ('BARCAS','Barcelona CF', 'Lionel Messi', 'Camp Nou','Barcelona', '8028', 'Spain');]
# (Background on this error at: http://sqlalche.me/e/14/gkpj)

# %% [markdown]
# #### You can delete all records using <code>DELETE FROM table_name</code>, Please don't try it.  : )

# %% [markdown]
# ## SQL LIMIT clause

# %% [markdown]
# #### The SQL SELECT LIMIT statement is used to retrieve records from one or more tables in a database and limit the number of records returned based on a limit value.

# %% [markdown]
# <code>SELECT column_name(s)
# FROM table_name
# WHERE condition
# LIMIT number;</code>

# %% [markdown]
# ### Exercise 8
# #### Write a query to select the first three customers that live in Mexico.

# %%
# %%sql SELECT *
# FROM Customers
# WHERE Country="Mexico"
# LIMIT 4;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Inigo Montoya', 'Owner', 'Mataderos  2312', 'México D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('CENTC', 'Centro comercial Moctezuma', 'Antonio Banderas', 'Marketing Manager', 'Sierras de Granada 9993', 'México D.F.', None, '05022', 'Mexico', '(5) 555-3392', '(5) 555-7293'),
#  ('PERIC', 'Pericles Comidas clásicas', 'Salma Hayek', 'Sales Representative', 'Calle Dr. Jorge Cash 321', 'México D.F.', None, '05033', 'Mexico', '(5) 552-3745', '(5) 545-3745')]

# %% [markdown]
# ## SQL MIN() and MAX() Functions

# %% [markdown]
# #### The MIN() function returns the smallest value of the selected column.
# #### The MAX() function returns the largest value of the selected column.

# %% [markdown]
# <code>SELECT <b>MIN</b> or <b>MAX</b>(column_name)
# FROM table_name
# WHERE condition;</code>

# %% [markdown]
# ## Exercise 9
# #### First get some information on "Products" table, then write a query to return back the cheapest product in this table.

# %%
# %%sql SELECT MIN or MAX(column_name)
# FROM CUSTOMERS
# WHERE condition;

# %%
# %sql SELECT MIN(Unitprice) FROM Products
# Out:
#  * sqlite:///northwind.db
# Done.
# [(2.5,)]

# %%
# %%sql SELECT MIN(Unitprice) as Cheapest
# FROM Products
# Out:
#  * sqlite:///northwind.db
# Done.
# [(2.5,)]

# %%
# %sql SELECT MAX(Unitprice) as Sec_Highest
FROM Product WHERE NOT Unitprice IN (SELECT MAX(Unitprice) FROM Products);
# Out:
#   File "<ipython-input-140-bdc416d18b56>", line 2
#     FROM Product WHERE NOT Unitprice IN (SELECT MAX(Unitprice) FROM Products);
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## SQL COUNT(), AVG() and SUM() Functions

# %% [markdown]
# #### The COUNT() function returns the number of rows that matches a specified criteria.
# #### The AVG() function returns the average value of a numeric column.
# #### The SUM() function returns the total sum of a numeric column.

# %% [markdown]
# ### COUNT Syntax
# <code>SELECT <b>COUNT</b>(column_name)
# FROM table_name
# WHERE condition;</code>

# %% [markdown]
# ### AVG Syntax
# <code>SELECT <b>AVG</b>(column_name)
# FROM table_name
# WHERE condition;</code>

# %% [markdown]
# ### SUM Syntax
# <code>SELECT <b>SUM</b>(column_name)
# FROM table_name
# WHERE condition;</code>

# %% [markdown]
# ### Exercise 10
# #### How many products do we have in our database?

# %%
# %%sql
# SELECT COUNT(ProductID)
# FROM Products;
# Out:
#  * sqlite:///northwind.db
# Done.
# [(77,)]

# %% [markdown]
# ### Exercise 11
# #### Write a SQL statement to find the average price of all products?

# %%
# %%sql SELECT AVG(UnitPrice)
# FROM Products;
# Out:
#  * sqlite:///northwind.db
# Done.
# [(28.866363636363637,)]

# %% [markdown]
# ### Exercise 12
# #### How many quantities have the customers ordered?

# %%
# %%sql SELECT SUM(UnitsOnOrder)
# FROM Products;
# Out:
#  * sqlite:///northwind.db
# Done.
# [(780,)]

# %% [markdown]
# ## SQL LIKE Operator

# %% [markdown]
# #### The LIKE operator is used in a WHERE clause to search for a specified pattern in a column.
# #### There are two wildcards used in conjunction with the LIKE operator:
# ##### % : The percent sign is used to represent zero, one, or multiple characters.
# ##### _ : The underscore sign is used to represent a single character.

# %% [markdown]
# <code>SELECT column1, column2, ...
# FROM table_name
# WHERE columnN <b>LIKE</b> pattern;</code>

# %% [markdown]
# ### Exercise 13-19
# #### Write a query to...in Customers table.

# %% [markdown]
# - Find any values that start with "a"
# - Find any values that end with "a"
# - Find any values that have "or" in any position
# - Find any values that have "r" in the second position
# - Find any values that start with "a" and are at least 3 characters in length
# - Find any values that start with "a" and ends with "o"
# - Find any values that does NOT start with "a"

# %% [markdown]
# ### Find any values that start with "a"

# %%
# %%sql
# SELECT * FROM Customers
# WHERE ContactName LIKE 'a%'
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('CENTC', 'Centro comercial Moctezuma', 'Antonio Banderas', 'Marketing Manager', 'Sierras de Granada 9993', 'México D.F.', None, '05022', 'Mexico', '(5) 555-3392', '(5) 555-7293'),
#  ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'),
#  ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Marketing Assistant', 'Rua Orós, 92', 'Sao Paulo', 'SP', '05442-030', 'Brazil', '(11) 555-9857', None),
#  ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Sales Associate', 'Av. Brasil, 442', 'Campinas', 'SP', '04876-786', 'Brazil', '(11) 555-9482', None),
#  ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Marketing Assistant', 'Heerstr. 22', 'Leipzig', None, '04179', 'Germany', '0342-023176', None),
#  ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Accounting Manager', 'Gran Vía, 1', 'Madrid', None, '28001', 'Spain', '(91) 745 6200', '(91) 745 6210'),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525'),
#  ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Sales Representative', 'Av. Inês de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brazil', '(11) 555-2167', '(11) 555-2168')]

# %% [markdown]
# ### Find any values that end with "a"

# %%
# %%sql
# SELECT * FROM Customers
# WHERE ContactName LIKE '%a'
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ANTON', 'Antonio Moreno Taquería', 'Inigo Montoya', 'Owner', 'Mataderos  2312', 'México D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Marketing Manager', 'Rambla de Cataluña, 23', 'Barcelona', None, '08022', 'Spain', '(93) 203 4560', '(93) 203 4561'),
#  ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Sales Associate', 'Av. Brasil, 442', 'Campinas', 'SP', '04876-786', 'Brazil', '(11) 555-9482', None),
#  ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', 'Owner', '5ª Ave. Los Palos Grandes', 'Caracas', 'DF', '1081', 'Venezuela', '(2) 283-2951', '(2) 283-3397'),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', 'Sales Associate', '8 Johnstown Road', 'Cork', 'Co. Cork', None, 'Ireland', '2967 542', '2967 3333'),
#  ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Sales Agent', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5333', '(1) 135-5535'),
#  ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Accounting Manager', 'Rua da Panificadora, 12', 'Rio de Janeiro', 'RJ', '02389-673', 'Brazil', '(21) 555-4252', '(21) 555-4545'),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Assistant Sales Agent', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brazil', '(21) 555-3412', None)]

# %% [markdown]
# ### Find any values that have "or" in any position

# %%
# %%sql
# SELECT * FROM Customers
# WHERE ContactName LIKE '%or%'
# Out:
#  * sqlite:///northwind.db
# Done.
# [('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None),
#  ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Sales Representative', 'Via Monte Bianco 34', 'Torino', None, '10100', 'Italy', '011-4988260', '011-4988261'),
#  ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Owner', '87 Polk St. Suite 5', 'San Francisco', 'CA', '94117', 'USA', '(415) 555-5938', None),
#  ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Sales Manager', 'Geislweg 14', 'Salzburg', None, '5020', 'Austria', '6562-9722', '6562-9723'),
#  ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Accounting Manager', 'Taucherstraße 10', 'Cunewalde', None, '01307', 'Germany', '0372-035188', None),
#  ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Sales Associate', 'Strada Provinciale 124', 'Reggio Emilia', None, '42100', 'Italy', '0522-556721', '0522-556722')]

# %% [markdown]
# ### Find any values that have "r" in the second position

# %%
# %%sql
# SELECT * FROM Customers
# WHERE ContactName LIKE '_r%'
# Out:
#  * sqlite:///northwind.db
# Done.
# [('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', 'Marketing Manager', '24, place Kléber', 'Strasbourg', None, '67000', 'France', '88.60.15.31', '88.60.15.32'),
#  ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Marketing Assistant', 'Rua Orós, 92', 'Sao Paulo', 'SP', '05442-030', 'Brazil', '(11) 555-9857', None),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 'Sales Manager', '89 Chiaroscuro Rd.', 'Portland', 'OR', '97219', 'USA', '(503) 555-9573', '(503) 555-9646'),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525')]

# %% [markdown]
# ### Find any values that start with "a" and are at least 3 characters in length

# %%
# %%sql
# SELECT * FROM Customers
# WHERE ContactName LIKE 'a__%'
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('CENTC', 'Centro comercial Moctezuma', 'Antonio Banderas', 'Marketing Manager', 'Sierras de Granada 9993', 'México D.F.', None, '05022', 'Mexico', '(5) 555-3392', '(5) 555-7293'),
#  ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'),
#  ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Marketing Assistant', 'Rua Orós, 92', 'Sao Paulo', 'SP', '05442-030', 'Brazil', '(11) 555-9857', None),
#  ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Sales Associate', 'Av. Brasil, 442', 'Campinas', 'SP', '04876-786', 'Brazil', '(11) 555-9482', None),
#  ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Marketing Assistant', 'Heerstr. 22', 'Leipzig', None, '04179', 'Germany', '0342-023176', None),
#  ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Accounting Manager', 'Gran Vía, 1', 'Madrid', None, '28001', 'Spain', '(91) 745 6200', '(91) 745 6210'),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525'),
#  ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Sales Representative', 'Av. Inês de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brazil', '(11) 555-2167', '(11) 555-2168')]

# %% [markdown]
# ### Find any values that start with "a" and ends with "o"

# %%
# %%sql
# SELECT * FROM Customers
# WHERE ContactName LIKE ('a%o')
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Accounting Manager', 'Gran Vía, 1', 'Madrid', None, '28001', 'Spain', '(91) 745 6200', '(91) 745 6210')]

# %% [markdown]
# ### Find any values that does NOT start with "a"

# %%
# %%sql
# SELECT * FROM Customers
# WHERE ContactName NOT LIKE 'a%'
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Tom B. Erichsen', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Inigo Montoya', 'Owner', 'Mataderos  2312', 'México D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Tom B. Erichsen', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', None, '68306', 'Germany', '0621-08460', '0621-08924'),
#  ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', 'Marketing Manager', '24, place Kléber', 'Strasbourg', None, '67000', 'France', '88.60.15.31', '88.60.15.32'),
#  ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', 'Owner', 'C/ Araquil, 67', 'Madrid', None, '28023', 'Spain', '(91) 555 22 82', '(91) 555 91 99'),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 'Owner', '12, rue des Bouchers', 'Marseille', None, '13008', 'France', '91.24.45.40', '91.24.45.41'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Accounting Manager', '23 Tsawassen Blvd.', 'Tsawassen', 'BC', 'T2F 8M4', 'Canada', '(604) 555-4729', '(604) 555-3745'),
#  ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None),
#  ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Sales Agent', 'Cerrito 333', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5555', '(1) 135-4892'),
#  ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Owner', 'Hauptstr. 29', 'Bern', None, '3012', 'Switzerland', '0452-076545', None),
#  ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', 'Sales Associate', 'Av. dos Lusíadas, 23', 'Sao Paulo', 'SP', '05432-043', 'Brazil', '(11) 555-7647', None),
#  ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199'),
#  ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Order Administrator', 'Walserweg 21', 'Aachen', None, '52066', 'Germany', '0241-039123', '0241-059428'),
#  ('DUMON', 'Du monde entier', 'Janine Labrune', 'Owner', '67, rue des Cinquante Otages', 'Nantes', None, '44000', 'France', '40.67.88.88', '40.67.89.89'),
#  ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Sales Manager', 'Kirchgasse 6', 'Graz', None, '8010', 'Austria', '7675-3425', '7675-3426'),
#  ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'Accounting Manager', 'C/ Moralzarzal, 86', 'Madrid', None, '28034', 'Spain', '(91) 555 94 44', '(91) 555 55 93'),
#  ('FOLIG', 'Folies gourmandes', 'Martine Rancé', 'Assistant Sales Agent', '184, chaussée de Tournai', 'Lille', None, '59000', 'France', '20.16.10.16', '20.16.10.17'),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', 'Marketing Assistant', '1900 Oak St.', 'Vancouver', 'BC', 'V3F 2K1', 'Canada', '(604) 555-3392', '(604) 555-7293'),
#  ('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Marketing Manager', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'USA', '(509) 555-7969', '(509) 555-6221'),
#  ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Sales Representative', 'Magazinweg 7', 'Frankfurt a.M.', None, '60528', 'Germany', '069-0245984', '069-0245874'),
#  ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Owner', '87 Polk St. Suite 5', 'San Francisco', 'CA', '94117', 'USA', '(415) 555-5938', None),
#  ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Accounting Manager', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', 'Lara', '3508', 'Venezuela', '(9) 331-6954', '(9) 331-7256'),
#  ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Owner', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', 'Nueva Esparta', '4980', 'Venezuela', '(8) 34-56-12', '(8) 34-93-93'),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 'Sales Manager', '89 Chiaroscuro Rd.', 'Portland', 'OR', '97219', 'USA', '(503) 555-9573', '(503) 555-9646'),
#  ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Marketing Manager', 'Via Ludovico il Moro 22', 'Bergamo', None, '24100', 'Italy', '035-640230', '035-640231'),
#  ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Sales Agent', 'Rue Joseph-Bens 532', 'Bruxelles', None, 'B-1180', 'Belgium', '(02) 201 24 67', '(02) 201 24 68'),
#  ('MEREP', 'Mère Paillarde', 'Jean Fresnière', 'Marketing Assistant', '43 rue St. Laurent', 'Montréal', 'Québec', 'H1J 1C3', 'Canada', '(514) 555-8054', '(514) 555-8055'),
#  ('NORTS', 'North/South', 'Simon Crowther', 'Sales Associate', 'South House 300 Queensbridge', 'London', None, 'SW7 1RZ', 'UK', '(171) 555-7733', '(171) 555-2530'),
#  ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Sales Agent', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5333', '(1) 135-5535'),
#  ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', 'Sales Representative', '2743 Bering St.', 'Anchorage', 'AK', '99508', 'USA', '(907) 555-7584', '(907) 555-2880'),
#  ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Owner', 'Mehrheimerstr. 369', 'Köln', None, '50739', 'Germany', '0221-0644327', '0221-0765721'),
#  ('PARIS', 'Paris spécialités', 'Marie Bertrand', 'Owner', '265, boulevard Charonne', 'Paris', None, '75012', 'France', '(1) 42.34.22.66', '(1) 42.34.22.77'),
#  ('PERIC', 'Pericles Comidas clásicas', 'Salma Hayek', 'Sales Representative', 'Calle Dr. Jorge Cash 321', 'México D.F.', None, '05033', 'Mexico', '(5) 552-3745', '(5) 545-3745'),
#  ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Sales Manager', 'Geislweg 14', 'Salzburg', None, '5020', 'Austria', '6562-9722', '6562-9723'),
#  ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Sales Representative', 'Estrada da saúde n. 58', 'Lisboa', None, '1756', 'Portugal', '(1) 356-5634', None),
#  ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Accounting Manager', 'Rua da Panificadora, 12', 'Rio de Janeiro', 'RJ', '02389-673', 'Brazil', '(21) 555-4252', '(21) 555-4545'),
#  ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Marketing Assistant', 'Alameda dos Canàrios, 891', 'Sao Paulo', 'SP', '05487-020', 'Brazil', '(11) 555-1189', None),
#  ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Accounting Manager', 'Taucherstraße 10', 'Cunewalde', None, '01307', 'Germany', '0372-035188', None),
#  ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Sales Representative', 'Av. del Libertador 900', 'Buenos Aires', None, '1010', 'Argentina', '(1) 123-5555', '(1) 123-5556'),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', 'Assistant Sales Representative', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA', '(505) 555-5939', '(505) 555-3620'),
#  ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Sales Associate', 'Strada Provinciale 124', 'Reggio Emilia', None, '42100', 'Italy', '0522-556721', '0522-556722'),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Assistant Sales Agent', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brazil', '(21) 555-3412', None),
#  ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Sales Manager', 'Grenzacherweg 237', 'Genève', None, '1203', 'Switzerland', '0897-034214', None),
#  ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Owner', 'Erling Skakkes gate 78', 'Stavern', None, '4110', 'Norway', '07-98 92 35', '07-98 92 47'),
#  ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Sales Representative', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', None),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Owner', 'Vinbæltet 34', 'Kobenhavn', None, '1734', 'Denmark', '31 12 34 56', '31 13 35 57'),
#  ('SPECD', 'Spécialités du monde', 'Dominique Perrier', 'Marketing Manager', '25, rue Lauriston', 'Paris', None, '75016', 'France', '(1) 47.55.60.10', '(1) 47.55.60.20'),
#  ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Accounting Manager', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium', '(071) 23 67 22 20', '(071) 23 67 22 21'),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Marketing Manager', '89 Jefferson Way Suite 2', 'Portland', 'OR', '97201', 'USA', '(503) 555-3612', None),
#  ('THECR', 'The Cracker Box', 'Liu Wong', 'Marketing Assistant', '55 Grizzly Peak Rd.', 'Butte', 'MT', '59801', 'USA', '(406) 555-5834', '(406) 555-8083'),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany', '0251-031259', '0251-035695'),
#  ('TORTU', 'Tortuga Restaurante', 'Hugo Sanchis', 'Owner', 'Avda. Azteca 123', 'México D.F.', None, '05033', 'Mexico', '(5) 555-2933', None),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Sales Associate', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'USA', '(206) 555-8257', '(206) 555-2174'),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Sales Manager', 'Smagsloget 45', 'Århus', None, '8200', 'Denmark', '86 21 32 43', '86 22 33 44'),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'Sales Agent', '2, rue du Commerce', 'Lyon', None, '69004', 'France', '78.32.54.86', '78.32.54.87'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11'),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Sales Representative', 'Adenauerallee 900', 'Stuttgart', None, '70563', 'Germany', '0711-020361', '0711-035428'),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Accounting Manager', 'Torikatu 38', 'Oulu', None, '90110', 'Finland', '981-443655', '981-443655'),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Sales Manager', 'Rua do Mercado, 12', 'Resende', 'SP', '08737-363', 'Brazil', '(14) 555-8122', None),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115'),
#  ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Owner/Marketing Assistant', 'Keskuskatu 45', 'Helsinki', None, '21240', 'Finland', '90-224 8858', '90-224 8858'),
#  ('WOLZA', 'Wolski Zajazd', 'Zbyszek Piestrzeniewicz', 'Owner', 'ul. Filtrowa 68', 'Warszawa', None, '01-012', 'Poland', '(26) 642-7012', '(26) 642-7012'),
#  ('CARTO', 'Cardinal', 'Tom B. Erichsen', 'Owner', 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('BARCAS', 'Barcelona CF', 'Lionel Messi', None, 'Camp Nou', 'Barcelona', None, '8028', 'Spain', None, None),
#  ('CART1', 'TheCADS', 'Mehdi', None, 'Skagen 21', 'Stavanger', None, '4040', 'Norway', None, None),
#  ('CART2', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, 'Norway', None, None),
#  ('CART001', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('CART002', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, 'Norway', None, None)]

# %% [markdown]
# ## SQL IN Operator

# %% [markdown]
# #### The IN operator allows you to specify multiple values in a WHERE clause. The IN operator is a shorthand for multiple OR conditions.

# %% [markdown]
# <code>SELECT column_name(s)
# FROM table_name
# WHERE column_name IN (value1, value2, ...);</code>
# <br><b>Or</b><br>
# <code>SELECT column_name(s)
# FROM table_name
# WHERE column_name IN (SELECT STATEMENT);
# </code>

# %% [markdown]
# ### Exercise 20
# #### Write a SELECT statement to get all customers located in "Germany", "USA", and "France":

# %%
# %%sql
# SELECT * FROM Customers
# WHERE Country IN ("Germany", "USA", "France");
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Tom B. Erichsen', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Tom B. Erichsen', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', None, '68306', 'Germany', '0621-08460', '0621-08924'),
#  ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', 'Marketing Manager', '24, place Kléber', 'Strasbourg', None, '67000', 'France', '88.60.15.31', '88.60.15.32'),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 'Owner', '12, rue des Bouchers', 'Marseille', None, '13008', 'France', '91.24.45.40', '91.24.45.41'),
#  ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Order Administrator', 'Walserweg 21', 'Aachen', None, '52066', 'Germany', '0241-039123', '0241-059428'),
#  ('DUMON', 'Du monde entier', 'Janine Labrune', 'Owner', '67, rue des Cinquante Otages', 'Nantes', None, '44000', 'France', '40.67.88.88', '40.67.89.89'),
#  ('FOLIG', 'Folies gourmandes', 'Martine Rancé', 'Assistant Sales Agent', '184, chaussée de Tournai', 'Lille', None, '59000', 'France', '20.16.10.16', '20.16.10.17'),
#  ('FRANK', 'Frankenversand', 'Peter Franken', 'Marketing Manager', 'Berliner Platz 43', 'München', None, '80805', 'Germany', '089-0877310', '089-0877451'),
#  ('FRANR', 'France restauration', 'Carine Schmitt', 'Marketing Manager', '54, rue Royale', 'Nantes', None, '44000', 'France', '40.32.21.21', '40.32.21.20'),
#  ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 'Marketing Manager', '2732 Baker Blvd.', 'Eugene', 'OR', '97403', 'USA', '(503) 555-7555', None),
#  ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'Sales Representative', 'City Center Plaza 516 Main St.', 'Elgin', 'OR', '97827', 'USA', '(503) 555-6874', '(503) 555-2376'),
#  ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Sales Associate', 'Maubelstr. 90', 'Brandenburg', None, '14776', 'Germany', '0555-09876', None),
#  ('LACOR', "La corne d'abondance", 'Daniel Tonini', 'Sales Representative', "67, avenue de l'Europe", 'Versailles', None, '78000', 'France', '30.59.84.10', '30.59.85.11'),
#  ('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Marketing Manager', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'USA', '(509) 555-7969', '(509) 555-6221'),
#  ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Sales Representative', 'Magazinweg 7', 'Frankfurt a.M.', None, '60528', 'Germany', '069-0245984', '069-0245874'),
#  ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Owner', '87 Polk St. Suite 5', 'San Francisco', 'CA', '94117', 'USA', '(415) 555-5938', None),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 'Sales Manager', '89 Chiaroscuro Rd.', 'Portland', 'OR', '97219', 'USA', '(503) 555-9573', '(503) 555-9646'),
#  ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Marketing Assistant', 'Heerstr. 22', 'Leipzig', None, '04179', 'Germany', '0342-023176', None),
#  ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', 'Sales Representative', '2743 Bering St.', 'Anchorage', 'AK', '99508', 'USA', '(907) 555-7584', '(907) 555-2880'),
#  ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Owner', 'Mehrheimerstr. 369', 'Köln', None, '50739', 'Germany', '0221-0644327', '0221-0765721'),
#  ('PARIS', 'Paris spécialités', 'Marie Bertrand', 'Owner', '265, boulevard Charonne', 'Paris', None, '75012', 'France', '(1) 42.34.22.66', '(1) 42.34.22.77'),
#  ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Accounting Manager', 'Taucherstraße 10', 'Cunewalde', None, '01307', 'Germany', '0372-035188', None),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', 'Assistant Sales Representative', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA', '(505) 555-5939', '(505) 555-3620'),
#  ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Sales Representative', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', None),
#  ('SPECD', 'Spécialités du monde', 'Dominique Perrier', 'Marketing Manager', '25, rue Lauriston', 'Paris', None, '75016', 'France', '(1) 47.55.60.10', '(1) 47.55.60.20'),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525'),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Marketing Manager', '89 Jefferson Way Suite 2', 'Portland', 'OR', '97201', 'USA', '(503) 555-3612', None),
#  ('THECR', 'The Cracker Box', 'Liu Wong', 'Marketing Assistant', '55 Grizzly Peak Rd.', 'Butte', 'MT', '59801', 'USA', '(406) 555-5834', '(406) 555-8083'),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany', '0251-031259', '0251-035695'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Sales Associate', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'USA', '(206) 555-8257', '(206) 555-2174'),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'Sales Agent', '2, rue du Commerce', 'Lyon', None, '69004', 'France', '78.32.54.86', '78.32.54.87'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11'),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Sales Representative', 'Adenauerallee 900', 'Stuttgart', None, '70563', 'Germany', '0711-020361', '0711-035428'),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115')]

# %% [markdown]
# ### Exercise 21
# #### Write a SELECT statement to get all customers from the same countries as the suppliers:

# %%
# %%sql
# SELECT * FROM Customers
# WHERE Country IN (SELECT Country FROM Suppliers);
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Tom B. Erichsen', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545'),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Tom B. Erichsen', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', None, '68306', 'Germany', '0621-08460', '0621-08924'),
#  ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', 'Marketing Manager', '24, place Kléber', 'Strasbourg', None, '67000', 'France', '88.60.15.31', '88.60.15.32'),
#  ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', 'Owner', 'C/ Araquil, 67', 'Madrid', None, '28023', 'Spain', '(91) 555 22 82', '(91) 555 91 99'),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 'Owner', '12, rue des Bouchers', 'Marseille', None, '13008', 'France', '91.24.45.40', '91.24.45.41'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Accounting Manager', '23 Tsawassen Blvd.', 'Tsawassen', 'BC', 'T2F 8M4', 'Canada', '(604) 555-4729', '(604) 555-3745'),
#  ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None),
#  ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', 'Sales Associate', 'Av. dos Lusíadas, 23', 'Sao Paulo', 'SP', '05432-043', 'Brazil', '(11) 555-7647', None),
#  ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199'),
#  ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Order Administrator', 'Walserweg 21', 'Aachen', None, '52066', 'Germany', '0241-039123', '0241-059428'),
#  ('DUMON', 'Du monde entier', 'Janine Labrune', 'Owner', '67, rue des Cinquante Otages', 'Nantes', None, '44000', 'France', '40.67.88.88', '40.67.89.89'),
#  ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'),
#  ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Marketing Assistant', 'Rua Orós, 92', 'Sao Paulo', 'SP', '05442-030', 'Brazil', '(11) 555-9857', None),
#  ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'Accounting Manager', 'C/ Moralzarzal, 86', 'Madrid', None, '28034', 'Spain', '(91) 555 94 44', '(91) 555 55 93'),
#  ('FOLIG', 'Folies gourmandes', 'Martine Rancé', 'Assistant Sales Agent', '184, chaussée de Tournai', 'Lille', None, '59000', 'France', '20.16.10.16', '20.16.10.17'),
#  ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Owner', 'Åkergatan 24', 'Bräcke', None, 'S-844 67', 'Sweden', '0695-34 67 21', None),
#  ('FRANK', 'Frankenversand', 'Peter Franken', 'Marketing Manager', 'Berliner Platz 43', 'München', None, '80805', 'Germany', '089-0877310', '089-0877451'),
#  ('FRANR', 'France restauration', 'Carine Schmitt', 'Marketing Manager', '54, rue Royale', 'Nantes', None, '44000', 'France', '40.32.21.21', '40.32.21.20'),
#  ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Sales Representative', 'Via Monte Bianco 34', 'Torino', None, '10100', 'Italy', '011-4988260', '011-4988261'),
#  ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Marketing Manager', 'Rambla de Cataluña, 23', 'Barcelona', None, '08022', 'Spain', '(93) 203 4560', '(93) 203 4561'),
#  ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'Sales Manager', 'C/ Romero, 33', 'Sevilla', None, '41101', 'Spain', '(95) 555 82 82', None),
#  ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Sales Associate', 'Av. Brasil, 442', 'Campinas', 'SP', '04876-786', 'Brazil', '(11) 555-9482', None),
#  ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 'Marketing Manager', '2732 Baker Blvd.', 'Eugene', 'OR', '97403', 'USA', '(503) 555-7555', None),
#  ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Accounting Manager', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil', '(21) 555-0091', '(21) 555-8765'),
#  ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'Sales Representative', 'City Center Plaza 516 Main St.', 'Elgin', 'OR', '97827', 'USA', '(503) 555-6874', '(503) 555-2376'),
#  ('ISLAT', 'Island Trading', 'Helen Bennett', 'Marketing Manager', 'Garden House Crowther Way', 'Cowes', 'Isle of Wight', 'PO31 7PJ', 'UK', '(198) 555-8888', None),
#  ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Sales Associate', 'Maubelstr. 90', 'Brandenburg', None, '14776', 'Germany', '0555-09876', None),
#  ('LACOR', "La corne d'abondance", 'Daniel Tonini', 'Sales Representative', "67, avenue de l'Europe", 'Versailles', None, '78000', 'France', '30.59.84.10', '30.59.85.11'),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', 'Marketing Assistant', '1900 Oak St.', 'Vancouver', 'BC', 'V3F 2K1', 'Canada', '(604) 555-3392', '(604) 555-7293'),
#  ('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Marketing Manager', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'USA', '(509) 555-7969', '(509) 555-6221'),
#  ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Sales Representative', 'Magazinweg 7', 'Frankfurt a.M.', None, '60528', 'Germany', '069-0245984', '069-0245874'),
#  ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Owner', '87 Polk St. Suite 5', 'San Francisco', 'CA', '94117', 'USA', '(415) 555-5938', None),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 'Sales Manager', '89 Chiaroscuro Rd.', 'Portland', 'OR', '97219', 'USA', '(503) 555-9573', '(503) 555-9646'),
#  ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Marketing Manager', 'Via Ludovico il Moro 22', 'Bergamo', None, '24100', 'Italy', '035-640230', '035-640231'),
#  ('MEREP', 'Mère Paillarde', 'Jean Fresnière', 'Marketing Assistant', '43 rue St. Laurent', 'Montréal', 'Québec', 'H1J 1C3', 'Canada', '(514) 555-8054', '(514) 555-8055'),
#  ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Marketing Assistant', 'Heerstr. 22', 'Leipzig', None, '04179', 'Germany', '0342-023176', None),
#  ('NORTS', 'North/South', 'Simon Crowther', 'Sales Associate', 'South House 300 Queensbridge', 'London', None, 'SW7 1RZ', 'UK', '(171) 555-7733', '(171) 555-2530'),
#  ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', 'Sales Representative', '2743 Bering St.', 'Anchorage', 'AK', '99508', 'USA', '(907) 555-7584', '(907) 555-2880'),
#  ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Owner', 'Mehrheimerstr. 369', 'Köln', None, '50739', 'Germany', '0221-0644327', '0221-0765721'),
#  ('PARIS', 'Paris spécialités', 'Marie Bertrand', 'Owner', '265, boulevard Charonne', 'Paris', None, '75012', 'France', '(1) 42.34.22.66', '(1) 42.34.22.77'),
#  ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Accounting Manager', 'Rua da Panificadora, 12', 'Rio de Janeiro', 'RJ', '02389-673', 'Brazil', '(21) 555-4252', '(21) 555-4545'),
#  ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Marketing Assistant', 'Alameda dos Canàrios, 891', 'Sao Paulo', 'SP', '05487-020', 'Brazil', '(11) 555-1189', None),
#  ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Accounting Manager', 'Taucherstraße 10', 'Cunewalde', None, '01307', 'Germany', '0372-035188', None),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', 'Assistant Sales Representative', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA', '(505) 555-5939', '(505) 555-3620'),
#  ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Sales Associate', 'Strada Provinciale 124', 'Reggio Emilia', None, '42100', 'Italy', '0522-556721', '0522-556722'),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Assistant Sales Agent', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brazil', '(21) 555-3412', None),
#  ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Accounting Manager', 'Gran Vía, 1', 'Madrid', None, '28001', 'Spain', '(91) 745 6200', '(91) 745 6210'),
#  ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Owner', 'Erling Skakkes gate 78', 'Stavern', None, '4110', 'Norway', '07-98 92 35', '07-98 92 47'),
#  ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Sales Representative', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', None),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Owner', 'Vinbæltet 34', 'Kobenhavn', None, '1734', 'Denmark', '31 12 34 56', '31 13 35 57'),
#  ('SPECD', 'Spécialités du monde', 'Dominique Perrier', 'Marketing Manager', '25, rue Lauriston', 'Paris', None, '75016', 'France', '(1) 47.55.60.10', '(1) 47.55.60.20'),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525'),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Marketing Manager', '89 Jefferson Way Suite 2', 'Portland', 'OR', '97201', 'USA', '(503) 555-3612', None),
#  ('THECR', 'The Cracker Box', 'Liu Wong', 'Marketing Assistant', '55 Grizzly Peak Rd.', 'Butte', 'MT', '59801', 'USA', '(406) 555-5834', '(406) 555-8083'),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany', '0251-031259', '0251-035695'),
#  ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Sales Representative', 'Av. Inês de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brazil', '(11) 555-2167', '(11) 555-2168'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Sales Associate', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'USA', '(206) 555-8257', '(206) 555-2174'),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Sales Manager', 'Smagsloget 45', 'Århus', None, '8200', 'Denmark', '86 21 32 43', '86 22 33 44'),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'Sales Agent', '2, rue du Commerce', 'Lyon', None, '69004', 'France', '78.32.54.86', '78.32.54.87'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11'),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Sales Representative', 'Adenauerallee 900', 'Stuttgart', None, '70563', 'Germany', '0711-020361', '0711-035428'),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Accounting Manager', 'Torikatu 38', 'Oulu', None, '90110', 'Finland', '981-443655', '981-443655'),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Sales Manager', 'Rua do Mercado, 12', 'Resende', 'SP', '08737-363', 'Brazil', '(14) 555-8122', None),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115'),
#  ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Owner/Marketing Assistant', 'Keskuskatu 45', 'Helsinki', None, '21240', 'Finland', '90-224 8858', '90-224 8858'),
#  ('CARTO', 'Cardinal', 'Tom B. Erichsen', 'Owner', 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('BARCAS', 'Barcelona CF', 'Lionel Messi', None, 'Camp Nou', 'Barcelona', None, '8028', 'Spain', None, None),
#  ('CART1', 'TheCADS', 'Mehdi', None, 'Skagen 21', 'Stavanger', None, '4040', 'Norway', None, None),
#  ('CART2', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, 'Norway', None, None),
#  ('CART001', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('CART002', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, 'Norway', None, None)]

# %% [markdown]
# ## SQL BETWEEN Operator

# %% [markdown]
# #### The BETWEEN operator selects values within a given range.
# ##### The BETWEEN operator is inclusive: begin and end values are included. The values can be numbers, text, or dates.

# %% [markdown]
# ### BETWEEN Syntax
# <code>SELECT column_name(s)
# FROM table_name
# WHERE column_name BETWEEN value1 AND value2;</code>

# %% [markdown]
# ### Exercise 22
# #### Write a SELECT statement to get all products with a price BETWEEN 5 and 15:

# %%
# %%sql
# SELECT *
# FROM Products
# WHERE Unitprice BETWEEN 5 AND 15 limit 10;
# Out:
#  * sqlite:///northwind.db
# Done.
# [(3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10, 13, 70, 25, 0, None),
#  (13, 'Konbu', 6, 8, '2 kg box', 6, 24, 0, 5, 0, None),
#  (19, 'Teatime Chocolate Biscuits', 8, 3, '10 boxes x 12 pieces', 9.2, 25, 0, 5, 0, None),
#  (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10, 3, 40, 5, 0, None),
#  (23, 'Tunnbröd', 9, 5, '12 - 250 g pkgs.', 9, 61, 0, 25, 0, None),
#  (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14, 76, 0, 30, 0, None),
#  (31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 12.5, 0, 70, 20, 0, None),
#  (34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14, 111, 0, 15, 0, None),
#  (41, "Jack's New England Clam Chowder", 19, 8, '12 - 12 oz cans', 9.65, 85, 0, 10, 0, None),
#  (42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14, 26, 0, 0, 1, '1996-07-04 00:00:00')]

# %% [markdown]
# ### Exercise 23
# #### Write a SELECT statement to get all products that their price are not BETWEEN 5 and 15, and their CategoryID are not 1,2, or 3 :

# %%
# %%sql
# SELECT *
# FROM Products
# WHERE (Unitprice NOT BETWEEN 5 AND 15 and CategoryID NOT IN (1,2,3));
# Out:
#  * sqlite:///northwind.db
# Done.
# [(7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30, 15, 0, 10, 0, None),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97, 29, 0, 0, 1, '1996-07-04 00:00:00'),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31, 31, 0, 0, 0, None),
#  (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21, 22, 30, 30, 0, None),
#  (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38, 86, 0, 0, 0, None),
#  (14, 'Tofu', 6, 7, '40 - 100 g pkgs.', 23.25, 35, 0, 0, 0, None),
#  (17, 'Alice Mutton', 7, 6, '20 - 1 kg tins', 39, 0, 0, 0, 1, '1996-07-04 00:00:00'),
#  (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62.5, 42, 0, 0, 0, None),
#  (22, "Gustaf's Knäckebröd", 9, 5, '24 - 500 g pkgs.', 21, 104, 0, 25, 0, None),
#  (28, 'Rössle Sauerkraut', 12, 7, '25 - 825 g cans', 45.6, 26, 0, 0, 1, '1996-07-04 00:00:00'),
#  (29, 'Thüringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123.79, 0, 0, 0, 1, '1996-07-04 00:00:00'),
#  (30, 'Nord-Ost Matjeshering', 13, 8, '10 - 200 g glasses', 25.89, 10, 0, 15, 0, None),
#  (32, 'Mascarpone Fabioli', 14, 4, '24 - 200 g pkgs.', 32, 9, 40, 25, 0, None),
#  (33, 'Geitost', 15, 4, '500 g', 2.5, 112, 0, 20, 0, None),
#  (36, 'Inlagd Sill', 17, 8, '24 - 250 g  jars', 19, 112, 0, 20, 0, None),
#  (37, 'Gravad lax', 17, 8, '12 - 500 g pkgs.', 26, 11, 50, 25, 0, None),
#  (40, 'Boston Crab Meat', 19, 8, '24 - 4 oz tins', 18.4, 123, 0, 30, 0, None),
#  (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53, 20, 0, 10, 0, None),
#  (53, 'Perth Pasties', 24, 6, '48 pieces', 32.8, 0, 0, 0, 1, '1996-07-04 00:00:00'),
#  (55, 'Pâté chinois', 25, 6, '24 boxes x 2 pies', 24, 115, 0, 20, 0, None),
#  (56, 'Gnocchi di nonna Alice', 26, 5, '24 - 250 g pkgs.', 38, 21, 10, 30, 0, None),
#  (57, 'Ravioli Angelo', 26, 5, '24 - 250 g pkgs.', 19.5, 36, 0, 20, 0, None),
#  (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55, 79, 0, 0, 0, None),
#  (60, 'Camembert Pierrot', 28, 4, '15 - 300 g rounds', 34, 19, 0, 0, 0, None),
#  (64, 'Wimmers gute Semmelknödel', 12, 5, '20 bags x 4 pieces', 33.25, 22, 80, 30, 0, None),
#  (69, 'Gudbrandsdalsost', 15, 4, '10 kg pkg.', 36, 26, 0, 15, 0, None),
#  (71, 'Flotemysost', 15, 4, '10 - 500 g pkgs.', 21.5, 26, 0, 0, 0, None),
#  (72, 'Mozzarella di Giovanni', 14, 4, '24 - 200 g pkgs.', 34.8, 14, 0, 0, 0, None)]

# %% [markdown]
# ### Exercise 24
# #### Write a query to SELECT all orders with an OrderDate BETWEEN '16-July-1996' and '01-August-1996':

# %%
# %%sql
# SELECT *
# FROM Orders LIMIT 1;
# Out:
#  * sqlite:///northwind.db
# Done.
# [(10248, 'VINET', 5, '1996-07-04 00:00:00', '1996-08-01 00:00:00', '1996-07-16 00:00:00', 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France')]

# %%
# %%sql
# SELECT *
# FROM Orders
# WHERE OrderDate BETWEEN '1996-07-16' AND '1996-08-01';
# Out:
#  * sqlite:///northwind.db
# Done.
# [(10257, 'HILAA', 4, '1996-07-16 00:00:00', '1996-08-13 00:00:00', '1996-07-22 00:00:00', 81.91, 'HILARION-Abastos', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', 'Táchira', '5022', 'Venezuela'),
#  (10258, 'ERNSH', 1, '1996-07-17 00:00:00', '1996-08-14 00:00:00', '1996-07-23 00:00:00', 140.51, 'Ernst Handel', 'Kirchgasse 6', 'Graz', None, '8010', 'Austria'),
#  (10259, 'CENTC', 4, '1996-07-18 00:00:00', '1996-08-15 00:00:00', '1996-07-25 00:00:00', 3.25, 'Centro comercial Moctezuma', 'Sierras de Granada 9993', 'México D.F.', None, '05022', 'Mexico'),
#  (10260, 'OTTIK', 4, '1996-07-19 00:00:00', '1996-08-16 00:00:00', '1996-07-29 00:00:00', 55.09, 'Ottilies Käseladen', 'Mehrheimerstr. 369', 'Köln', None, '50739', 'Germany'),
#  (10261, 'QUEDE', 4, '1996-07-19 00:00:00', '1996-08-16 00:00:00', '1996-07-30 00:00:00', 3.05, 'Que Delícia', 'Rua da Panificadora, 12', 'Rio de Janeiro', 'RJ', '02389-673', 'Brazil'),
#  (10262, 'RATTC', 8, '1996-07-22 00:00:00', '1996-08-19 00:00:00', '1996-07-25 00:00:00', 48.29, 'Rattlesnake Canyon Grocery', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA'),
#  (10263, 'ERNSH', 9, '1996-07-23 00:00:00', '1996-08-20 00:00:00', '1996-07-31 00:00:00', 146.06, 'Ernst Handel', 'Kirchgasse 6', 'Graz', None, '8010', 'Austria'),
#  (10264, 'FOLKO', 6, '1996-07-24 00:00:00', '1996-08-21 00:00:00', '1996-08-23 00:00:00', 3.67, 'Folk och fä HB', 'Åkergatan 24', 'Bräcke', None, 'S-844 67', 'Sweden'),
#  (10265, 'BLONP', 2, '1996-07-25 00:00:00', '1996-08-22 00:00:00', '1996-08-12 00:00:00', 55.28, 'Blondel père et fils', '24, place Kléber', 'Strasbourg', None, '67000', 'France'),
#  (10266, 'WARTH', 3, '1996-07-26 00:00:00', '1996-09-06 00:00:00', '1996-07-31 00:00:00', 25.73, 'Wartian Herkku', 'Torikatu 38', 'Oulu', None, '90110', 'Finland'),
#  (10267, 'FRANK', 4, '1996-07-29 00:00:00', '1996-08-26 00:00:00', '1996-08-06 00:00:00', 208.58, 'Frankenversand', 'Berliner Platz 43', 'München', None, '80805', 'Germany'),
#  (10268, 'GROSR', 8, '1996-07-30 00:00:00', '1996-08-27 00:00:00', '1996-08-02 00:00:00', 66.29, 'GROSELLA-Restaurante', '5ª Ave. Los Palos Grandes', 'Caracas', 'DF', '1081', 'Venezuela'),
#  (10269, 'WHITC', 5, '1996-07-31 00:00:00', '1996-08-14 00:00:00', '1996-08-09 00:00:00', 4.56, 'White Clover Markets', '1029 - 12th Ave. S.', 'Seattle', 'WA', '98124', 'USA')]

# %% [markdown]
# ## SQL Aliases

# %% [markdown]
# #### SQL aliases are used to give a table, or a column in a table, a temporary name. You can use aliases to make your column names more readable.
# #### Look at this example:

# %%
# %%sql
# SELECT CustomerID as ID, CompanyName as Customer
# FROM Customers;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados'),
#  ('ANTON', 'Antonio Moreno Taquería'),
#  ('AROUT', 'Around the Horn'),
#  ('BERGS', 'Berglunds snabbköp'),
#  ('BLAUS', 'Blauer See Delikatessen'),
#  ('BLONP', 'Blondesddsl père et fils'),
#  ('BOLID', 'Bólido Comidas preparadas'),
#  ('BONAP', "Bon app'"),
#  ('BOTTM', 'Bottom-Dollar Markets'),
#  ('BSBEV', "B's Beverages"),
#  ('CACTU', 'Cactus Comidas para llevar'),
#  ('CENTC', 'Centro comercial Moctezuma'),
#  ('CHOPS', 'Chop-suey Chinese'),
#  ('COMMI', 'Comércio Mineiro'),
#  ('CONSH', 'Consolidated Holdings'),
#  ('DRACD', 'Drachenblut Delikatessen'),
#  ('DUMON', 'Du monde entier'),
#  ('EASTC', 'Eastern Connection'),
#  ('ERNSH', 'Ernst Handel'),
#  ('FAMIA', 'Familia Arquibaldo'),
#  ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.'),
#  ('FOLIG', 'Folies gourmandes'),
#  ('FOLKO', 'Folk och fä HB'),
#  ('FRANK', 'Frankenversand'),
#  ('FRANR', 'France restauration'),
#  ('FRANS', 'Franchi S.p.A.'),
#  ('FURIB', 'Furia Bacalhau e Frutos do Mar'),
#  ('GALED', 'Galería del gastrónomo'),
#  ('GODOS', 'Godos Cocina Típica'),
#  ('GOURL', 'Gourmet Lanchonetes'),
#  ('GREAL', 'Great Lakes Food Market'),
#  ('GROSR', 'GROSELLA-Restaurante'),
#  ('HANAR', 'Hanari Carnes'),
#  ('HILAA', 'HILARION-Abastos'),
#  ('HUNGC', 'Hungry Coyote Import Store'),
#  ('HUNGO', 'Hungry Owl All-Night Grocers'),
#  ('ISLAT', 'Island Trading'),
#  ('KOENE', 'Königlich Essen'),
#  ('LACOR', "La corne d'abondance"),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars'),
#  ('LAZYK', 'Lazy K Kountry Store'),
#  ('LEHMS', 'Lehmanns Marktstand'),
#  ('LETSS', "Let's Stop N Shop"),
#  ('LILAS', 'LILA-Supermercado'),
#  ('LINOD', 'LINO-Delicateses'),
#  ('LONEP', 'Lonesome Pine Restaurant'),
#  ('MAGAA', 'Magazzini Alimentari Riuniti'),
#  ('MAISD', 'Maison Dewey'),
#  ('MEREP', 'Mère Paillarde'),
#  ('MORGK', 'Morgenstern Gesundkost'),
#  ('NORTS', 'North/South'),
#  ('OCEAN', 'Océano Atlántico Ltda.'),
#  ('OLDWO', 'Old World Delicatessen'),
#  ('OTTIK', 'Ottilies Käseladen'),
#  ('PARIS', 'Paris spécialités'),
#  ('PERIC', 'Pericles Comidas clásicas'),
#  ('PICCO', 'Piccolo und mehr'),
#  ('PRINI', 'Princesa Isabel Vinhos'),
#  ('QUEDE', 'Que Delícia'),
#  ('QUEEN', 'Queen Cozinha'),
#  ('QUICK', 'QUICK-Stop'),
#  ('RANCH', 'Rancho grande'),
#  ('RATTC', 'Rattlesnake Canyon Grocery'),
#  ('REGGC', 'Reggiani Caseifici'),
#  ('RICAR', 'Ricardo Adocicados'),
#  ('RICSU', 'Richter Supermarkt'),
#  ('ROMEY', 'Romero y tomillo'),
#  ('SANTG', 'Santé Gourmet'),
#  ('SAVEA', 'Save-a-lot Markets'),
#  ('SEVES', 'Seven Seas Imports'),
#  ('SIMOB', 'Simons bistro'),
#  ('SPECD', 'Spécialités du monde'),
#  ('SPLIR', 'Split Rail Beer & Ale'),
#  ('SUPRD', 'Suprêmes délices'),
#  ('THEBI', 'The Big Cheese'),
#  ('THECR', 'The Cracker Box'),
#  ('TOMSP', 'Toms Spezialitäten'),
#  ('TORTU', 'Tortuga Restaurante'),
#  ('TRADH', 'Tradição Hipermercados'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners"),
#  ('VAFFE', 'Vaffeljernet'),
#  ('VICTE', 'Victuailles en stock'),
#  ('VINET', 'Vins et alcools Chevalier'),
#  ('WANDK', 'Die Wandernde Kuh'),
#  ('WARTH', 'Wartian Herkku'),
#  ('WELLI', 'Wellington Importadora'),
#  ('WHITC', 'White Clover Markets'),
#  ('WILMK', 'Wilman Kala'),
#  ('WOLZA', 'Wolski Zajazd'),
#  ('CARTO', 'Cardinal'),
#  ('BARCAS', 'Barcelona CF'),
#  ('CART1', 'TheCADS'),
#  ('CART2', 'Cardinal'),
#  ('CART001', 'Cardinal'),
#  ('CART002', 'Cardinal')]

# %% [markdown]
# #### When an alias name consists of two or more parts, you should put it into square brackets.

# %%
# %%sql
# SELECT CustomerID as ID, ContactName as [Contact Person]
# FROM Customers;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Tom B. Erichsen'),
#  ('ANATR', 'Ana Trujillo'),
#  ('ANTON', 'Inigo Montoya'),
#  ('AROUT', 'Thomas Hardy'),
#  ('BERGS', 'Christina Berglund'),
#  ('BLAUS', 'Tom B. Erichsen'),
#  ('BLONP', 'Frédérique Citeaux'),
#  ('BOLID', 'Martín Sommer'),
#  ('BONAP', 'Laurence Lebihan'),
#  ('BOTTM', 'Elizabeth Lincoln'),
#  ('BSBEV', 'Victoria Ashworth'),
#  ('CACTU', 'Patricio Simpson'),
#  ('CENTC', 'Antonio Banderas'),
#  ('CHOPS', 'Yang Wang'),
#  ('COMMI', 'Pedro Afonso'),
#  ('CONSH', 'Elizabeth Brown'),
#  ('DRACD', 'Sven Ottlieb'),
#  ('DUMON', 'Janine Labrune'),
#  ('EASTC', 'Ann Devon'),
#  ('ERNSH', 'Roland Mendel'),
#  ('FAMIA', 'Aria Cruz'),
#  ('FISSA', 'Diego Roel'),
#  ('FOLIG', 'Martine Rancé'),
#  ('FOLKO', 'Maria Larsson'),
#  ('FRANK', 'Peter Franken'),
#  ('FRANR', 'Carine Schmitt'),
#  ('FRANS', 'Paolo Accorti'),
#  ('FURIB', 'Lino Rodriguez'),
#  ('GALED', 'Eduardo Saavedra'),
#  ('GODOS', 'José Pedro Freyre'),
#  ('GOURL', 'André Fonseca'),
#  ('GREAL', 'Howard Snyder'),
#  ('GROSR', 'Manuel Pereira'),
#  ('HANAR', 'Mario Pontes'),
#  ('HILAA', 'Carlos Hernández'),
#  ('HUNGC', 'Yoshi Latimer'),
#  ('HUNGO', 'Patricia McKenna'),
#  ('ISLAT', 'Helen Bennett'),
#  ('KOENE', 'Philip Cramer'),
#  ('LACOR', 'Daniel Tonini'),
#  ('LAUGB', 'Yoshi Tannamuri'),
#  ('LAZYK', 'John Steel'),
#  ('LEHMS', 'Renate Messner'),
#  ('LETSS', 'Jaime Yorres'),
#  ('LILAS', 'Carlos González'),
#  ('LINOD', 'Felipe Izquierdo'),
#  ('LONEP', 'Fran Wilson'),
#  ('MAGAA', 'Giovanni Rovelli'),
#  ('MAISD', 'Catherine Dewey'),
#  ('MEREP', 'Jean Fresnière'),
#  ('MORGK', 'Alexander Feuer'),
#  ('NORTS', 'Simon Crowther'),
#  ('OCEAN', 'Yvonne Moncada'),
#  ('OLDWO', 'Rene Phillips'),
#  ('OTTIK', 'Henriette Pfalzheim'),
#  ('PARIS', 'Marie Bertrand'),
#  ('PERIC', 'Salma Hayek'),
#  ('PICCO', 'Georg Pipps'),
#  ('PRINI', 'Isabel de Castro'),
#  ('QUEDE', 'Bernardo Batista'),
#  ('QUEEN', 'Lúcia Carvalho'),
#  ('QUICK', 'Horst Kloss'),
#  ('RANCH', 'Sergio Gutiérrez'),
#  ('RATTC', 'Paula Wilson'),
#  ('REGGC', 'Maurizio Moroni'),
#  ('RICAR', 'Janete Limeira'),
#  ('RICSU', 'Michael Holz'),
#  ('ROMEY', 'Alejandra Camino'),
#  ('SANTG', 'Jonas Bergulfsen'),
#  ('SAVEA', 'Jose Pavarotti'),
#  ('SEVES', 'Hari Kumar'),
#  ('SIMOB', 'Jytte Petersen'),
#  ('SPECD', 'Dominique Perrier'),
#  ('SPLIR', 'Art Braunschweiger'),
#  ('SUPRD', 'Pascale Cartrain'),
#  ('THEBI', 'Liz Nixon'),
#  ('THECR', 'Liu Wong'),
#  ('TOMSP', 'Karin Josephs'),
#  ('TORTU', 'Hugo Sanchis'),
#  ('TRADH', 'Anabela Domingues'),
#  ('TRAIH', 'Helvetius Nagy'),
#  ('VAFFE', 'Palle Ibsen'),
#  ('VICTE', 'Mary Saveley'),
#  ('VINET', 'Paul Henriot'),
#  ('WANDK', 'Rita Müller'),
#  ('WARTH', 'Pirkko Koskitalo'),
#  ('WELLI', 'Paula Parente'),
#  ('WHITC', 'Karl Jablonski'),
#  ('WILMK', 'Matti Karttunen'),
#  ('WOLZA', 'Zbyszek Piestrzeniewicz'),
#  ('CARTO', 'Tom B. Erichsen'),
#  ('BARCAS', 'Lionel Messi'),
#  ('CART1', 'Mehdi'),
#  ('CART2', 'Tom B. Erichsen'),
#  ('CART001', 'Tom B. Erichsen'),
#  ('CART002', 'Tom B. Erichsen')]

# %% [markdown]
# #### We can merge some fields and then give them an alias name. Look at this example.

# %%
# %%sql
# SELECT CompanyName, printf('%s, %s, %s, %s',Address, PostalCode,City,Country) AS Address
# FROM Customers;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('Alfreds Futterkiste', 'Obere Str. 57, 12209, Berlin, Germany'),
#  ('Ana Trujillo Emparedados y helados', 'Avda. de la Constitución 2222, 05021, México D.F., Mexico'),
#  ('Antonio Moreno Taquería', 'Mataderos  2312, 05023, México D.F., Mexico'),
#  ('Around the Horn', '120 Hanover Sq., WA1 1DP, London, UK'),
#  ('Berglunds snabbköp', 'Berguvsvägen  8, S-958 22, Luleå, Sweden'),
#  ('Blauer See Delikatessen', 'Forsterstr. 57, 68306, Mannheim, Germany'),
#  ('Blondesddsl père et fils', '24, place Kléber, 67000, Strasbourg, France'),
#  ('Bólido Comidas preparadas', 'C/ Araquil, 67, 28023, Madrid, Spain'),
#  ("Bon app'", '12, rue des Bouchers, 13008, Marseille, France'),
#  ('Bottom-Dollar Markets', '23 Tsawassen Blvd., T2F 8M4, Tsawassen, Canada'),
#  ("B's Beverages", 'Fauntleroy Circus, EC2 5NT, London, UK'),
#  ('Cactus Comidas para llevar', 'Cerrito 333, 1010, Buenos Aires, Argentina'),
#  ('Centro comercial Moctezuma', 'Sierras de Granada 9993, 05022, México D.F., Mexico'),
#  ('Chop-suey Chinese', 'Hauptstr. 29, 3012, Bern, Switzerland'),
#  ('Comércio Mineiro', 'Av. dos Lusíadas, 23, 05432-043, Sao Paulo, Brazil'),
#  ('Consolidated Holdings', 'Berkeley Gardens 12  Brewery, WX1 6LT, London, UK'),
#  ('Drachenblut Delikatessen', 'Walserweg 21, 52066, Aachen, Germany'),
#  ('Du monde entier', '67, rue des Cinquante Otages, 44000, Nantes, France'),
#  ('Eastern Connection', '35 King George, WX3 6FW, London, UK'),
#  ('Ernst Handel', 'Kirchgasse 6, 8010, Graz, Austria'),
#  ('Familia Arquibaldo', 'Rua Orós, 92, 05442-030, Sao Paulo, Brazil'),
#  ('FISSA Fabrica Inter. Salchichas S.A.', 'C/ Moralzarzal, 86, 28034, Madrid, Spain'),
#  ('Folies gourmandes', '184, chaussée de Tournai, 59000, Lille, France'),
#  ('Folk och fä HB', 'Åkergatan 24, S-844 67, Bräcke, Sweden'),
#  ('Frankenversand', 'Berliner Platz 43, 80805, München, Germany'),
#  ('France restauration', '54, rue Royale, 44000, Nantes, France'),
#  ('Franchi S.p.A.', 'Via Monte Bianco 34, 10100, Torino, Italy'),
#  ('Furia Bacalhau e Frutos do Mar', 'Jardim das rosas n. 32, 1675, Lisboa, Portugal'),
#  ('Galería del gastrónomo', 'Rambla de Cataluña, 23, 08022, Barcelona, Spain'),
#  ('Godos Cocina Típica', 'C/ Romero, 33, 41101, Sevilla, Spain'),
#  ('Gourmet Lanchonetes', 'Av. Brasil, 442, 04876-786, Campinas, Brazil'),
#  ('Great Lakes Food Market', '2732 Baker Blvd., 97403, Eugene, USA'),
#  ('GROSELLA-Restaurante', '5ª Ave. Los Palos Grandes, 1081, Caracas, Venezuela'),
#  ('Hanari Carnes', 'Rua do Paço, 67, 05454-876, Rio de Janeiro, Brazil'),
#  ('HILARION-Abastos', 'Carrera 22 con Ave. Carlos Soublette #8-35, 5022, San Cristóbal, Venezuela'),
#  ('Hungry Coyote Import Store', 'City Center Plaza 516 Main St., 97827, Elgin, USA'),
#  ('Hungry Owl All-Night Grocers', '8 Johnstown Road, , Cork, Ireland'),
#  ('Island Trading', 'Garden House Crowther Way, PO31 7PJ, Cowes, UK'),
#  ('Königlich Essen', 'Maubelstr. 90, 14776, Brandenburg, Germany'),
#  ("La corne d'abondance", "67, avenue de l'Europe, 78000, Versailles, France"),
#  ('Laughing Bacchus Wine Cellars', '1900 Oak St., V3F 2K1, Vancouver, Canada'),
#  ('Lazy K Kountry Store', '12 Orchestra Terrace, 99362, Walla Walla, USA'),
#  ('Lehmanns Marktstand', 'Magazinweg 7, 60528, Frankfurt a.M., Germany'),
#  ("Let's Stop N Shop", '87 Polk St. Suite 5, 94117, San Francisco, USA'),
#  ('LILA-Supermercado', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo, 3508, Barquisimeto, Venezuela'),
#  ('LINO-Delicateses', 'Ave. 5 de Mayo Porlamar, 4980, I. de Margarita, Venezuela'),
#  ('Lonesome Pine Restaurant', '89 Chiaroscuro Rd., 97219, Portland, USA'),
#  ('Magazzini Alimentari Riuniti', 'Via Ludovico il Moro 22, 24100, Bergamo, Italy'),
#  ('Maison Dewey', 'Rue Joseph-Bens 532, B-1180, Bruxelles, Belgium'),
#  ('Mère Paillarde', '43 rue St. Laurent, H1J 1C3, Montréal, Canada'),
#  ('Morgenstern Gesundkost', 'Heerstr. 22, 04179, Leipzig, Germany'),
#  ('North/South', 'South House 300 Queensbridge, SW7 1RZ, London, UK'),
#  ('Océano Atlántico Ltda.', 'Ing. Gustavo Moncada 8585 Piso 20-A, 1010, Buenos Aires, Argentina'),
#  ('Old World Delicatessen', '2743 Bering St., 99508, Anchorage, USA'),
#  ('Ottilies Käseladen', 'Mehrheimerstr. 369, 50739, Köln, Germany'),
#  ('Paris spécialités', '265, boulevard Charonne, 75012, Paris, France'),
#  ('Pericles Comidas clásicas', 'Calle Dr. Jorge Cash 321, 05033, México D.F., Mexico'),
#  ('Piccolo und mehr', 'Geislweg 14, 5020, Salzburg, Austria'),
#  ('Princesa Isabel Vinhos', 'Estrada da saúde n. 58, 1756, Lisboa, Portugal'),
#  ('Que Delícia', 'Rua da Panificadora, 12, 02389-673, Rio de Janeiro, Brazil'),
#  ('Queen Cozinha', 'Alameda dos Canàrios, 891, 05487-020, Sao Paulo, Brazil'),
#  ('QUICK-Stop', 'Taucherstraße 10, 01307, Cunewalde, Germany'),
#  ('Rancho grande', 'Av. del Libertador 900, 1010, Buenos Aires, Argentina'),
#  ('Rattlesnake Canyon Grocery', '2817 Milton Dr., 87110, Albuquerque, USA'),
#  ('Reggiani Caseifici', 'Strada Provinciale 124, 42100, Reggio Emilia, Italy'),
#  ('Ricardo Adocicados', 'Av. Copacabana, 267, 02389-890, Rio de Janeiro, Brazil'),
#  ('Richter Supermarkt', 'Grenzacherweg 237, 1203, Genève, Switzerland'),
#  ('Romero y tomillo', 'Gran Vía, 1, 28001, Madrid, Spain'),
#  ('Santé Gourmet', 'Erling Skakkes gate 78, 4110, Stavern, Norway'),
#  ('Save-a-lot Markets', '187 Suffolk Ln., 83720, Boise, USA'),
#  ('Seven Seas Imports', '90 Wadhurst Rd., OX15 4NB, London, UK'),
#  ('Simons bistro', 'Vinbæltet 34, 1734, Kobenhavn, Denmark'),
#  ('Spécialités du monde', '25, rue Lauriston, 75016, Paris, France'),
#  ('Split Rail Beer & Ale', 'P.O. Box 555, 82520, Lander, USA'),
#  ('Suprêmes délices', 'Boulevard Tirou, 255, B-6000, Charleroi, Belgium'),
#  ('The Big Cheese', '89 Jefferson Way Suite 2, 97201, Portland, USA'),
#  ('The Cracker Box', '55 Grizzly Peak Rd., 59801, Butte, USA'),
#  ('Toms Spezialitäten', 'Luisenstr. 48, 44087, Münster, Germany'),
#  ('Tortuga Restaurante', 'Avda. Azteca 123, 05033, México D.F., Mexico'),
#  ('Tradição Hipermercados', 'Av. Inês de Castro, 414, 05634-030, Sao Paulo, Brazil'),
#  ("Trail's Head Gourmet Provisioners", '722 DaVinci Blvd., 98034, Kirkland, USA'),
#  ('Vaffeljernet', 'Smagsloget 45, 8200, Århus, Denmark'),
#  ('Victuailles en stock', '2, rue du Commerce, 69004, Lyon, France'),
#  ('Vins et alcools Chevalier', "59 rue de l'Abbaye, 51100, Reims, France"),
#  ('Die Wandernde Kuh', 'Adenauerallee 900, 70563, Stuttgart, Germany'),
#  ('Wartian Herkku', 'Torikatu 38, 90110, Oulu, Finland'),
#  ('Wellington Importadora', 'Rua do Mercado, 12, 08737-363, Resende, Brazil'),
#  ('White Clover Markets', '305 - 14th Ave. S. Suite 3B, 98128, Seattle, USA'),
#  ('Wilman Kala', 'Keskuskatu 45, 21240, Helsinki, Finland'),
#  ('Wolski Zajazd', 'ul. Filtrowa 68, 01-012, Warszawa, Poland'),
#  ('Cardinal', 'Skagen 21, 4006, Stavanger, Norway'),
#  ('Barcelona CF', 'Camp Nou, 8028, Barcelona, Spain'),
#  ('TheCADS', 'Skagen 21, 4040, Stavanger, Norway'),
#  ('Cardinal', 'Stavanger, , 4006, Norway'),
#  ('Cardinal', 'Skagen 21, 4006, Stavanger, Norway'),
#  ('Cardinal', 'Stavanger, , 4006, Norway')]

# %% [markdown]
# #### We also can use alias names for our tables, look at the example.
# /*selects all the orders of the Around the Horn company*/

# %%
# %%sql
# SELECT o.OrderID, o.OrderDate, c.CompanyName
# FROM Customers AS c, Orders AS o
# WHERE c.CompanyName="Around the Horn" AND c.CustomerID=o.CustomerID;
# Out:
#  * sqlite:///northwind.db
# Done.
# [(10355, '1996-11-15 00:00:00', 'Around the Horn'),
#  (10383, '1996-12-16 00:00:00', 'Around the Horn'),
#  (10453, '1997-02-21 00:00:00', 'Around the Horn'),
#  (10558, '1997-06-04 00:00:00', 'Around the Horn'),
#  (10707, '1997-10-16 00:00:00', 'Around the Horn'),
#  (10741, '1997-11-14 00:00:00', 'Around the Horn'),
#  (10743, '1997-11-17 00:00:00', 'Around the Horn'),
#  (10768, '1997-12-08 00:00:00', 'Around the Horn'),
#  (10793, '1997-12-24 00:00:00', 'Around the Horn'),
#  (10864, '1998-02-02 00:00:00', 'Around the Horn'),
#  (10920, '1998-03-03 00:00:00', 'Around the Horn'),
#  (10953, '1998-03-16 00:00:00', 'Around the Horn'),
#  (11016, '1998-04-10 00:00:00', 'Around the Horn')]

# %%
# %%sql
# SELECT o.OrderID, o.OrderDate, c.CompanyName
# FROM Customers AS c
# INNER JOIN Orders as o
# ON c.CustomerID=o.CustomerID
# WHERE c.CompanyName="Around the Horn"
# Out:
#  * sqlite:///northwind.db
# Done.
# [(10355, '1996-11-15 00:00:00', 'Around the Horn'),
#  (10383, '1996-12-16 00:00:00', 'Around the Horn'),
#  (10453, '1997-02-21 00:00:00', 'Around the Horn'),
#  (10558, '1997-06-04 00:00:00', 'Around the Horn'),
#  (10707, '1997-10-16 00:00:00', 'Around the Horn'),
#  (10741, '1997-11-14 00:00:00', 'Around the Horn'),
#  (10743, '1997-11-17 00:00:00', 'Around the Horn'),
#  (10768, '1997-12-08 00:00:00', 'Around the Horn'),
#  (10793, '1997-12-24 00:00:00', 'Around the Horn'),
#  (10864, '1998-02-02 00:00:00', 'Around the Horn'),
#  (10920, '1998-03-03 00:00:00', 'Around the Horn'),
#  (10953, '1998-03-16 00:00:00', 'Around the Horn'),
#  (11016, '1998-04-10 00:00:00', 'Around the Horn')]

# %% [markdown]
# ## SQL JOIN

# %% [markdown]
# #### A JOIN clause is used to combine rows from two or more tables, based on a related column between them. Let's look at a selection from the "Orders" table:

# %% [markdown]
# <table>
#   <tbody><tr>
#     <th style="width:15%">OrderID</th>
#     <th>CustomerID</th>
#     <th>OrderDate</th>
#   </tr>
#   <tr>
#     <td>10308</td>
#     <td>VINET</td>
#     <td>1996-09-18</td>
#   </tr>
#   <tr>
#     <td>10309</td>
#     <td>TOMSP</td>
#     <td>1996-09-19</td>
#   </tr>
#   <tr>
#     <td>10310</td>
#     <td>HANAR</td>
#     <td>1996-09-20</td>
#   </tr>
# </tbody></table>

# %% [markdown]
# #### Then, look at a selection from the Custmers table:

# %% [markdown]
# <table> <tbody><tr> <th>CustomerID</th> <th>CompanyName</th> <th>ContactName</th> <th>Country</th> </tr> <tr> <td>ALFKI</td> <td>Alfreds Futterkiste</td> <td>Maria Anders</td> <td>Germany</td> </tr> <tr> <td>BLAUS</td> <td>Blauer See Delikatessen</td> <td>Hanna Moos</td> <td>Germany</td> </tr> <tr> <td>BLONP</td> <td>Blondesddsl père et fils</td> <td>Frédérique Citeaux</td> <td>France</td> </tr> <tr> <td>BONAP</td> <td>Bon app'</td> <td>Laurence Lebihan</td> <td>France</td> </tr> <tr> <td>DRACD</td> <td>Drachenblut Delikatessen</td> <td>Sven Ottlieb</td> <td>Germany</td> </tr> <tr> <td>DUMON</td> <td>Du monde entier</td> <td>Janine Labrune</td> <td>France</td> </tr> <tr> <td>FOLIG</td> <td>Folies gourmandes</td> <td>Martine Rancé</td> <td>France</td> </tr> </tbody></table>
#   </tr>
# </tbody></table>

# %% [markdown]
# #### Notice that the "CustomerID" column in the "Orders" table refers to the "CustomerID" in the "Customers" table. The relationship between the two tables above is the "CustomerID" column.
#
# #### Then, we can create the following SQL statement (that contains an INNER JOIN), that selects records that have matching values in both tables:

# %%
# %%sql
# SELECT c.CompanyName, o.OrderID, o.OrderDate
# FROM Orders as o INNER JOIN Customers as c
# ON o.CustomerID=c.CustomerID
# ORDER BY c.CompanyName
# Out:
#  * sqlite:///northwind.db
# Done.
# [('Alfreds Futterkiste', 10643, '1997-08-25 00:00:00'),
#  ('Alfreds Futterkiste', 10692, '1997-10-03 00:00:00'),
#  ('Alfreds Futterkiste', 10702, '1997-10-13 00:00:00'),
#  ('Alfreds Futterkiste', 10835, '1998-01-15 00:00:00'),
#  ('Alfreds Futterkiste', 10952, '1998-03-16 00:00:00'),
#  ('Alfreds Futterkiste', 11011, '1998-04-09 00:00:00'),
#  ('Ana Trujillo Emparedados y helados', 10308, '1996-09-18 00:00:00'),
#  ('Ana Trujillo Emparedados y helados', 10625, '1997-08-08 00:00:00'),
#  ('Ana Trujillo Emparedados y helados', 10759, '1997-11-28 00:00:00'),
#  ('Ana Trujillo Emparedados y helados', 10926, '1998-03-04 00:00:00'),
#  ('Berglunds snabbköp', 10875, '1998-02-06 00:00:00'),
#  ('Berglunds snabbköp', 10924, '1998-03-04 00:00:00'),
#  ('Blauer See Delikatessen', 10501, '1997-04-09 00:00:00'),
#  ('Blauer See Delikatessen', 10509, '1997-04-17 00:00:00'),
#  ('Blauer See Delikatessen', 10582, '1997-06-27 00:00:00'),
#  ('Blauer See Delikatessen', 10614, '1997-07-29 00:00:00'),
#  ('Blauer See Delikatessen', 10853, '1998-01-27 00:00:00'),
#  ('Blauer See Delikatessen', 10956, '1998-03-17 00:00:00'),
#  ('Blauer See Delikatessen', 11058, '1998-04-29 00:00:00'),
#  ('Blondesddsl père et fils', 10265, '1996-07-25 00:00:00'),
#  ('Blondesddsl père et fils', 10297, '1996-09-04 00:00:00'),
#  ('Blondesddsl père et fils', 10360, '1996-11-22 00:00:00'),
#  ('Blondesddsl père et fils', 10436, '1997-02-05 00:00:00'),
#  ('Blondesddsl père et fils', 10449, '1997-02-18 00:00:00'),
#  ('Blondesddsl père et fils', 10559, '1997-06-05 00:00:00'),
#  ('Blondesddsl père et fils', 10566, '1997-06-12 00:00:00'),
#  ('Blondesddsl père et fils', 10584, '1997-06-30 00:00:00'),
#  ('Blondesddsl père et fils', 10628, '1997-08-12 00:00:00'),
#  ('Blondesddsl père et fils', 10679, '1997-09-23 00:00:00'),
#  ('Blondesddsl père et fils', 10826, '1998-01-12 00:00:00'),
#  ("Bon app'", 10331, '1996-10-16 00:00:00'),
#  ("Bon app'", 10340, '1996-10-29 00:00:00'),
#  ("Bon app'", 10362, '1996-11-25 00:00:00'),
#  ("Bon app'", 10470, '1997-03-11 00:00:00'),
#  ("Bon app'", 10511, '1997-04-18 00:00:00'),
#  ("Bon app'", 10525, '1997-05-02 00:00:00'),
#  ("Bon app'", 10663, '1997-09-10 00:00:00'),
#  ("Bon app'", 10715, '1997-10-23 00:00:00'),
#  ("Bon app'", 10730, '1997-11-05 00:00:00'),
#  ("Bon app'", 10732, '1997-11-06 00:00:00'),
#  ("Bon app'", 10755, '1997-11-26 00:00:00'),
#  ("Bon app'", 10827, '1998-01-12 00:00:00'),
#  ("Bon app'", 10871, '1998-02-05 00:00:00'),
#  ("Bon app'", 10876, '1998-02-09 00:00:00'),
#  ("Bon app'", 10932, '1998-03-06 00:00:00'),
#  ("Bon app'", 10940, '1998-03-11 00:00:00'),
#  ("Bon app'", 11076, '1998-05-06 00:00:00'),
#  ('Bottom-Dollar Markets', 10389, '1996-12-20 00:00:00'),
#  ('Bottom-Dollar Markets', 10410, '1997-01-10 00:00:00'),
#  ('Bottom-Dollar Markets', 10411, '1997-01-10 00:00:00'),
#  ('Bottom-Dollar Markets', 10431, '1997-01-30 00:00:00'),
#  ('Bottom-Dollar Markets', 10492, '1997-04-01 00:00:00'),
#  ('Bottom-Dollar Markets', 10742, '1997-11-14 00:00:00'),
#  ('Bottom-Dollar Markets', 10918, '1998-03-02 00:00:00'),
#  ('Bottom-Dollar Markets', 10944, '1998-03-12 00:00:00'),
#  ('Bottom-Dollar Markets', 10949, '1998-03-13 00:00:00'),
#  ('Familia Arquibaldo', 10386, '1996-12-18 00:00:00'),
#  ('Familia Arquibaldo', 10414, '1997-01-14 00:00:00'),
#  ('Familia Arquibaldo', 10512, '1997-04-21 00:00:00'),
#  ('Familia Arquibaldo', 10581, '1997-06-26 00:00:00'),
#  ('Familia Arquibaldo', 10650, '1997-08-29 00:00:00'),
#  ('Familia Arquibaldo', 10725, '1997-10-31 00:00:00'),
#  ('Folies gourmandes', 10408, '1997-01-08 00:00:00'),
#  ('Folies gourmandes', 10480, '1997-03-20 00:00:00'),
#  ('Folies gourmandes', 10634, '1997-08-15 00:00:00'),
#  ('Folies gourmandes', 10763, '1997-12-03 00:00:00'),
#  ('Folies gourmandes', 10789, '1997-12-22 00:00:00'),
#  ('Folk och fä HB', 10264, '1996-07-24 00:00:00'),
#  ('Folk och fä HB', 10327, '1996-10-11 00:00:00'),
#  ('Folk och fä HB', 10378, '1996-12-10 00:00:00'),
#  ('Folk och fä HB', 10434, '1997-02-03 00:00:00'),
#  ('Folk och fä HB', 10460, '1997-02-28 00:00:00'),
#  ('Folk och fä HB', 10533, '1997-05-12 00:00:00'),
#  ('Folk och fä HB', 10561, '1997-06-06 00:00:00'),
#  ('Folk och fä HB', 10703, '1997-10-14 00:00:00'),
#  ('Folk och fä HB', 10762, '1997-12-02 00:00:00'),
#  ('Folk och fä HB', 10774, '1997-12-11 00:00:00'),
#  ('Folk och fä HB', 10824, '1998-01-09 00:00:00'),
#  ('Folk och fä HB', 10880, '1998-02-10 00:00:00'),
#  ('Folk och fä HB', 10902, '1998-02-23 00:00:00'),
#  ('Folk och fä HB', 10955, '1998-03-17 00:00:00'),
#  ('Folk och fä HB', 10977, '1998-03-26 00:00:00'),
#  ('Folk och fä HB', 10980, '1998-03-27 00:00:00'),
#  ('Folk och fä HB', 10993, '1998-04-01 00:00:00'),
#  ('Folk och fä HB', 11001, '1998-04-06 00:00:00'),
#  ('Folk och fä HB', 11050, '1998-04-27 00:00:00'),
#  ('France restauration', 10671, '1997-09-17 00:00:00'),
#  ('France restauration', 10860, '1998-01-29 00:00:00'),
#  ('France restauration', 10971, '1998-03-24 00:00:00'),
#  ('Franchi S.p.A.', 10422, '1997-01-22 00:00:00'),
#  ('Franchi S.p.A.', 10710, '1997-10-20 00:00:00'),
#  ('Franchi S.p.A.', 10753, '1997-11-25 00:00:00'),
#  ('Franchi S.p.A.', 10807, '1997-12-31 00:00:00'),
#  ('Franchi S.p.A.', 11026, '1998-04-15 00:00:00'),
#  ('Franchi S.p.A.', 11060, '1998-04-30 00:00:00'),
#  ('Frankenversand', 10267, '1996-07-29 00:00:00'),
#  ('Frankenversand', 10337, '1996-10-24 00:00:00'),
#  ('Frankenversand', 10342, '1996-10-30 00:00:00'),
#  ('Frankenversand', 10396, '1996-12-27 00:00:00'),
#  ('Frankenversand', 10488, '1997-03-27 00:00:00'),
#  ('Frankenversand', 10560, '1997-06-06 00:00:00'),
#  ('Frankenversand', 10623, '1997-08-07 00:00:00'),
#  ('Simons bistro', 10802, '1997-12-29 00:00:00'),
#  ('Simons bistro', 11074, '1998-05-06 00:00:00'),
#  ('Split Rail Beer & Ale', 10271, '1996-08-01 00:00:00'),
#  ('Split Rail Beer & Ale', 10329, '1996-10-15 00:00:00'),
#  ('Split Rail Beer & Ale', 10349, '1996-11-08 00:00:00'),
#  ('Split Rail Beer & Ale', 10369, '1996-12-02 00:00:00'),
#  ('Split Rail Beer & Ale', 10385, '1996-12-17 00:00:00'),
#  ('Split Rail Beer & Ale', 10432, '1997-01-31 00:00:00'),
#  ('Split Rail Beer & Ale', 10756, '1997-11-27 00:00:00'),
#  ('Split Rail Beer & Ale', 10821, '1998-01-08 00:00:00'),
#  ('Split Rail Beer & Ale', 10974, '1998-03-25 00:00:00'),
#  ('Spécialités du monde', 10738, '1997-11-12 00:00:00'),
#  ('Spécialités du monde', 10907, '1998-02-25 00:00:00'),
#  ('Spécialités du monde', 10964, '1998-03-20 00:00:00'),
#  ('Spécialités du monde', 11043, '1998-04-22 00:00:00'),
#  ('Suprêmes délices', 10252, '1996-07-09 00:00:00'),
#  ('Suprêmes délices', 10302, '1996-09-10 00:00:00'),
#  ('Suprêmes délices', 10458, '1997-02-26 00:00:00'),
#  ('Suprêmes délices', 10463, '1997-03-04 00:00:00'),
#  ('Suprêmes délices', 10475, '1997-03-14 00:00:00'),
#  ('Suprêmes délices', 10767, '1997-12-05 00:00:00'),
#  ('Suprêmes délices', 10841, '1998-01-20 00:00:00'),
#  ('Suprêmes délices', 10846, '1998-01-22 00:00:00'),
#  ('Suprêmes délices', 10885, '1998-02-12 00:00:00'),
#  ('Suprêmes délices', 10930, '1998-03-06 00:00:00'),
#  ('Suprêmes délices', 11035, '1998-04-20 00:00:00'),
#  ('Suprêmes délices', 11038, '1998-04-21 00:00:00'),
#  ('The Big Cheese', 10310, '1996-09-20 00:00:00'),
#  ('The Big Cheese', 10708, '1997-10-17 00:00:00'),
#  ('The Big Cheese', 10805, '1997-12-30 00:00:00'),
#  ('The Big Cheese', 10992, '1998-04-01 00:00:00'),
#  ('The Cracker Box', 10624, '1997-08-07 00:00:00'),
#  ('The Cracker Box', 10775, '1997-12-12 00:00:00'),
#  ('The Cracker Box', 11003, '1998-04-06 00:00:00'),
#  ('Toms Spezialitäten', 10249, '1996-07-05 00:00:00'),
#  ('Toms Spezialitäten', 10438, '1997-02-06 00:00:00'),
#  ('Toms Spezialitäten', 10446, '1997-02-14 00:00:00'),
#  ('Toms Spezialitäten', 10548, '1997-05-26 00:00:00'),
#  ('Toms Spezialitäten', 10608, '1997-07-23 00:00:00'),
#  ('Toms Spezialitäten', 10967, '1998-03-23 00:00:00'),
#  ('Tortuga Restaurante', 10276, '1996-08-08 00:00:00'),
#  ('Tortuga Restaurante', 10293, '1996-08-29 00:00:00'),
#  ('Tortuga Restaurante', 10304, '1996-09-12 00:00:00'),
#  ('Tortuga Restaurante', 10319, '1996-10-02 00:00:00'),
#  ('Tortuga Restaurante', 10518, '1997-04-25 00:00:00'),
#  ('Tortuga Restaurante', 10576, '1997-06-23 00:00:00'),
#  ('Tortuga Restaurante', 10676, '1997-09-22 00:00:00'),
#  ('Tortuga Restaurante', 10842, '1998-01-20 00:00:00'),
#  ('Tortuga Restaurante', 10915, '1998-02-27 00:00:00'),
#  ('Tortuga Restaurante', 11069, '1998-05-04 00:00:00'),
#  ('Tradição Hipermercados', 10292, '1996-08-28 00:00:00'),
#  ('Tradição Hipermercados', 10496, '1997-04-04 00:00:00'),
#  ('Tradição Hipermercados', 10606, '1997-07-22 00:00:00'),
#  ('Tradição Hipermercados', 10830, '1998-01-13 00:00:00'),
#  ('Tradição Hipermercados', 10834, '1998-01-15 00:00:00'),
#  ('Tradição Hipermercados', 10839, '1998-01-19 00:00:00'),
#  ("Trail's Head Gourmet Provisioners", 10574, '1997-06-19 00:00:00'),
#  ("Trail's Head Gourmet Provisioners", 10577, '1997-06-23 00:00:00'),
#  ("Trail's Head Gourmet Provisioners", 10822, '1998-01-08 00:00:00'),
#  ('Vaffeljernet', 10367, '1996-11-28 00:00:00'),
#  ('Vaffeljernet', 10399, '1996-12-31 00:00:00'),
#  ('Vaffeljernet', 10465, '1997-03-05 00:00:00'),
#  ('Vaffeljernet', 10591, '1997-07-07 00:00:00'),
#  ('Vaffeljernet', 10602, '1997-07-17 00:00:00'),
#  ('Vaffeljernet', 10688, '1997-10-01 00:00:00'),
#  ('Vaffeljernet', 10744, '1997-11-17 00:00:00'),
#  ('Vaffeljernet', 10769, '1997-12-08 00:00:00'),
#  ('Vaffeljernet', 10921, '1998-03-03 00:00:00'),
#  ('Vaffeljernet', 10946, '1998-03-12 00:00:00'),
#  ('Vaffeljernet', 10994, '1998-04-02 00:00:00'),
#  ('Victuailles en stock', 10251, '1996-07-08 00:00:00'),
#  ('Victuailles en stock', 10334, '1996-10-21 00:00:00'),
#  ('Victuailles en stock', 10450, '1997-02-19 00:00:00'),
#  ('Victuailles en stock', 10459, '1997-02-27 00:00:00'),
#  ('Victuailles en stock', 10478, '1997-03-18 00:00:00'),
#  ('Victuailles en stock', 10546, '1997-05-23 00:00:00'),
#  ('Victuailles en stock', 10806, '1997-12-31 00:00:00'),
#  ('Victuailles en stock', 10814, '1998-01-05 00:00:00'),
#  ('Victuailles en stock', 10843, '1998-01-21 00:00:00'),
#  ('Victuailles en stock', 10850, '1998-01-23 00:00:00'),
#  ('Vins et alcools Chevalier', 10248, '1996-07-04 00:00:00'),
#  ('Vins et alcools Chevalier', 10274, '1996-08-06 00:00:00'),
#  ('Vins et alcools Chevalier', 10295, '1996-09-02 00:00:00'),
#  ('Vins et alcools Chevalier', 10737, '1997-11-11 00:00:00'),
#  ('Vins et alcools Chevalier', 10739, '1997-11-12 00:00:00'),
#  ('Wartian Herkku', 10266, '1996-07-26 00:00:00'),
#  ('Wartian Herkku', 10270, '1996-08-01 00:00:00'),
#  ('Wartian Herkku', 10320, '1996-10-03 00:00:00'),
#  ('Wartian Herkku', 10333, '1996-10-18 00:00:00'),
#  ('Wartian Herkku', 10412, '1997-01-13 00:00:00'),
#  ('Wartian Herkku', 10416, '1997-01-16 00:00:00'),
#  ('Wartian Herkku', 10437, '1997-02-05 00:00:00'),
#  ('Wartian Herkku', 10455, '1997-02-24 00:00:00'),
#  ('Wartian Herkku', 10526, '1997-05-05 00:00:00'),
#  ('Wartian Herkku', 10553, '1997-05-30 00:00:00'),
#  ('Wartian Herkku', 10583, '1997-06-30 00:00:00'),
#  ('Wartian Herkku', 10636, '1997-08-19 00:00:00'),
#  ('Wartian Herkku', 10750, '1997-11-21 00:00:00'),
#  ('Wartian Herkku', 10781, '1997-12-17 00:00:00'),
#  ('Wartian Herkku', 11025, '1998-04-15 00:00:00'),
#  ('Wellington Importadora', 10256, '1996-07-15 00:00:00'),
#  ('Wellington Importadora', 10420, '1997-01-21 00:00:00'),
#  ('Wellington Importadora', 10585, '1997-07-01 00:00:00'),
#  ('Wellington Importadora', 10644, '1997-08-25 00:00:00'),
#  ('Wellington Importadora', 10803, '1997-12-30 00:00:00'),
#  ('Wellington Importadora', 10809, '1998-01-01 00:00:00'),
#  ('Wellington Importadora', 10900, '1998-02-20 00:00:00'),
#  ('Wellington Importadora', 10905, '1998-02-24 00:00:00'),
#  ('Wellington Importadora', 10935, '1998-03-09 00:00:00'),
#  ('White Clover Markets', 10269, '1996-07-31 00:00:00'),
#  ('White Clover Markets', 10344, '1996-11-01 00:00:00'),
#  ('White Clover Markets', 10469, '1997-03-10 00:00:00'),
#  ('White Clover Markets', 10483, '1997-03-24 00:00:00'),
#  ('White Clover Markets', 10504, '1997-04-11 00:00:00'),
#  ('White Clover Markets', 10596, '1997-07-11 00:00:00'),
#  ('White Clover Markets', 10693, '1997-10-06 00:00:00'),
#  ('White Clover Markets', 10696, '1997-10-08 00:00:00'),
#  ('White Clover Markets', 10723, '1997-10-30 00:00:00'),
#  ('White Clover Markets', 10740, '1997-11-13 00:00:00'),
#  ('White Clover Markets', 10861, '1998-01-30 00:00:00'),
#  ('White Clover Markets', 10904, '1998-02-24 00:00:00'),
#  ('White Clover Markets', 11032, '1998-04-17 00:00:00'),
#  ('White Clover Markets', 11066, '1998-05-01 00:00:00'),
#  ('Wilman Kala', 10615, '1997-07-30 00:00:00'),
#  ('Wilman Kala', 10673, '1997-09-18 00:00:00'),
#  ('Wilman Kala', 10695, '1997-10-07 00:00:00'),
#  ('Wilman Kala', 10873, '1998-02-06 00:00:00'),
#  ('Wilman Kala', 10879, '1998-02-10 00:00:00'),
#  ('Wilman Kala', 10910, '1998-02-26 00:00:00'),
#  ('Wilman Kala', 11005, '1998-04-07 00:00:00')]

# %%
# %%sql
# SELECT o.OrderID, c.CompanyName, o.OrderDate
# FROM Orders as o INNER JOIN Customers as c
# ON o.CustomerID=c.CustomerID
# WHERE c.CompanyName='Hanari Carnes';
# Out:
#  * sqlite:///northwind.db
# Done.
# [(10250, 'Hanari Carnes', '1996-07-08 00:00:00'),
#  (10253, 'Hanari Carnes', '1996-07-10 00:00:00'),
#  (10541, 'Hanari Carnes', '1997-05-19 00:00:00'),
#  (10645, 'Hanari Carnes', '1997-08-26 00:00:00'),
#  (10690, 'Hanari Carnes', '1997-10-02 00:00:00'),
#  (10770, 'Hanari Carnes', '1997-12-09 00:00:00'),
#  (10783, 'Hanari Carnes', '1997-12-18 00:00:00'),
#  (10886, 'Hanari Carnes', '1998-02-13 00:00:00'),
#  (10903, 'Hanari Carnes', '1998-02-24 00:00:00'),
#  (10922, 'Hanari Carnes', '1998-03-03 00:00:00'),
#  (10925, 'Hanari Carnes', '1998-03-04 00:00:00'),
#  (10981, 'Hanari Carnes', '1998-03-27 00:00:00'),
#  (11022, 'Hanari Carnes', '1998-04-14 00:00:00'),
#  (11052, 'Hanari Carnes', '1998-04-27 00:00:00')]

# %% [markdown]
# ## SQL INNER JOIN

# %% [markdown]
# #### This type of join selects rows that have matching values in both tables.

# %% [markdown]
# <img src="https://www.w3schools.com/sql/img_innerjoin.gif">

# %% [markdown]
# ##### The INNER JOIN keyword selects all rows from both tables as long as there is a match between the columns. If there are records in the "Orders" table that do not have matches in "Customers", these orders will not be shown!

# %%
# %sql select * from products limit 1
# Out:
#  * sqlite:///northwind.db
# Done.
# [(1, 'Chai', 1, 1, '10 boxes x 20 bags', 18, 39, 0, 10, 0, None)]

# %%
# %sql select * from suppliers limit 1
# Out:
#  * sqlite:///northwind.db
# Done.
# [(1, 'Exotic Liquids', 'Charlotte Cooper', 'Purchasing Manager', '49 Gilbert St.', 'London', None, 'EC1 4SD', 'UK', '(171) 555-2222', None, None)]

# %% [markdown]
# ### Exercise 25
# #### Write a SQL inner join statement to list all product's name of one supplier.

# %%
# %%sql
# SELECT p.ProductName, s.CompanyName as [Supplier Name]
# FROM Products as p INNER JOIN Suppliers as s
# ON p.SupplierID=s.SupplierID
# WHERE s.CompanyName='Exotic Liquids'
# Out:
#  * sqlite:///northwind.db
# Done.
# [('Chai', 'Exotic Liquids'),
#  ('Chang', 'Exotic Liquids'),
#  ('Aniseed Syrup', 'Exotic Liquids')]

# %% [markdown]
# ### Exercise 26
# #### Write a SQL statement to list all orders of each customer.

# %%
# %%sql
# SELECT *
# FROM Orders as o INNER JOIN Customers as c
# ON o.CustomerID=c.CustomerID
# LIMIT 10
# Out:
#  * sqlite:///northwind.db
# Done.
# [(10248, 'VINET', 5, '1996-07-04 00:00:00', '1996-08-01 00:00:00', '1996-07-16 00:00:00', 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', 'VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11'),
#  (10249, 'TOMSP', 6, '1996-07-05 00:00:00', '1996-08-16 00:00:00', '1996-07-10 00:00:00', 11.61, 'Toms Spezialitäten', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany', 'TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany', '0251-031259', '0251-035695'),
 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', 'Táchira', '5022', 'Venezuela', '(5) 555-1340', '(5) 555-1948')]

# %%
# %%sql
# SELECT p.ProductName, s.CompanyName as Supplier_Name
# FROM Products as p INNER JOIN Suppliers as s
# ON p.SupplierID=s.SupplierIDb
# WHERE s.CompanyName='Tokyo Traders'
# Out:
#  * sqlite:///northwind.db
# Done.
# [('Mishi Kobe Niku', 'Tokyo Traders'),
#  ('Ikura', 'Tokyo Traders'),
#  ('Longlife Tofu', 'Tokyo Traders')]

# %%
# %%sql
# SELECT c.CompanyName, count(o.OrderID) as [Number of Orders]
# FROM
# Orders as o INNER JOIN Customers as c
# ON o.CustomerID=c.CustomerID
# group by c.companyname
# ORDER BY [Number of Orders] desc
# Out:
#  * sqlite:///northwind.db
# Done.
# [('Save-a-lot Markets', 31),
#  ('Ernst Handel', 30),
#  ('QUICK-Stop', 28),
#  ('Folk och fä HB', 19),
#  ('Hungry Owl All-Night Grocers', 19),
#  ('Berglunds snabbköp', 18),
#  ('HILARION-Abastos', 18),
#  ('Rattlesnake Canyon Grocery', 18),
#  ("Bon app'", 17),
#  ('Frankenversand', 15),
#  ('Lehmanns Marktstand', 15),
#  ('Wartian Herkku', 15),
#  ('Bottom-Dollar Markets', 14),
#  ('Hanari Carnes', 14),
#  ('Königlich Essen', 14),
#  ('LILA-Supermercado', 14),
#  ('White Clover Markets', 14),
#  ('Around the Horn', 13),
#  ('Mère Paillarde', 13),
#  ('Queen Cozinha', 13),
#  ('LINO-Delicateses', 12),
#  ('Reggiani Caseifici', 12),
#  ('Suprêmes délices', 12),
#  ('Blondesddsl père et fils', 11),
#  ('Great Lakes Food Market', 11),
#  ('Ricardo Adocicados', 11),
#  ('Vaffeljernet', 11),
#  ("B's Beverages", 10),
#  ('Die Wandernde Kuh', 10),
#  ('Godos Cocina Típica', 10),
#  ('Island Trading', 10),
#  ('Magazzini Alimentari Riuniti', 10),
#  ('Old World Delicatessen', 10),
#  ('Ottilies Käseladen', 10),
#  ('Piccolo und mehr', 10),
#  ('Richter Supermarkt', 10),
#  ('Tortuga Restaurante', 10),
#  ('Victuailles en stock', 10),
#  ('Gourmet Lanchonetes', 9),
#  ('Que Delícia', 9),
#  ('Seven Seas Imports', 9),
#  ('Split Rail Beer & Ale', 9),
#  ('Wellington Importadora', 9),
#  ('Chop-suey Chinese', 8),
#  ('Eastern Connection', 8),
#  ('Furia Bacalhau e Frutos do Mar', 8),
#  ('Lonesome Pine Restaurant', 8),
#  ('Antonio Moreno Taquería', 7),
#  ('Blauer See Delikatessen', 7),
#  ('Familia Arquibaldo', 7),
#  ('Maison Dewey', 7),
#  ('Simons bistro', 7),
#  ('Wilman Kala', 7),
#  ('Alfreds Futterkiste', 6),
#  ('Cactus Comidas para llevar', 6),
#  ('Drachenblut Delikatessen', 6),
#  ('Franchi S.p.A.', 6),
#  ('Pericles Comidas clásicas', 6),
#  ('Santé Gourmet', 6),
#  ('Toms Spezialitäten', 6),
#  ('Tradição Hipermercados', 6),
#  ('Comércio Mineiro', 5),
#  ('Folies gourmandes', 5),
#  ('Galería del gastrónomo', 5),
#  ('Hungry Coyote Import Store', 5),
#  ('Morgenstern Gesundkost', 5),
#  ('Océano Atlántico Ltda.', 5),
#  ('Princesa Isabel Vinhos', 5),
#  ('Rancho grande', 5),
#  ('Romero y tomillo', 5),
#  ('Vins et alcools Chevalier', 5),
#  ('Ana Trujillo Emparedados y helados', 4),
#  ('Du monde entier', 4),
#  ("La corne d'abondance", 4),
#  ("Let's Stop N Shop", 4),
#  ('Spécialités du monde', 4),
#  ('The Big Cheese', 4),
#  ('Bólido Comidas preparadas', 3),
#  ('Consolidated Holdings', 3),
#  ('France restauration', 3),
#  ('Laughing Bacchus Wine Cellars', 3),
#  ('North/South', 3),
#  ('The Cracker Box', 3),
#  ("Trail's Head Gourmet Provisioners", 3),
#  ('GROSELLA-Restaurante', 2),
#  ('Lazy K Kountry Store', 2),
#  ('Centro comercial Moctezuma', 1)]

# %% [markdown]
# ## SQL LEFT JOIN

# %% [markdown]
# #### The LEFT JOIN keyword returns all records from the left table (table1), and the matched records from the right table (table2). The result is NULL from the right side, if there is no match.

# %% [markdown]
# ### LEFT JOIN Syntax
# <code>SELECT column_name(s)
# FROM table1 LEFT JOIN table2
# ON table1.column_name = table2.column_name;</code>

# %% [markdown]
# <img src="https://www.w3schools.com/sql/img_leftjoin.gif">

# %% [markdown]
# ### Exercise 27
# #### Write a SQL statement to select all customers, and any orders they might have.

# %%
# %%sql
# SELECT *
# FROM Customers limit 1
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Tom B. Erichsen', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545')]

# %%
# %%sql
# SELECT *
# FROM Orders limit 1
# Out:
#  * sqlite:///northwind.db
# Done.
# [(10248, 'VINET', 5, '1996-07-04 00:00:00', '1996-08-01 00:00:00', '1996-07-16 00:00:00', 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France')]

# %%
# %%sql
# SELECT *
# FROM Customers LEFT JOIN Orders
# ON Customers.CustomerID = Orders.CustomerID
# limit 5
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Tom B. Erichsen', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545', 10643, 'ALFKI', 6, '1997-08-25 00:00:00', '1997-09-22 00:00:00', '1997-09-02 00:00:00', 29.46, 'Alfreds Futterkiste', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany'),
#  ('ALFKI', 'Alfreds Futterkiste', 'Tom B. Erichsen', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545', 10692, 'ALFKI', 4, '1997-10-03 00:00:00', '1997-10-31 00:00:00', '1997-10-13 00:00:00', 61.02, "Alfred's Futterkiste", 'Obere Str. 57', 'Berlin', None, '12209', 'Germany'),
#  ('ALFKI', 'Alfreds Futterkiste', 'Tom B. Erichsen', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545', 10702, 'ALFKI', 4, '1997-10-13 00:00:00', '1997-11-24 00:00:00', '1997-10-21 00:00:00', 23.94, "Alfred's Futterkiste", 'Obere Str. 57', 'Berlin', None, '12209', 'Germany'),
#  ('ALFKI', 'Alfreds Futterkiste', 'Tom B. Erichsen', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545', 10835, 'ALFKI', 1, '1998-01-15 00:00:00', '1998-02-12 00:00:00', '1998-01-21 00:00:00', 69.53, "Alfred's Futterkiste", 'Obere Str. 57', 'Berlin', None, '12209', 'Germany'),
#  ('ALFKI', 'Alfreds Futterkiste', 'Tom B. Erichsen', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545', 10952, 'ALFKI', 1, '1998-03-16 00:00:00', '1998-04-27 00:00:00', '1998-03-24 00:00:00', 40.42, "Alfred's Futterkiste", 'Obere Str. 57', 'Berlin', None, '12209', 'Germany')]

# %% [markdown]
# ##### The LEFT JOIN keyword returns all records from the left table (Customers), even if there are no matches in the right table (Orders).

# %% [markdown]
# ## SQL RIGHT JOIN
# #### The RIGHT JOIN keyword returns all records from the right table (table2), and the matched records from the left table (table1). The result is NULL from the left side, when there is no match.

# %% [markdown]
# ### RIGHT JOIN Syntax

# %% [markdown]
# <code>SELECT column_name(s)
# FROM table1
# RIGHT JOIN table2 ON table1.column_name = table2.column_name;</code>

# %% [markdown]
# <img src="https://www.w3schools.com/sql/img_rightjoin.gif">

# %% [markdown]
# #### Write a SQL statement that return all employees, and any orders they might have placed.

# %%
# %%sql
# SELECT O.OrderID, E.LastName, E.FirstName
# FROM Orders as O RIGHT JOIN Employees as E
# ON O.EmployeeID = E.EmployeeID
# ORDER BY O.OrderID;
# Out:
#  * sqlite:///northwind.db
# (sqlite3.OperationalError) RIGHT and FULL OUTER JOINs are not currently supported
# [SQL: SELECT O.OrderID, E.LastName, E.FirstName
# FROM Orders as O
# RIGHT JOIN Employees as E ON O.EmployeeID = E.EmployeeID
# ORDER BY O.OrderID;]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ## SQL FULL OUTER JOIN

# %% [markdown]
# #### The FULL OUTER JOIN keyword return all records when there is a match in either left (table1) or right (table2) table records.

# %% [markdown]
# ### FULL OUTER JOIN Syntax

# %% [markdown]
# <code>SELECT column_name(s)
# FROM table1
# FULL OUTER JOIN table2 ON table1.column_name = table2.column_name;</code>

# %% [markdown]
# <img src="https://www.w3schools.com/sql/img_fulljoin.gif">

# %% [markdown]
# #### Write a SQL statement to select all customers, and all orders

# %%
# %%sql
# SELECT Customers.CompanyName, Orders.OrderID
# FROM Customers
# FULL OUTER JOIN Orders ON Customers.CustomerID=Orders.CustomerID
# ORDER BY Customers.CompanyName;

# %% [markdown]
# ## SQL GROUP BY

# %% [markdown]
# #### The GROUP BY statement is often used with aggregate functions (COUNT, MAX, MIN, SUM, AVG) to group the result-set by one or more columns.

# %% [markdown]
# ### GROUP BY Syntax

# %% [markdown]
# <code>SELECT column_name(s)
# FROM table_name
# WHERE condition
# GROUP BY column_name(s)
# ORDER BY column_name(s);</code>

# %% [markdown]
# ### Exercise 28

# %% [markdown]
# #### Write a SQL statement to list the number of customers in each country:

# %%
# %%sql
# SELECT Country, count(*) as [Numbers of Customers]
# FROM Customers
# GROUP BY Country
# ORDER BY [Numbers of Customers];
# Out:
#  * sqlite:///northwind.db
# Done.
# [('Ireland', 1),
#  ('Poland', 1),
#  ('Austria', 2),
#  ('Belgium', 2),
#  ('Denmark', 2),
#  ('Finland', 2),
#  ('Portugal', 2),
#  ('Sweden', 2),
#  ('Switzerland', 2),
#  ('Argentina', 3),
#  ('Canada', 3),
#  ('Italy', 3),
#  ('Venezuela', 4),
#  ('Mexico', 5),
#  ('Norway', 6),
#  ('Spain', 6),
#  ('UK', 7),
#  ('Brazil', 9),
#  ('France', 10),
#  ('Germany', 11),
#  ('USA', 13)]

# %% [markdown]
# ### Exercise 29
# #### Write a SQL statement to list the number of customers in each country, sorted high to low:

# %%
# %%sql
# SELECT Country, count(*) as [Numbers of Customers]
# FROM Customers
# GROUP BY Country
# ORDER BY [Numbers of Customers] desc;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('USA', 13),
#  ('Germany', 11),
#  ('France', 10),
#  ('Brazil', 9),
#  ('UK', 7),
#  ('Spain', 6),
#  ('Norway', 6),
#  ('Mexico', 5),
#  ('Venezuela', 4),
#  ('Italy', 3),
#  ('Canada', 3),
#  ('Argentina', 3),
#  ('Switzerland', 2),
#  ('Sweden', 2),
#  ('Portugal', 2),
#  ('Finland', 2),
#  ('Denmark', 2),
#  ('Belgium', 2),
#  ('Austria', 2),
#  ('Poland', 1),
#  ('Ireland', 1)]

# %% [markdown]
# ### Exercise 30
# #### Write a SQL statement to list the number of orders of each customer.

# %%
# %%sql
# SELECT *
# FROM Customers LIMIT 1
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Tom B. Erichsen', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545')]

# %%
# %%sql
# SELECT *
# FROM Orders LIMIT 1
# Out:
#  * sqlite:///northwind.db
# Done.
# [(10248, 'VINET', 5, '1996-07-04 00:00:00', '1996-08-01 00:00:00', '1996-07-16 00:00:00', 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France')]

# %%
# %%sql
# SELECT CustomerID, count(*) as [Numbers of Order]
# FROM Orders
# GROUP BY CustomerID
# ORDER BY [Numbers of Order];
# Out:
#  * sqlite:///northwind.db
# Done.
# [('CENTC', 1),
#  ('GROSR', 2),
#  ('LAZYK', 2),
#  ('BOLID', 3),
#  ('CONSH', 3),
#  ('FRANR', 3),
#  ('LAUGB', 3),
#  ('NORTS', 3),
#  ('THECR', 3),
#  ('TRAIH', 3),
#  ('ANATR', 4),
#  ('DUMON', 4),
#  ('LACOR', 4),
#  ('LETSS', 4),
#  ('SPECD', 4),
#  ('THEBI', 4),
#  ('COMMI', 5),
#  ('FOLIG', 5),
#  ('GALED', 5),
#  ('HUNGC', 5),
#  ('MORGK', 5),
#  ('OCEAN', 5),
#  ('PRINI', 5),
#  ('RANCH', 5),
#  ('ROMEY', 5),
#  ('VINET', 5),
#  ('ALFKI', 6),
#  ('CACTU', 6),
#  ('DRACD', 6),
#  ('FRANS', 6),
#  ('PERIC', 6),
#  ('SANTG', 6),
#  ('TOMSP', 6),
#  ('TRADH', 6),
#  (None, 7),
#  ('ANTON', 7),
#  ('BLAUS', 7),
#  ('FAMIA', 7),
#  ('MAISD', 7),
#  ('SIMOB', 7),
#  ('WILMK', 7),
#  ('CHOPS', 8),
#  ('EASTC', 8),
#  ('FURIB', 8),
#  ('LONEP', 8),
#  ('GOURL', 9),
#  ('QUEDE', 9),
#  ('SEVES', 9),
#  ('SPLIR', 9),
#  ('WELLI', 9),
#  ('BSBEV', 10),
#  ('GODOS', 10),
#  ('ISLAT', 10),
#  ('MAGAA', 10),
#  ('OLDWO', 10),
#  ('OTTIK', 10),
#  ('PICCO', 10),
#  ('RICSU', 10),
#  ('TORTU', 10),
#  ('VICTE', 10),
#  ('WANDK', 10),
#  ('BLONP', 11),
#  ('GREAL', 11),
#  ('RICAR', 11),
#  ('VAFFE', 11),
#  ('LINOD', 12),
#  ('REGGC', 12),
#  ('SUPRD', 12),
#  ('AROUT', 13),
#  ('MEREP', 13),
#  ('QUEEN', 13),
#  ('BOTTM', 14),
#  ('HANAR', 14),
#  ('KOENE', 14),
#  ('LAMAI', 14),
#  ('LILAS', 14),
#  ('WHITC', 14),
#  ('FRANK', 15),
#  ('LEHMS', 15),
#  ('WARTH', 15),
#  ('BONAP', 17),
#  ('BERGS', 18),
#  ('HILAA', 18),
#  ('RATTC', 18),
#  ('FOLKO', 19),
#  ('HUNGO', 19),
#  ('QUICK', 28),
#  ('ERNSH', 30),
#  ('SAVEA', 31)]

# %%
# %%sql
# Select c.CustomerID, COUNT(o.OrderID) as [Number of order]
# FROM Customers as c inner join Orders as o
# ON c.CustomerID=o.CustomerID
# group by c.customerID
# ORDER BY [Number of order]
# Out:
#  * sqlite:///northwind.db
# Done.
# [('CENTC', 1),
#  ('GROSR', 2),
#  ('LAZYK', 2),
#  ('BOLID', 3),
#  ('CONSH', 3),
#  ('FRANR', 3),
#  ('LAUGB', 3),
#  ('NORTS', 3),
#  ('THECR', 3),
#  ('TRAIH', 3),
#  ('ANATR', 4),
#  ('DUMON', 4),
#  ('LACOR', 4),
#  ('LETSS', 4),
#  ('SPECD', 4),
#  ('THEBI', 4),
#  ('COMMI', 5),
#  ('FOLIG', 5),
#  ('GALED', 5),
#  ('HUNGC', 5),
#  ('MORGK', 5),
#  ('OCEAN', 5),
#  ('PRINI', 5),
#  ('RANCH', 5),
#  ('ROMEY', 5),
#  ('VINET', 5),
#  ('ALFKI', 6),
#  ('CACTU', 6),
#  ('DRACD', 6),
#  ('FRANS', 6),
#  ('PERIC', 6),
#  ('SANTG', 6),
#  ('TOMSP', 6),
#  ('TRADH', 6),
#  ('ANTON', 7),
#  ('BLAUS', 7),
#  ('FAMIA', 7),
#  ('MAISD', 7),
#  ('SIMOB', 7),
#  ('WILMK', 7),
#  ('CHOPS', 8),
#  ('EASTC', 8),
#  ('FURIB', 8),
#  ('LONEP', 8),
#  ('GOURL', 9),
#  ('QUEDE', 9),
#  ('SEVES', 9),
#  ('SPLIR', 9),
#  ('WELLI', 9),
#  ('BSBEV', 10),
#  ('GODOS', 10),
#  ('ISLAT', 10),
#  ('MAGAA', 10),
#  ('OLDWO', 10),
#  ('OTTIK', 10),
#  ('PICCO', 10),
#  ('RICSU', 10),
#  ('TORTU', 10),
#  ('VICTE', 10),
#  ('WANDK', 10),
#  ('BLONP', 11),
#  ('GREAL', 11),
#  ('RICAR', 11),
#  ('VAFFE', 11),
#  ('LINOD', 12),
#  ('REGGC', 12),
#  ('SUPRD', 12),
#  ('AROUT', 13),
#  ('MEREP', 13),
#  ('QUEEN', 13),
#  ('BOTTM', 14),
#  ('HANAR', 14),
#  ('KOENE', 14),
#  ('LILAS', 14),
#  ('WHITC', 14),
#  ('FRANK', 15),
#  ('LEHMS', 15),
#  ('WARTH', 15),
#  ('BONAP', 17),
#  ('BERGS', 18),
#  ('HILAA', 18),
#  ('RATTC', 18),
#  ('FOLKO', 19),
#  ('HUNGO', 19),
#  ('QUICK', 28),
#  ('ERNSH', 30),
#  ('SAVEA', 31)]

# %% [markdown]
# ## SQL HAVING Clause

# %% [markdown]
# #### The HAVING clause was added to SQL because the WHERE keyword could not be used with aggregate functions.

# %% [markdown]
# ### HAVING Syntax

# %% [markdown]
# <code>SELECT column_name(s)
# FROM table_name
# WHERE condition
# GROUP BY column_name(s)
# HAVING condition
# ORDER BY column_name(s);</code>

# %% [markdown]
# ### Exercise 31
# #### Write a SQL statement to list the number of customers in each country. Only include countries with more than 5 customers, and then sort them from high to low.

# %%
# %%sql
# SELECT Country, COUNT(*) as [Number of customer] from customers
# Group by Country
# Having [Number of Customer]>5
# ORDER BY [Number of Customer] DESC;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('USA', 13),
#  ('Germany', 11),
#  ('France', 10),
#  ('Brazil', 9),
#  ('UK', 7),
#  ('Spain', 6),
#  ('Norway', 6)]

# %% [markdown]
# ### Exercise 32
# #### Write a SQL statement to list the employees that have registered more than 50 orders:

# %%
# %%sql
# SELECT * FROM Employees LIMIT 1
# Out:
#  * sqlite:///northwind.db
# Done.
# [(1, 'Davolio', 'Nancy', 'Sales Representative', 'Ms.', '1948-12-08 00:00:00', '1992-05-01 00:00:00', '507 - 20th Ave. E.\r\nApt. 2A', 'Seattle', 'WA', '98122', 'USA', '(206) 555-9857', '5467', b'\x15\x1c/\x00\x02\x00\x00\x00\r\x00\x0e\x00\x14\x00!\x00\xff\xff\xff\xffBitmap Image\x00Paint.Picture\x00\x01\x05\x00\x00\x02\x00\x00\x00\x07\x00\x0 ... (80909 characters truncated) ... 0\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x05\x00\x00\x00\x00\x00\x00\xb4\xad\x05\xfe', 'Education includes a BA in psychology from Colorado State University in 1970.  She also completed "The Art of the Cold Call."  Nancy is a member of Toastmasters International.', 'http://accweb/emmployees/davolio.bmp')]

# %%
# %%sql
# Select e.EmployeeID, COUNT(OrderID) as [Number of Orders]
# FROM Employees as e inner join Orders as o
# ON e.EmployeeID = o.EmployeeID
# group by e.EmployeeID
# HAVING [Number of Orders] >50
# ORDER BY [Number of orders]
# Out:
#  * sqlite:///northwind.db
# Done.
# [(6, 67), (2, 96), (8, 104), (1, 123), (3, 127), (4, 156)]

# %% [markdown]
# ## SQL EXISTS

# %% [markdown]
# #### The EXISTS operator is used to test for the existence of any record in a subquery.
# #### The EXISTS operator returns true if the subquery returns one or more records.

# %% [markdown]
# ### EXISTS Syntax

# %% [markdown]
# <code>SELECT column_name(s)
# FROM table_name
# WHERE EXISTS
# (SELECT column_name FROM table_name WHERE condition);</code>

# %% [markdown]
# ### Exercise 33
# #### Write a SQL statement to list the suppliers with a product price less than 20

# %% [markdown]
# ## SQL ANY and ALL Operators

# %% [markdown]
# #### The ANY and ALL operators are used with a WHERE or HAVING clause.
#
# #### The ANY operator returns true if any of the subquery values meet the condition.
#
# #### The ALL operator returns true if all of the subquery values meet the condition.

# %% [markdown]
# ### ANY Syntax

# %% [markdown]
# <code>SELECT column_name(s)
# FROM table_name
# WHERE column_name operator ANY
# (SELECT column_name FROM table_name WHERE condition);</code>

# %% [markdown]
# ### ALL Syntax

# %% [markdown]
# <code>SELECT column_name(s)
# FROM table_name
# WHERE column_name operator ALL
# (SELECT column_name FROM table_name WHERE condition);</code>

# %% [markdown]
# ### SQLite doesn't support ANY and ALL. :-)

# %% [markdown]
# ## Views

# %% [markdown]
# <p>A view is nothing more than a SQLite statement that is stored in the database with an associated name. It is actually a composition of a table in the form of a predefined SQLite query.
# A view can contain all rows of a table or selected rows from one or more tables. A view can be created from one or many tables which depends on the written SQLite query to create a view.
# Views which are kind of virtual tables, allow the users to −
# <ul>
#     <li>Structure data in a way that users or classes of users find natural or intuitive.</li>
# <li>Restrict access to the data such that a user can only see limited data instead of a complete table.</li>
#     <li>Summarize data from various tables, which can be used to generate reports.</li>
#     </ul>
# SQLite views are read-only and thus you may not be able to execute a DELETE, INSERT or UPDATE statement on a view. However, you can create a trigger on a view that fires on an attempt to DELETE, INSERT, or UPDATE a view and do what you need in the body of the trigger.</p>

# %% [markdown]
# <code>CREATE [TEMP | TEMPORARY] VIEW view_name AS
# SELECT column1, column2.....
# FROM table_name
# WHERE [condition];</code>

# %%
# %%sql
# DROP VIEW IF EXISTS Current_Product_List;
# CREATE VIEW Current_Product_List AS SELECT ProductID, ProductName FROM Products WHERE SupplierID= 2;
# SELECT * FROM Current_Product_List;

# %% [markdown]
# ### Data Definition Language (DDL)
#
# DDL deals with the schemas and structures of database. Examples of DDL are CREATE, ALTER, DROP, and TRUNCATE. In this tutorial, we will use DROP to drop a table from the database.
#
# <code>DROP TABLE table_name;</code>

# %%
#DROP TABLE Region;

# %%
# %sql SELECT FROM Customers GROUP BY HAVING COUNT (*)>1;

# %%
#%sql SELECT Country,LastName FROM Employees GROUP BY Country,LastName HAVING COUNT (*)>1;
#%sql SELECT Country,LastName FROM Employees WHERE COUNT (*)>1;
#%sql SELECT Country,LastName FROM Employees WHERE Country, LastName HAVING  COUNT (*)>1;
# Out:
#  * sqlite:///northwind.db
# (sqlite3.OperationalError) near ",": syntax error
# [SQL: SELECT Country,LastName FROM Employees WHERE Country,LastName HAVING COUNT (*)>1;]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
# %sql SELECT * FROM Customers;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Inigo Montoya', 'Owner', 'Mataderos  2312', 'México D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', None, '68306', 'Germany', '0621-08460', '0621-08924'),
#  ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', 'Marketing Manager', '24, place Kléber', 'Strasbourg', None, '67000', 'France', '88.60.15.31', '88.60.15.32'),
#  ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', 'Owner', 'C/ Araquil, 67', 'Madrid', None, '28023', 'Spain', '(91) 555 22 82', '(91) 555 91 99'),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 'Owner', '12, rue des Bouchers', 'Marseille', None, '13008', 'France', '91.24.45.40', '91.24.45.41'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Accounting Manager', '23 Tsawassen Blvd.', 'Tsawassen', 'BC', 'T2F 8M4', 'Canada', '(604) 555-4729', '(604) 555-3745'),
#  ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None),
#  ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Sales Agent', 'Cerrito 333', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5555', '(1) 135-4892'),
#  ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'Sales Manager', 'C/ Romero, 33', 'Sevilla', None, '41101', 'Spain', '(95) 555 82 82', None),
#  ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Sales Associate', 'Av. Brasil, 442', 'Campinas', 'SP', '04876-786', 'Brazil', '(11) 555-9482', None),
#  ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 'Marketing Manager', '2732 Baker Blvd.', 'Eugene', 'OR', '97403', 'USA', '(503) 555-7555', None),
#  ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', 'Owner', '5ª Ave. Los Palos Grandes', 'Caracas', 'DF', '1081', 'Venezuela', '(2) 283-2951', '(2) 283-3397'),
#  ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Accounting Manager', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil', '(21) 555-0091', '(21) 555-8765'),
#  ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 'Sales Representative', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', 'Táchira', '5022', 'Venezuela', '(5) 555-1340', '(5) 555-1948'),
#  ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'Sales Representative', 'City Center Plaza 516 Main St.', 'Elgin', 'OR', '97827', 'USA', '(503) 555-6874', '(503) 555-2376'),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', 'Sales Associate', '8 Johnstown Road', 'Cork', 'Co. Cork', None, 'Ireland', '2967 542', '2967 3333'),
#  ('ISLAT', 'Island Trading', 'Helen Bennett', 'Marketing Manager', 'Garden House Crowther Way', 'Cowes', 'Isle of Wight', 'PO31 7PJ', 'UK', '(198) 555-8888', None),
#  ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Sales Associate', 'Maubelstr. 90', 'Brandenburg', None, '14776', 'Germany', '0555-09876', None),
#  ('LACOR', "La corne d'abondance", 'Daniel Tonini', 'Sales Representative', "67, avenue de l'Europe", 'Versailles', None, '78000', 'France', '30.59.84.10', '30.59.85.11'),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', 'Marketing Assistant', '1900 Oak St.', 'Vancouver', 'BC', 'V3F 2K1', 'Canada', '(604) 555-3392', '(604) 555-7293'),
#  ('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Marketing Manager', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'USA', '(509) 555-7969', '(509) 555-6221'),
#  ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Sales Representative', 'Magazinweg 7', 'Frankfurt a.M.', None, '60528', 'Germany', '069-0245984', '069-0245874'),
#  ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Owner', '87 Polk St. Suite 5', 'San Francisco', 'CA', '94117', 'USA', '(415) 555-5938', None),
#  ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Accounting Manager', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', 'Lara', '3508', 'Venezuela', '(9) 331-6954', '(9) 331-7256'),
#  ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Owner', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita
#  ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Accounting Manager', 'Taucherstraße 10', 'Cunewalde', None, '01307', 'Germany', '0372-035188', None),
#  ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Sales Representative', 'Av. del Libertador 900', 'Buenos Aires', None, '1010', 'Argentina', '(1) 123-5555', '(1) 123-5556'),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', 'Assistant Sales Representative', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA', '(505) 555-5939', '(505) 555-3620'),
#  ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Sales Associate', 'Strada Provinciale 124', 'Reggio Emilia', None, '42100', 'Italy', '0522-556721', '0522-556722'),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Assistant Sales Agent', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brazil', '(21) 555-3412', None),
#  ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Sales Manager', 'Grenzacherweg 237', 'Genève', None, '1203', 'Switzerland', '0897-034214', None),
#  ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Accounting Manager', 'Gran Vía, 1', 'Madrid', None, '28001', 'Spain', '(91) 745 6200', '(91) 745 6210'),
#  ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Owner', 'Erling Skakkes gate 78', 'Stavern', None, '4110', 'Norway', '07-98 92 35', '07-98 92 47'),
#  ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Sales Representative', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', None),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Owner', 'Vinbæltet 34', 'Kobenhavn', None, '1734', 'Denmark', '31 12 34 56', '31 13 35 57'),
#  ('SPECD', 'Spécialités du monde', 'Dominique Perrier', 'Marketing Manager', '25, rue Lauriston', 'Paris', None, '75016', 'France', '(1) 47.55.60.10', '(1) 47.55.60.20'),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525'),
#  ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Accounting Manager', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium', '(071) 23 67 22 20', '(071) 23 67 22 21'),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Marketing Manager', '89 Jefferson Way Suite 2', 'Portland', 'OR', '97201', 'USA', '(503) 555-3612', None),
#  ('THECR', 'The Cracker Box', 'Liu Wong', 'Marketing Assistant', '55 Grizzly Peak Rd.', 'Butte', 'MT', '59801', 'USA', '(406) 555-5834', '(406) 555-8083'),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany', '0251-031259', '0251-035695'),
#  ('TORTU', 'Tortuga Restaurante', 'Hugo Sanchis', 'Owner', 'Avda. Azteca 123', 'México D.F.', None, '05033', 'Mexico', '(5) 555-2933', None),
#  ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Sales Representative', 'Av. Inês de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brazil', '(11) 555-2167', '(11) 555-2168'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Sales Associate', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'USA', '(206) 555-8257', '(206) 555-2174'),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Sales Manager', 'Smagsloget 45', 'Århus', None, '8200', 'Denmark', '86 21 32 43', '86 22 33 44'),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'Sales Agent', '2, rue du Commerce', 'Lyon', None, '69004', 'France', '78.32.54.86', '78.32.54.87'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11'),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Sales Representative', 'Adenauerallee 900', 'Stuttgart', None, '70563', 'Germany', '0711-020361', '0711-035428'),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Accounting Manager', 'Torikatu 38', 'Oulu', None, '90110', 'Finland', '981-443655', '981-443655'),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Sales Manager', 'Rua do Mercado, 12', 'Resende', 'SP', '08737-363', 'Brazil', '(14) 555-8122', None),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115'),
#  ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Owner/Marketing Assistant', 'Keskuskatu 45', 'Helsinki', None, '21240', 'Finland', '90-224 8858', '90-224 8858'),
#  ('WOLZA', 'Wolski Zajazd', 'Zbyszek Piestrzeniewicz', 'Owner', 'ul. Filtrowa 68', 'Warszawa', None, '01-012', 'Poland', '(26) 642-7012', '(26) 642-7012'),
#  ('CARTO', 'Cardinal', 'Tom B. Erichsen', 'Owner', 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('BARCAS', 'Barcelona CF', 'Lionel Messi', None, 'Camp Nou', 'Barcelona', None, '8028', 'Spain', None, None),
#  ('CART1', 'TheCADS', 'Mehdi', None, 'Skagen 21', 'Stavanger', None, '4040', 'Norway', None, None),
#  ('CART2', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, 'Norway', None, None),
#  ('CART001', 'Cardinal', 'Tom B. Erichsen', None, 'Skagen 21', 'Stavanger', None, '4006', 'Norway', None, None),
#  ('CART002', 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway', None, 'Norway', None, None)]

# %%
# %sql SELECT CompanyName, ContactName FROM Customers ORDER BY CompanyName;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('Alfreds Futterkiste', 'Maria Anders'),
#  ('Ana Trujillo Emparedados y helados', 'Ana Trujillo'),
#  ('Antonio Moreno Taquería', 'Inigo Montoya'),
#  ('Around the Horn', 'Thomas Hardy'),
#  ("B's Beverages", 'Victoria Ashworth'),
#  ('Barcelona CF', 'Lionel Messi'),
#  ('Berglunds snabbköp', 'Christina Berglund'),
#  ('Blauer See Delikatessen', 'Hanna Moos'),
#  ('Blondesddsl père et fils', 'Frédérique Citeaux'),
#  ("Bon app'", 'Laurence Lebihan'),
#  ('Bottom-Dollar Markets', 'Elizabeth Lincoln'),
#  ('Bólido Comidas preparadas', 'Martín Sommer'),
#  ('Cactus Comidas para llevar', 'Patricio Simpson'),
#  ('Cardinal', 'Tom B. Erichsen'),
#  ('Cardinal', 'Tom B. Erichsen'),
#  ('Cardinal', 'Tom B. Erichsen'),
#  ('Cardinal', 'Tom B. Erichsen'),
#  ('Centro comercial Moctezuma', 'Antonio Banderas'),
#  ('Chop-suey Chinese', 'Yang Wang'),
#  ('Comércio Mineiro', 'Pedro Afonso'),
#  ('Consolidated Holdings', 'Elizabeth Brown'),
#  ('Die Wandernde Kuh', 'Rita Müller'),
#  ('Drachenblut Delikatessen', 'Sven Ottlieb'),
#  ('Du monde entier', 'Janine Labrune'),
#  ('Eastern Connection', 'Ann Devon'),
#  ('Ernst Handel', 'Roland Mendel'),
#  ('Familia Arquibaldo', 'Aria Cruz'),
#  ('FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel'),
#  ('Folies gourmandes', 'Martine Rancé'),
#  ('Folk och fä HB', 'Maria Larsson'),
#  ('France restauration', 'Carine Schmitt'),
#  ('Franchi S.p.A.', 'Paolo Accorti'),
#  ('Frankenversand', 'Peter Franken'),
#  ('Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez'),
#  ('Galería del gastrónomo', 'Eduardo Saavedra'),
#  ('Godos Cocina Típica', 'José Pedro Freyre'),
#  ('Gourmet Lanchonetes', 'André Fonseca'),
#  ('Great Lakes Food Market', 'Howard Snyder'),
#  ('GROSELLA-Restaurante', 'Manuel Pereira'),
#  ('Hanari Carnes', 'Mario Pontes'),
#  ('HILARION-Abastos', 'Carlos Hernández'),
#  ('Hungry Coyote Import Store', 'Yoshi Latimer'),
#  ('Hungry Owl All-Night Grocers', 'Patricia McKenna'),
#  ('Island Trading', 'Helen Bennett'),
#  ('Königlich Essen', 'Philip Cramer'),
#  ("La corne d'abondance", 'Daniel Tonini'),
#  ('Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri'),
#  ('Lazy K Kountry Store', 'John Steel'),
#  ('Lehmanns Marktstand', 'Renate Messner'),
#  ("Let's Stop N Shop", 'Jaime Yorres'),
#  ('LILA-Supermercado', 'Carlos González'),
#  ('LINO-Delicateses', 'Felipe Izquierdo'),
#  ('Lonesome Pine Restaurant', 'Fran Wilson'),
#  ('Magazzini Alimentari Riuniti', 'Giovanni Rovelli'),
#  ('Maison Dewey', 'Catherine Dewey'),
#  ('Morgenstern Gesundkost', 'Alexander Feuer'),
#  ('Mère Paillarde', 'Jean Fresnière'),
#  ('North/South', 'Simon Crowther'),
#  ('Océano Atlántico Ltda.', 'Yvonne Moncada'),
#  ('Old World Delicatessen', 'Rene Phillips'),
#  ('Ottilies Käseladen', 'Henriette Pfalzheim'),
#  ('Paris spécialités', 'Marie Bertrand'),
#  ('Pericles Comidas clásicas', 'Salma Hayek'),
#  ('Piccolo und mehr', 'Georg Pipps'),
#  ('Princesa Isabel Vinhos', 'Isabel de Castro'),
#  ('Que Delícia', 'Bernardo Batista'),
#  ('Queen Cozinha', 'Lúcia Carvalho'),
#  ('QUICK-Stop', 'Horst Kloss'),
#  ('Rancho grande', 'Sergio Gutiérrez'),
#  ('Rattlesnake Canyon Grocery', 'Paula Wilson'),
#  ('Reggiani Caseifici', 'Maurizio Moroni'),
#  ('Ricardo Adocicados', 'Janete Limeira'),
#  ('Richter Supermarkt', 'Michael Holz'),
#  ('Romero y tomillo', 'Alejandra Camino'),
#  ('Santé Gourmet', 'Jonas Bergulfsen'),
#  ('Save-a-lot Markets', 'Jose Pavarotti'),
#  ('Seven Seas Imports', 'Hari Kumar'),
#  ('Simons bistro', 'Jytte Petersen'),
#  ('Split Rail Beer & Ale', 'Art Braunschweiger'),
#  ('Spécialités du monde', 'Dominique Perrier'),
#  ('Suprêmes délices', 'Pascale Cartrain'),
#  ('The Big Cheese', 'Liz Nixon'),
#  ('The Cracker Box', 'Liu Wong'),
#  ('TheCADS', 'Mehdi'),
#  ('Toms Spezialitäten', 'Karin Josephs'),
#  ('Tortuga Restaurante', 'Hugo Sanchis'),
#  ('Tradição Hipermercados', 'Anabela Domingues'),
#  ("Trail's Head Gourmet Provisioners", 'Helvetius Nagy'),
#  ('Vaffeljernet', 'Palle Ibsen'),
#  ('Victuailles en stock', 'Mary Saveley'),
#  ('Vins et alcools Chevalier', 'Paul Henriot'),
#  ('Wartian Herkku', 'Pirkko Koskitalo'),
#  ('Wellington Importadora', 'Paula Parente'),
#  ('White Clover Markets', 'Karl Jablonski'),
#  ('Wilman Kala', 'Matti Karttunen'),
#  ('Wolski Zajazd', 'Zbyszek Piestrzeniewicz')]

# %%
# %%sql SELECT CustomerID, CompanyName, ContactName
# FROM Customers
# WHERE CompanyName IS 'Cardinal' OR ContactName IS "Tom B. Erichsen" LIMIT 4 ;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Tom B. Erichsen'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Tom B. Erichsen'),
#  ('CARTO', 'Cardinal', 'Tom B. Erichsen'),
#  ('CART2', 'Cardinal', 'Tom B. Erichsen')]

# %%
# %%sql
# SELECT Country
# FROM Customers WHERE Country HAVING COUNT(*)>1
# Out:
#  * sqlite:///northwind.db
# (sqlite3.OperationalError) a GROUP BY clause is required before HAVING
# [SQL: SELECT Country FROM Customers WHERE Country HAVING COUNT(*)>1]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
